# %%
import pandas as pd

# %%
# Import all data from the main df noebook (Immo_Assistant.app) 
# %run Immo_Assistant.app.ipynb
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_14468\507487594.py:2: SyntaxWarning: invalid escape sequence '\L'
#   df = pd.read_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\data\year_make_model_df.xlsx')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3463 entries, 0 to 3462
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            3463 non-null   int64
#  1   Make            3463 non-null   object
#  2   Model           3463 non-null   string
#  3   Security        3156 non-null   object
#  4   ParameterReset  938 non-null    object
# dtypes: int64(1), object(3), string(1)
# memory usage: 135.4+ KB
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# ...

# %%
# Print the check list to see what is the next dataframe needs to be created
print(make_to_be_done)
# Out:
# ['Pontiac', 'Mazda', 'Acura', 'Honda', 'BMW', 'Lexus', 'Toyota', 'Chrysler', 'Dodge', 'Infiniti', 'Jaguar', 'Lincoln', 'Nissan', 'Plymouth', 'Jeep', 'Audi', 'Mitsubishi', 'Volkswagen', 'Land Rover', 'Mini', 'Rolls-Royce', 'Scion', 'Subaru', 'Fiat']

# %%
# Create Nissan dataframe
df_nissan = create_make_df('Nissan')

# %%
# Check how the df is
df_nissan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 184 entries, 272 to 3372
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            184 non-null    int64
#  1   Make            184 non-null    object
#  2   Model           184 non-null    string
#  3   Security        154 non-null    object
#  4   ParameterReset  0 non-null      object
# dtypes: int64(1), object(3), string(1)
# memory usage: 8.6+ KB

# %%
# Create a list w/ all strings/values from column model
nissan_model_list = strings_from_column(df_nissan, 'Model')

# %%
# Print the list
print(nissan_model_list)
# Out:
# {'Altima', 'Quest', 'Murano', 'Armada', 'Versa', '370Z', 'LEAF (EV)', 'Frontier', 'Maxima', 'Titan', 'Rogue', 'Xterra', 'GT-R', 'Sentra', '350Z', 'Pathfinder', 'Cube', 'Juke'}

# %% [markdown]
# No changes are needed in the Model names.

# %%
# Create a list w/ all strings/values from column security
nissan_security_list = strings_from_column(df_nissan, 'Security')

# %%
# Print the list
nissan_security_list
# Out:
# {'KING CAB:\nStd\nSV, SV14 &\nPro-4X, S Model =Not Available\nCREW CAB:\nStd SV, Pro-4X\n& SL, S Model=Not Available',
#  'KING CAB: All trim levels – optional only \nCREW CAB: All trim levels Std"',
#  'KING CAB: N/A on XE & SE, Std on NISMO & LE\nCREW CAB: Std on SE, LE & NISMO',
#  'KING CAB: Optional LE & Pro-4X Trim Levels\nCREW CAB: Std',
#  'KING CAB: Optional LE & Pro-4X Trim Levels \nCREW CAB: Std',
#  'KING CAB: Optional SV & Pro-4X Trim Levels\nCREW CAB: SV Pro-4X & SL Std',
#  'KING CAB: Optional SV, SV14 & Pro- 4X\nCREW CAB: SV, Pro-4X & SL Std"',
#  'KING CAB: Std on SE & LE, N/A on XE\nCREW CAB: Std on SE & LE, Opt on XE',
#  'KING CAB: Std on SE, Pro- 4x & LE, N/A on XE\nCREW CAB: Std on SE Pro- 4x\n& LE',
#  'KING CAB: Std on SE, Pro-4x & LE, N/A on XE\nCREW CAB: Std on SE Pro-4x\n& LE, Opt on XE',
#  'KING CAB: Std on SE, Pro-4x & LE, N/A on XE\nCREW CAB: Std on SE Pro-4x & LE, Opt on XE',
#  'KING CAB: Std on SV, Pro-4x\nCREW CAB: Std',
# ...

# %%
# Remove charactere '\n'
df_nissan['Security'] = df_nissan['Security'].str.replace('\n', ' ', regex=True)
# Out:
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_14468\825130750.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nissan['Security'] = df_nissan['Security'].str.replace('\n', ' ', regex=True)

# %%
# Print the same list again to confirm if the charactere '\n' was removed from all rows
nissan_security_list_updated = strings_from_column(df_nissan, 'Security')

# %%
# Print the list
nissan_security_list_updated
# Out:
# {'KING CAB: All trim levels – optional only  CREW CAB: All trim levels Std"',
#  'KING CAB: N/A on XE & SE, Std on NISMO & LE CREW CAB: Std on SE, LE & NISMO',
#  'KING CAB: Optional LE & Pro-4X Trim Levels  CREW CAB: Std',
#  'KING CAB: Optional LE & Pro-4X Trim Levels CREW CAB: Std',
#  'KING CAB: Optional SV & Pro-4X Trim Levels CREW CAB: SV Pro-4X & SL Std',
#  'KING CAB: Optional SV, SV14 & Pro- 4X CREW CAB: SV, Pro-4X & SL Std"',
#  'KING CAB: Std SV, SV14 & Pro-4X, S Model =Not Available CREW CAB: Std SV, Pro-4X & SL, S Model=Not Available',
#  'KING CAB: Std on SE & LE, N/A on XE CREW CAB: Std on SE & LE, Opt on XE',
#  'KING CAB: Std on SE, Pro- 4x & LE, N/A on XE CREW CAB: Std on SE Pro- 4x & LE',
#  'KING CAB: Std on SE, Pro-4x & LE, N/A on XE CREW CAB: Std on SE Pro-4x & LE, Opt on XE',
#  'KING CAB: Std on SV, Pro-4x CREW CAB: Std',
#  'KING CAB: Std on SV, Pro-4x CREW CAB: Std on SV Pro-4x & SL S Model=Not Available',
#  'Std',
# ...

# %%
# Fill out null values
df_nissan['Security'].fillna('Information not avaiable', inplace=True)
# Out:
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_14468\3698952474.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_nissan['Security'].fillna('Information not avaiable', inplace=True)
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_14468\3698952474.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
# Drop column 'ParameterReset'
df_nissan_dropped_column = df_nissan.drop(columns=['ParameterReset'])

# %%
df_nissan_dropped_column.columns
# Out:
# Index(['Year', 'Make', 'Model', 'Security'], dtype='object')

# %%
# Download the scion df to .pkl file format
df_nissan_updated.to_excel('df_nissan_updated.xlsx')
