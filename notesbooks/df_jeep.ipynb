# %%
import pandas as pd

# %%
# Import all data from the main df noebook (Immo_Assistant.app) 
# %run Immo_Assistant.app.ipynb
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3463 entries, 0 to 3462
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            3463 non-null   int64
#  1   Make            3463 non-null   object
#  2   Model           3463 non-null   string
#  3   Security        3156 non-null   object
#  4   ParameterReset  938 non-null    object
# dtypes: int64(1), object(3), string(1)
# memory usage: 135.4+ KB
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# Built February 1st or earlier: PATS Type A (Stand Alone PATS Module)
# Built February 2nd or later: PATS Type E (Powertrain Control Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type E (Powertrain Control Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type C (Instrument Cluster)
# PATS Type B (Stand Alone PATS Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type B (Stand Alone PATS Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type C (Instrument Cluster)
# PATS Type B (Stand Alone PATS Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type B (Stand Alone PATS Module)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type B (Stand Alone PATS Module)
# PATS Type E (Powertrain Control Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type C (Instrument Cluster)
# PATS Type B (Stand Alone PATS Module)
# Built July 23rd 2000 or Earlier: PATS Type B (Stand Alone PATS Module)
# Built July 24th 2000 or Later: PATS Type E (Powertrain Control Module)
# Built July 23rd 2000 or Earlier: PATS Type B (Stand Alone PATS Module)
# Built July 24th 2000 or Later: PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type E (Powertrain Control Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type E (Powertrain Control Module)
# PATS Type NA (No PATS)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type F (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type B (Stand Alone PATS Module)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type A (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type F (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type G (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type A (Instrument Cluster)
# Fleet Vehicles: PATS Type G (Instrument Cluster)
# Non-Fleet Vehicles: PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type G (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type G (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type A (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# Fleet Vehicles: PATS Type G (Instrument Cluster)
# Non-Fleet Vehicles: PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type G (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type G (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type A (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# Fleet Vehicles: PATS Type G (Instrument Cluster)
# Non-Fleet Vehicles: PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type G (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type G (Instrument Cluster)
# Keyed Ignition: PATS Type C (Instrument Cluster)
# Push To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type A (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type B (Body Control Module)
# PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type A (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type B (Body Control Module)
# PATS Type B (Body Control Module)
# PATS Type B (Body Control Module)
# Keyed Ignition: PATS Type A (Instrument Cluster)
# Push To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# Keyed Ignition: PATS Type C (Instrument Cluster)
# Push To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type A (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type B (Body Control Module)
# PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type A (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type B (Body Control Module)
# PATS Type B (Body Control Module)
# PATS Type B (Body Control Module)
# Keyed Ignition: PATS Type A (Instrument Cluster)
# Push To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type C (Instrument Cluster)
# Keyed Ignition: PATS Type C (Instrument Cluster)
# Push To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# Keyed Ignition: PATS Type C (Instrument Cluster)
# Push To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type A (Instrument Cluster)
# PATS Type B (Body Control Module)
# PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type B (Body Control Module)
# PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type B (Body Control Module)
# PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type A (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type B (Body Control Module)
# PATS Type B (Body Control Module)
# PATS Type B (Body Control Module)
# Keyed Ignition: PATS Type A (Instrument Cluster)
# Push To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type B (Body Control Module)
# PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# Keyed Ignition: PATS Type C (Instrument Cluster)
# Push To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type B (Body Control Module)
# PATS Type B (Body Control Module)
# PATS Type B (Body Control Module)
# PATS Type C (Instrument Cluster)
# Keyed Ignition: PATS Type C (Instrument Cluster)
# Push To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type A (Instrument Cluster)
# PATS Type B (Body Control Module)
# Stand Alone PATS Module)
# Built February 2nd or later: PATS Type E (Powertrain Control Module
# Year                                                                                                               2001
# Make                                                                                                               Ford
# Model                                                                                              Explorer Sport (2dr)
# ParameterReset                                                                                 Parameter Reset Required
# PATS Type                                                                 Built July 23rd 2000 or Earlier: PATS Type B
# PATS Module Location    Stand Alone PATS Module)\nBuilt July 24th 2000 or Later: PATS Type E (Powertrain Control Module
# Name: 705, dtype: object
# Year                                                                                                               2001
# Make                                                                                                               Ford
# Model                                                                                               Explorer Sport Trac
# ParameterReset                                                                                 Parameter Reset Required
# PATS Type                                                                 Built July 23rd 2000 or Earlier: PATS Type B
# PATS Module Location    Stand Alone PATS Module)\nBuilt July 24th 2000 or Later: PATS Type E (Powertrain Control Module
# Name: 706, dtype: object
# Year                                                                                        2008
# Make                                                                                        Ford
# Model                                                                                   E-Series
# ParameterReset                                                          Parameter Reset Required
# PATS Type                                                           Fleet Vehicles: PATS Type G
# PATS Module Location    Instrument Cluster)\nNon-Fleet Vehicles: PATS Type C (Instrument Cluster
# Name: 2069, dtype: object
# Year                                                                                        2009
# Make                                                                                        Ford
# Model                                                                                   E-Series
# ParameterReset                                                          Parameter Reset Required
# PATS Type                                                           Fleet Vehicles: PATS Type G
# PATS Module Location    Instrument Cluster)\nNon-Fleet Vehicles: PATS Type C (Instrument Cluster
# Name: 2316, dtype: object
# Year                                                                                        2010
# Make                                                                                        Ford
# Model                                                                                   E-Series
# ParameterReset                                                          Parameter Reset Required
# PATS Type                                                           Fleet Vehicles: PATS Type G
# PATS Module Location    Instrument Cluster)\nNon-Fleet Vehicles: PATS Type C (Instrument Cluster
# Name: 2563, dtype: object
# Year                                                                                                                  2010
# Make                                                                                                                  Ford
# Model                                                                                                               Taurus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 2576, dtype: object
# Year                                                                                                                  2011
# Make                                                                                                                  Ford
# Model                                                                                                               FIESTA
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type A
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 2806, dtype: object
# Year                                                                                                                  2011
# Make                                                                                                                  Ford
# Model                                                                                                               Taurus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 2812, dtype: object
# Year                                                                                                                  2012
# Make                                                                                                                  Ford
# Model                                                                                                               FIESTA
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type A
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3038, dtype: object
# Year                                                                                                                  2012
# Make                                                                                                                  Ford
# Model                                                                                                                Focus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3040, dtype: object
# Year                                                                                                                  2012
# Make                                                                                                                  Ford
# Model                                                                                                               Taurus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3045, dtype: object
# Year                                                                                                                  2013
# Make                                                                                                                  Ford
# Model                                                                                                               FIESTA
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type A
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3271, dtype: object
# Year                                                                                                                  2013
# Make                                                                                                                  Ford
# Model                                                                                                                Focus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3274, dtype: object
# Year                                                                                                                  2013
# Make                                                                                                                  Ford
# Model                                                                                                               Taurus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3280, dtype: object
# Year                                                                                                                  2010
# Make                                                                                                                  Ford
# Model                                                                                                               Taurus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 2576, dtype: object
# Year                                                                                                                  2011
# Make                                                                                                                  Ford
# Model                                                                                                               FIESTA
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type A
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 2806, dtype: object
# Year                                                                                                                  2011
# Make                                                                                                                  Ford
# Model                                                                                                               Taurus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 2812, dtype: object
# Year                                                                                                                  2012
# Make                                                                                                                  Ford
# Model                                                                                                               FIESTA
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type A
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3038, dtype: object
# Year                                                                                                                  2012
# Make                                                                                                                  Ford
# Model                                                                                                                Focus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3040, dtype: object
# Year                                                                                                                  2012
# Make                                                                                                                  Ford
# Model                                                                                                               Taurus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3045, dtype: object
# Year                                                                                                                  2013
# Make                                                                                                                  Ford
# Model                                                                                                               FIESTA
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type A
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3271, dtype: object
# Year                                                                                                                  2013
# Make                                                                                                                  Ford
# Model                                                                                                                Focus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3274, dtype: object
# Year                                                                                                                  2013
# Make                                                                                                                  Ford
# Model                                                                                                               Taurus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3280, dtype: object
# Year                                                                                                                  2010
# Make                                                                                                                  Ford
# Model                                                                                                               Taurus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 2576, dtype: object
# Year                                                                                                                  2011
# Make                                                                                                                  Ford
# Model                                                                                                               FIESTA
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type A
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 2806, dtype: object
# Year                                                                                                                  2011
# Make                                                                                                                  Ford
# Model                                                                                                               Taurus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 2812, dtype: object
# Year                                                                                                                  2012
# Make                                                                                                                  Ford
# Model                                                                                                               FIESTA
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type A
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3038, dtype: object
# Year                                                                                                                  2012
# Make                                                                                                                  Ford
# Model                                                                                                                Focus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3040, dtype: object
# Year                                                                                                                  2012
# Make                                                                                                                  Ford
# Model                                                                                                               Taurus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3045, dtype: object
# Year                                                                                                                  2013
# Make                                                                                                                  Ford
# Model                                                                                                               FIESTA
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type A
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3271, dtype: object
# Year                                                                                                                  2013
# Make                                                                                                                  Ford
# Model                                                                                                                Focus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3274, dtype: object
# Year                                                                                                                  2013
# Make                                                                                                                  Ford
# Model                                                                                                               Taurus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3280, dtype: object
# [2576, 2806, 2812, 3038, 3040, 3045, 3271, 3274, 3280]
# Year                                                                                                                  2009
# Make                                                                                                               Lincoln
# Model                                                                                                                  MKS
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 2384, dtype: object
# Year                                                                                                                  2010
# Make                                                                                                               Lincoln
# Model                                                                                                                  MKS
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 2630, dtype: object
# Year                                                                                                                  2011
# Make                                                                                                               Lincoln
# Model                                                                                                                  MKS
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 2862, dtype: object
# Year                                                                                                                  2012
# Make                                                                                                               Lincoln
# Model                                                                                                                  MKS
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3098, dtype: object
# 2384
# 2630
# 2862
# 3098
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_17084\3384685316.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ford[['PATS Type', 'PATS Module Location']] = df_ford['Security'].str.split('(', n=1, expand=True)
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_17084\3384685316.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ford[['PATS Type', 'PATS Module Location']] = df_ford['Security'].str.split('(', n=1, expand=True)
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_17084\370588408.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ford['PATS Module Location'] = df_ford['PATS Module Location'].str.strip(')')
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_17084\2886703368.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lincoln[['PATS Type', 'PATS Module Location']] = df_lincoln['Security'].str.split('(', n=1, expand=True)
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_17084\2886703368.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lincoln[['PATS Type', 'PATS Module Location']] = df_lincoln['Security'].str.split('(', n=1, expand=True)
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_17084\3965777578.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mercury[['PATS Type', 'PATS Module Location']] = df_mercury['Security'].str.split('(', n=1, expand=True)
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_17084\3965777578.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mercury[['PATS Type', 'PATS Module Location']] = df_mercury['Security'].str.split('(', n=1, expand=True)
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_17084\4086986821.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mercury['PATS Module Location'] = df_mercury['PATS Module Location'].str.strip(')')
# Year: 2005
# Make: Cadillac
# Model: CTS
# Security: PK3+
# Hardware Part Number: U44G-G45
# Is this hardware clonable?: No
# ['Acura', 'Honda', 'BMW', 'Lexus', 'Toyota', 'Chrysler', 'Dodge', 'Infiniti', 'Jaguar', 'Nissan', 'Plymouth', 'Jeep', 'Audi', 'Mitsubishi', 'Volkswagen', 'Land Rover', 'Mini', 'Rolls-Royce', 'Scion', 'Subaru', 'Fiat']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3463 entries, 0 to 3462
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            3463 non-null   int64
#  1   Make            3463 non-null   object
#  2   Model           3463 non-null   string
#  3   Security        3156 non-null   object
#  4   ParameterReset  938 non-null    object
# dtypes: int64(1), object(3), string(1)
# memory usage: 135.4+ KB
# ['Information not available', 'Std', 'Std*', 'Opt with\nPower package, SV Std', 'S=Opt with Power\npackage, SV Std\nNV200 Std']
# ['Acura', 'Honda', 'BMW', 'Lexus', 'Toyota', 'Chrysler', 'Dodge', 'Infiniti', 'Jaguar', 'Nissan', 'Plymouth', 'Jeep', 'Audi', 'Mitsubishi', 'Volkswagen', 'Land Rover', 'Mini', 'Rolls-Royce', 'Scion', 'Subaru', 'Fiat']
# <class 'pandas.core.frame.DataFrame'>
# Index: 163 entries, 34 to 3298
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Year      163 non-null    int64
#  1   Make      163 non-null    object
#  2   Model     163 non-null    string
#  3   Security  129 non-null    object
# dtypes: int64(1), object(2), string(1)
# memory usage: 6.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 163 entries, 34 to 3298
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Year      163 non-null    int64
#  1   Make      163 non-null    object
#  2   Model     163 non-null    string
#  3   Security  163 non-null    object
# dtypes: int64(1), object(2), string(1)
# memory usage: 6.4+ KB
# ['Information not available', 'N/A*', 'Std*', 'Std']
# <class 'pandas.core.frame.DataFrame'>
# Index: 266 entries, 119 to 3213
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            266 non-null    int64
#  1   Make            266 non-null    object
#  2   Model           266 non-null    string
#  3   Security        266 non-null    object
#  4   ParameterReset  245 non-null    object
# dtypes: int64(1), object(3), string(1)
# memory usage: 12.5+ KB
# ['318', '325', '525', '530', '535', '540', '840', '850', '740/745*', '750/760*', 'M3', '328', 'Z3', '528', '323', 'M Coupe/Roadster', 'M5', 'X5', '330', 'Z8', '745', '760', 'Z4', '645ci', 'X3', '545', '750', '335', '550', '650', 'M6', 'Z4M coupe & M Roadster', '1 Series (128i/135i)', '3 Series Cabriolet\nretractable hardtop', 'X6', '128', '135', '640', '740', 'Alpina B7', 'X1']
# {'325', '545', '750', '760*', 'M6', '840', 'M3', '530', 'Z8', 'Alpina B7', 'X3', '850', '745', '525', 'Z3', '330', 'Z4', 'X1', '740/745*', '740', '528', '3 Series Cabriolet\nretractable hardtop', '645ci', '650', '328', '550', '323', 'M Coupe/Roadster', 'M5', '128', '640', 'X5', '1 Series (128i', '1 Series (128i/135i)', '318', '128i', '535', 'X6', '540', '335', '135i)', '750/760*', 'Z4M coupe & M Roadster', '135', '760', '745*'}
# [55, 56, 63, 64, 73, 74, 82, 83, 92, 93, 101, 102, 114, 115, 127, 128, 207, 225, 243, 261, 282]
# [55, 56, 63, 64, 73, 74, 82, 83, 92, 93, 101, 102, 114, 115, 127, 128, 207, 225, 243, 261, 282, 32, 34, 36, 38, 40]
# {'325', '545', '750', 'M6', '840', 'M3', '530', 'Z8', 'Alpina B7', 'X3', '850', '745', '525', 'Z3', '330', 'Z4', 'X1', '740', '528', '645ci', '650', '328', '550', '323', 'M Coupe/Roadster', 'M5', '128', '640', '135i', 'X5', '318', '128i', '535', 'X6', '540', '335', '3 Series Cabriolet retractable hardtop', 'Z4M coupe & M Roadster', '135', '760'}
# <class 'pandas.core.frame.DataFrame'>
# Index: 287 entries, 0 to 312
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            287 non-null    int64
#  1   Make            287 non-null    object
#  2   Model           287 non-null    object
#  3   Security        287 non-null    object
#  4   ParameterReset  266 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 13.5+ KB
# ['Std']

# %%
# Print the check list to confirm the next df should be created
print(make_to_be_done)
# Out:
# ['Acura', 'Honda', 'BMW', 'Lexus', 'Toyota', 'Chrysler', 'Dodge', 'Infiniti', 'Jaguar', 'Nissan', 'Plymouth', 'Jeep', 'Audi', 'Mitsubishi', 'Volkswagen', 'Land Rover', 'Mini', 'Rolls-Royce', 'Scion', 'Subaru', 'Fiat']

# %%
# Jeep is the next df to be created
df_jeep = create_make_df('Jeep')

# %%
# Check how the df is
df_jeep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 98 entries, 351 to 3317
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            98 non-null     int64
#  1   Make            98 non-null     object
#  2   Model           98 non-null     string
#  3   Security        95 non-null     object
#  4   ParameterReset  28 non-null     object
# dtypes: int64(1), object(3), string(1)
# memory usage: 4.6+ KB

# %%
# Create a list w/ strings/values from column model
jeep_model_list = strings_from_column(df_jeep, 'Model')

# %%
# Print the list
print(jeep_model_list)
# Out:
# {'Compass', 'Commander', 'Wrangler', 'Patriot', 'Cherokee', 'Grand Cherokee Laredo', 'Liberty', 'Grand Cherokee Overland', 'Grand Cherokee Limited'}

# %% [markdown]
# No changes are needed at the strings/values from column 'Model'.

# %%
# Create a list w/ strings/values from column security
jeep_security_list = strings_from_column(df_jeep, 'Security')

# %%
# Print the list
jeep_security_list
# Out:
# {'- Std\nwith power windows & power locks ----',
#  'Opt',
#  'Opt\nLate availability',
#  'Opt (Std on Sahara)',
#  'Std',
#  'Std\nw/o  power windows\n& power locks',
#  'Std\nw/o  power windows & power locks',
#  'Std\nw/o power windows\n& power locks',
#  'Std\nw/o power windows & power locks',
#  'Std\nwith power windows\n& power locks',
#  'Std\nwith power windows & power locks',
#  'Std with power\nwindows & power locks',
#  nan}

# %%
# Remove the charactere '\n'
df_jeep['Security'] = df_jeep['Security'].str.replace('\n', ' ', regex=True)
# Out:
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_17084\1021279373.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_jeep['Security'] = df_jeep['Security'].str.replace('\n', ' ', regex=True)

# %%
# Fill out null values
df_jeep['Security'].fillna('Information not available', inplace=True)
# Out:
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_17084\2247910758.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_jeep['Security'].fillna('Information not available', inplace=True)
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_17084\2247910758.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_jeep['Security'].fillna('Information not available', inplace=True)

# %%
# Create a list w/ strings/values from column 'ParameterReset'
jeep_pr_list = strings_from_column(df_jeep, 'ParameterReset')

# %%
# Print the list
jeep_pr_list
# Out:
# {'Sentry Key Immobilizer System = Standard equipment',
#  nan,
#  '“SKREES” Sentry Key Remote Entry System (same as SKIS, the key remote entry module was combined with the Sentry Key Immobilizer Module, it’s still Sentry Key)'}

# %% [markdown]
# No changes are needed, just need to fill out the null values.

# %%
# Fill out null values at column 'ParameterReset'
df_jeep['ParameterReset'].fillna('Information not available', inplace=True)
# Out:
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_17084\3889975749.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_jeep['ParameterReset'].fillna('Information not available', inplace=True)
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_17084\3889975749.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_jeep['ParameterReset'].fillna('Information not available', inplace=True)

# %%
# Change the column 'ParameterReset' for 'Security System Addiotional info' as parameter reset is only for Ford
df_jeep_change_column = df_jeep.rename(columns={'ParameterReset': 'Jeep Security System Addiotional Info'})

# %%
# Reset index
df_jeep_updated = df_jeep_change_column.reset_index(drop=True)

# %%
# Download the scion df to .pkl file format
df_jeep_updated.to_pickle('df_jeep_updated.pkl')
