# %%
import pandas as pd

# %%
# Import all data from the main df noebook (Immo_Assistant.app) 
# %run Immo_Assistant.app.ipynb
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3463 entries, 0 to 3462
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            3463 non-null   int64
#  1   Make            3463 non-null   object
#  2   Model           3463 non-null   string
#  3   Security        3156 non-null   object
#  4   ParameterReset  938 non-null    object
# dtypes: int64(1), object(3), string(1)
# memory usage: 135.4+ KB
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# Built February 1st or earlier: PATS Type A (Stand Alone PATS Module)
# Built February 2nd or later: PATS Type E (Powertrain Control Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type B (Stand Alone PATS Module)
# ...

# %%
# Print the check list to see what is the next dataframe needs to be created
print(make_to_be_done)
# Out:
# ['Acura', 'Honda', 'BMW', 'Lexus', 'Toyota', 'Chrysler', 'Dodge', 'Infiniti', 'Jaguar', 'Nissan', 'Plymouth', 'Jeep', 'Audi', 'Mitsubishi', 'Volkswagen', 'Land Rover', 'Mini', 'Rolls-Royce', 'Scion', 'Subaru', 'Fiat']

# %%
# Create Nissan dataframe
df_land_rover = create_make_df('Land Rover')

# %%
# Check how the df is
df_land_rover.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45 entries, 904 to 3322
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            45 non-null     int64
#  1   Make            45 non-null     object
#  2   Model           45 non-null     string
#  3   Security        45 non-null     object
#  4   ParameterReset  0 non-null      object
# dtypes: int64(1), object(3), string(1)
# memory usage: 2.1+ KB

# %%
# Create a list w/ all strings/values from column model
land_rover_model_list = strings_from_column(df_land_rover, 'Model')

# %%
# Print the list
land_rover_model_list
# Out:
# {'Discovery',
#  'Freelander',
#  'LR2',
#  'LR3',
#  'LR4',
#  'Range Rover',
#  'Range Rover Evoque',
#  'Range Rover Sport'}

# %% [markdown]
# No changes are needed in the Land Rover models

# %%
# Create a list w/ all strings/values from column security
land_rover_security_list = strings_from_column(df_land_rover, 'Security')

# %%
# Print the list
land_rover_security_list
# Out:
# {'Std'}

# %% [markdown]
# No changes are needed in the Security column

# %%
# Remove column 'ParameterReset' as it is empty
df_land_rover_drop_pr_column = df_land_rover.drop(columns=['ParameterReset'])

# %%
# Reset index
df_land_rover_updated = df_land_rover_drop_pr_column.reset_index(drop=True)

# %%
# Transfer the df to pickle file 
df_land_rover_updated.to_pickle('df_land_rover_updated.pkl')
