# %%
import pandas as pandas

# %%
# Import all data from the main df noebook (Immo_Assistant.app) 
# %run Immo_Assistant.app.ipynb
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3463 entries, 0 to 3462
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            3463 non-null   int64
#  1   Make            3463 non-null   object
#  2   Model           3463 non-null   string
#  3   Security        3156 non-null   object
#  4   ParameterReset  938 non-null    object
# dtypes: int64(1), object(3), string(1)
# memory usage: 135.4+ KB
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# Built February 1st or earlier: PATS Type A (Stand Alone PATS Module)
# Built February 2nd or later: PATS Type E (Powertrain Control Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type B (Stand Alone PATS Module)
# ...

# %%
# Print the make to be done list to confirm the next dataframe to be created
print(make_to_be_done)
# Out:
# ['Acura', 'Honda', 'BMW', 'Lexus', 'Toyota', 'Chrysler', 'Dodge', 'Infiniti', 'Jaguar', 'Nissan', 'Plymouth', 'Jeep', 'Audi', 'Mitsubishi', 'Volkswagen', 'Land Rover', 'Mini', 'Rolls-Royce', 'Scion', 'Subaru', 'Fiat']

# %%
# Chrysler is the next df
df_chrysler = create_make_df('Chrysler')

# %%
# Check how the df is
df_chrysler.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 109 entries, 239 to 3244
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            109 non-null    int64
#  1   Make            109 non-null    object
#  2   Model           109 non-null    string
#  3   Security        92 non-null     object
#  4   ParameterReset  0 non-null      object
# dtypes: int64(1), object(3), string(1)
# memory usage: 5.1+ KB

# %% [markdown]
# 1. Fill out the null values in column 'Security'
# 2. Drop column 'ParameterReset'

# %%
# Fill out the null values in the column 'Security'
df_chrysler['Security'].fillna('Information not available', inplace=True)
# Out:
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_10960\2691649491.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chrysler['Security'].fillna('Information not available', inplace=True)

# %%
# Drop column 'ParameterReset'
df_chrysler_dropped_column = df_chrysler.drop(columns=['ParameterReset'])

# %%
# Check how the df is after the above updates
df_chrysler_dropped_column.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 109 entries, 239 to 3244
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Year      109 non-null    int64
#  1   Make      109 non-null    object
#  2   Model     109 non-null    string
#  3   Security  109 non-null    object
# dtypes: int64(1), object(2), string(1)
# memory usage: 4.3+ KB

# %%
# Create a list to show all models and decide if changes need to be done in this column
chrysler_model_list = strings_from_column(df_chrysler_dropped_column, 'Model')

# %%
# Print the list and decide what changes need to be done
print(chrysler_model_list)
# Out:
# {'Sebring Coupe', 'Sebring Sedan', '300M', 'Aspen', 'Crossfire', 'Sebring Convertible LX/GTC/base', 'Concorde', 'Pacifica', '300C', 'Concorde LXI/Limited', 'PT\nCruiser/Convertible.', 'Town & Country', 'Sebring Convertible LXI/Limited/Touring', 'Cirrus', 'LHS', '200 & 200 Convertible', 'PT Cruiser/ Convertible', 'PT Cruiser', 'Sebring Convertible  LXI/Limited/Touring'}

# %% [markdown]
# CHANGES NEEDED
# - Replace the caractere '\n' for space ' '

# %%
# Replace the caractere '\n' for space ' '
df_chrysler_dropped_column['Model'] = df_chrysler_dropped_column['Model'].str.replace('\n', ' ', regex=False)

# %%
# Create a list to show all strings in the column 'Security'
chrysler_security_list = strings_from_column(df_chrysler_dropped_column, 'Security')

# %%
# Print the list and decide what changes need to be done
print(chrysler_security_list)
# Out:
# {'Opt\nLate availability', 'Opt', 'Std', 'Std / Limited', 'Opt (Std in Canada)', 'Std (Except Base)', 'Information not available'}

# %% [markdown]
# CHANGES NEEDED
# - Replace the caractere '\n' for space ' '

# %%
# Replace the caractere '\n' for space ' '
df_chrysler_dropped_column['Security'] = df_chrysler_dropped_column['Security'].str.replace('\n', ' ', regex=False)

# %%
# Reset the index column
df_chrysler_dropped_column = df_chrysler_dropped_column.reset_index()

# %%
# Drop column 'index' and store the final dataframe into the final variable
df_chrysler_updated = df_chrysler_dropped_column.drop(columns=['index'])
