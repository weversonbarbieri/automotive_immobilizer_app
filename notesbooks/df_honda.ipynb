# %%
import pandas as pd

# %%
# %run Immo_Assistant.app.ipynb
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3463 entries, 0 to 3462
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            3463 non-null   int64
#  1   Make            3463 non-null   object
#  2   Model           3463 non-null   string
#  3   Security        3156 non-null   object
#  4   ParameterReset  938 non-null    object
# dtypes: int64(1), object(3), string(1)
# memory usage: 135.4+ KB
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# Built February 1st or earlier: PATS Type A (Stand Alone PATS Module)
# Built February 2nd or later: PATS Type E (Powertrain Control Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type B (Stand Alone PATS Module)
# ...

# %%
# Create the Honda df
df_honda = create_make_df('Honda')

# %%
# Check how the df is
df_honda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 163 entries, 34 to 3298
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            163 non-null    int64
#  1   Make            163 non-null    object
#  2   Model           163 non-null    string
#  3   Security        129 non-null    object
#  4   ParameterReset  0 non-null      object
# dtypes: int64(1), object(3), string(1)
# memory usage: 7.6+ KB

# %%
# Create w/ strings/values from column Model
honda_model_list = strings_from_column(df_honda, 'Model')

# %%
# Print the list
honda_model_list
# Out:
# {'Accord',
#  'CR-Z',
#  'CRV',
#  'Civic',
#  'Crosstour',
#  'Element',
#  'Fit',
#  'Insight (Hybrid)',
#  'Odyssey',
#  'Passport (Isuzu)',
#  'Pilot',
#  'Prelude',
#  'Ridgeline',
#  'S2000'}

# %% [markdown]
# No changes are needed, as all models are correct described.

# %%
# Create a list w/ strings/values from column security
honda_security_list = strings_from_column(df_honda, 'Security')

# %%
# Print the list
honda_security_list
# Out:
# {'N/A*', 'Std', 'Std*', nan}

# %% [markdown]
# CHANGES NEEDED:
# - Fill out null values.
# - Replace the string 'N/A*' for the string 'Immobilizer was not available for that model year'.
# - Remove the charactere '*'.

# %%
# Replace the string 'N/A*' for the string 'Immobilizer was not available for that model year'
df_honda['Security'] = df_honda['Security'].str.replace('N/A*', 'Immobilizer was not available for that model year', regex=False)
# Out:
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_1592\2832658725.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_honda['Security'] = df_honda['Security'].str.replace('N/A*', 'Immobilizer was not available for that model year', regex=False)

# %%
# Remove the charactere '*'
df_honda['Security'] = df_honda['Security'].str.replace('Std*', 'Std', regex=False)
# Out:
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_1592\96260864.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_honda['Security'] = df_honda['Security'].str.replace('Std*', 'Std', regex=False)

# %%
# Fill out null values
df_honda['Security'].fillna('Information not available', inplace=True)
# Out:
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_1592\1118030929.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_honda['Security'].fillna('Information not available', inplace=True)

# %%
# Drop column ParameterReset
df_honda_dropped_column = df_honda.drop(columns=['ParameterReset'])

# %%
# Reset index
df_honda_updated = df_honda_dropped_column.reset_index(drop=True)

# %%
df_honda_updated.to_pickle('df_honda_updated.pkl')
