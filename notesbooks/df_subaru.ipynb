# %%
import pandas as pd

# %%
# %run Immo_Assistant.app.ipynb
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_21764\507487594.py:2: SyntaxWarning: invalid escape sequence '\L'
#   df = pd.read_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\data\year_make_model_df.xlsx')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3463 entries, 0 to 3462
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            3463 non-null   int64
#  1   Make            3463 non-null   object
#  2   Model           3463 non-null   string
#  3   Security        3156 non-null   object
#  4   ParameterReset  938 non-null    object
# dtypes: int64(1), object(3), string(1)
# memory usage: 135.4+ KB
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# ...

# %%
# Print the check list to see what is the next dataframe needs to be created
print(make_to_be_done)
# Out:
# ['Mazda', 'Acura', 'Honda', 'BMW', 'Lexus', 'Toyota', 'Chrysler', 'Dodge', 'Infiniti', 'Jaguar', 'Lincoln', 'Nissan', 'Plymouth', 'Jeep', 'Audi', 'Mitsubishi', 'Volkswagen', 'Land Rover', 'Mini', 'Rolls-Royce', 'Scion', 'Subaru', 'Fiat']

# %%
# Create Subaru dataframe
df_subaru = create_make_df('Subaru')

# %%
# Check the dataframe to see how it is
df_subaru.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 53 entries, 1334 to 3387
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            53 non-null     int64
#  1   Make            53 non-null     object
#  2   Model           53 non-null     string
#  3   Security        46 non-null     object
#  4   ParameterReset  0 non-null      object
# dtypes: int64(1), object(3), string(1)
# memory usage: 2.5+ KB

# %%
# Create a list w/ all strings/values from column model
subaru_model_list = strings_from_column(df_subaru, 'Model')

# %%
# Print the list
subaru_model_list
# Out:
# {'B9 Tribeca (2006 – 2007)\nTribeca (2008 – onward)',
#  'BRZ',
#  'Baja',
#  'Forester',
#  'Impreza',
#  'Legacy',
#  'Outback',
#  'XV Crosstrek'}

# %%
# Create a dataframe only containing the string 'B9 Tribeca (2006 – 2007)\nTribeca (2008 – onward)'
tribeca_model_list = []

# Loop to get all rows with model Tribeca and store in the above list
for index, row in df_subaru.iterrows():
    if 'B9 Tribeca (2006 – 2007)\nTribeca (2008 – onward)' in row['Model']:
        tribeca_model_list.append(row)

# %%
# Change from list to dataframe
df_tribeca = pd.DataFrame(tribeca_model_list)

# %%
# Print the tribeca df
df_tribeca
# Out:
#       Year    Make                                              Model  \
# 1714  2006  Subaru  B9 Tribeca (2006 – 2007)\nTribeca (2008 – onward)
# 1951  2007  Subaru  B9 Tribeca (2006 – 2007)\nTribeca (2008 – onward)
# 2193  2008  Subaru  B9 Tribeca (2006 – 2007)\nTribeca (2008 – onward)
# 2445  2009  Subaru  B9 Tribeca (2006 – 2007)\nTribeca (2008 – onward)
# 2684  2010  Subaru  B9 Tribeca (2006 – 2007)\nTribeca (2008 – onward)
# 2906  2011  Subaru  B9 Tribeca (2006 – 2007)\nTribeca (2008 – onward)
# 3147  2012  Subaru  B9 Tribeca (2006 – 2007)\nTribeca (2008 – onward)
# 3382  2013  Subaru  B9 Tribeca (2006 – 2007)\nTribeca (2008 – onward)
#
#               Security  ParameterReset
# 1714  Std all variants             NaN
# 1951  Std all variants             NaN
# 2193  Std all variants             NaN
# 2445  Std all variants             NaN
# 2684  Std all variants             NaN
# 2906  Std all variants             NaN
# 3147  Std all variants             NaN
# ...

# %% [markdown]
# As the model B9 Tribeca needs to be only in 2 rows (2006 and 2007), the following will be done:
# - Create a dataframe w/ 2 rows for model 2006 and 2007 B9 Tribeca.
# - Concatenate this dataframe to the df_subaru.
# - Replace the string 'B9 Tribeca (2006 – 2007)\nTribeca (2008 – onward)' for the string 'Tribeca' on the df_subaru
# - Drop column 'ParameterReset' as it has no values.

# %%
# Create a df for the model B9 Tribeca
df_b9_tribeca = pd.DataFrame({'Year': [2006, 2007], 'Make': ['Subaru', 'Subaru'], 'Model': ['B9 Tribeca', 'B9 Tribeca'], 'Security': ['Std all variants', 'Std all variants']})

# %%
# Drop column ParameterReset
df_subaru_drop_column = df_subaru.drop(columns=['ParameterReset'])

# %%
# Replace the string 'B9 Tribeca (2006 – 2007)\nTribeca (2008 – onward)' for the string 'Tribeca'
df_replaced_tribeca = df_subaru_drop_column.replace(to_replace='B9 Tribeca (2006 – 2007)\nTribeca (2008 – onward)', value='Tribeca', regex=False)

# %%
# Concatenate df_tribeca to the df_subaru
df_subaru_concatenated = pd.concat([df_b9_tribeca, df_replaced_tribeca])

# %%
# Create a list w/ the models after updating
subaru_model_list_updated = strings_from_column(df_subaru_concatenated, 'Model')

# %%
# Print the updated list
subaru_model_list_updated
# Out:
# {'B9 Tribeca',
#  'BRZ',
#  'Baja',
#  'Forester',
#  'Impreza',
#  'Legacy',
#  'Outback',
#  'Tribeca',
#  'XV Crosstrek'}

# %%
# Create a list w/ all strings/values from column security
subaru_security_list = strings_from_column(df_subaru_concatenated, 'Security')

# %%
# Print the list
subaru_security_list
# Out:
# {'Std 2.5\nXT',
#  'Std 2.5\nXT &\n3.0 R',
#  'Std 2.5 GT',
#  'Std 2.5 XT',
#  'Std WRX\nSTI',
#  'Std all\nvariants',
#  'Std all Variants',
#  'Std all WRX &\nWRX STI',
#  'Std all variants',
#  nan}

# %% [markdown]
# CHANGES NEEDED:
# - Fill out null values.
# - Replace the charactere '\n' by space ' '.

# %%
# Fill out null values
df_subaru_concatenated['Security'].fillna('Information not available', inplace=True)
# Out:
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_21764\1834961439.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_subaru_concatenated['Security'].fillna('Information not available', inplace=True)

# %%
# Replace the charactere '\n' by space ' '
df_subaru_concatenated['Security'] = df_subaru_concatenated['Security'].str.replace('\n', ' ', regex=False)

# %%
# Creata a list after updating the the strings in the column security
subaru_security_list_updated = strings_from_column(df_subaru_concatenated, 'Security')

# %%
# Print the list
subaru_security_list_updated
# Out:
# {'Information not available',
#  'Std 2.5 GT',
#  'Std 2.5 XT',
#  'Std 2.5 XT & 3.0 R',
#  'Std WRX STI',
#  'Std all Variants',
#  'Std all WRX & WRX STI',
#  'Std all variants'}

# %%
# Sort the df using the values in the column Year and reset the index
df_subaru_sorted = df_subaru_concatenated.sort_values(by='Year', ascending=True).reset_index(drop=True)

# %%
# Download the scion df to .pkl file format
df_subaru_sorted.to_excel('df_subaru_updated.xlsx')
