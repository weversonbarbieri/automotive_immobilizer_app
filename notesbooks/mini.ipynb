# %%
import pandas as pd

# %%
# %run Immo_Assistant.app.ipynb
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_13376\507487594.py:2: SyntaxWarning: invalid escape sequence '\L'
#   df = pd.read_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\data\year_make_model_df.xlsx')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3463 entries, 0 to 3462
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            3463 non-null   int64
#  1   Make            3463 non-null   object
#  2   Model           3463 non-null   string
#  3   Security        3156 non-null   object
#  4   ParameterReset  938 non-null    object
# dtypes: int64(1), object(3), string(1)
# memory usage: 135.4+ KB
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# ...

# %%
# Print the check list to see what is the next dataframe needs to be created
print(make_to_be_done)
# Out:
# ['Pontiac', 'Mazda', 'Acura', 'Honda', 'BMW', 'Lexus', 'Toyota', 'Chrysler', 'Dodge', 'Infiniti', 'Jaguar', 'Lincoln', 'Nissan', 'Plymouth', 'Jeep', 'Audi', 'Mitsubishi', 'Volkswagen', 'Land Rover', 'Mini', 'Rolls-Royce', 'Scion', 'Subaru', 'Fiat']

# %%
# Create Mini dataframe
df_mini = create_make_df('Mini')

# %%
# Check how the df is
df_mini.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22 entries, 928 to 3349
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            22 non-null     int64
#  1   Make            22 non-null     object
#  2   Model           22 non-null     string
#  3   Security        22 non-null     object
#  4   ParameterReset  16 non-null     object
# dtypes: int64(1), object(3), string(1)
# memory usage: 1.0+ KB

# %%
# Create a list w/ all strings/values from column model
mini_model_list = strings_from_column(df_mini, 'Model')

# %%
# Print the list
mini_model_list
# Out:
# {'Clubman',
#  'Cooper',
#  'Cooper (s)\nHardtop & Cabrio',
#  'Countryman',
#  'Coupe',
#  'John Cooper Works'}

# %% [markdown]
# The only change needed is to remove/replace the charactere '\n' for space ' '

# %%
# Remove/replace the charactere '\n' for space ' '
df_mini['Model'] = df_mini['Model'].str.replace('\n', ' ', regex=True)
# Out:
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_13376\2580703707.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mini['Model'] = df_mini['Model'].str.replace('\n', ' ', regex=True)

# %%
# Filter the dataframe to get only the model Clubman
df_clubman = df_mini[df_mini['Model'] == 'Clubman']

# %%
# Check how the df is
df_clubman
# Out:
#       Year  Make    Model Security ParameterReset
# 3110  2012  Mini  Clubman      Std        EWS III
# 3111  2012  Mini  Clubman      Std        EWS III
# 3344  2013  Mini  Clubman      Std            NaN
# 3345  2013  Mini  Clubman      Std            NaN

# %%
# Remove duplicates
df_mini.drop_duplicates(inplace=True)
# Out:
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_13376\371691398.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mini.drop_duplicates(inplace=True)

# %%
# Create a list w/ all strings/values from column security
mini_security_list = strings_from_column(df_mini, 'Security')

# %%
# Print the list
mini_security_list
# Out:
# {'Std'}

# %% [markdown]
# No changes needed in the Security column as all rows has the value/string 'Std'

# %%
# Create a list w/ all strings/values from column ParameterReset
mini_pr_list = strings_from_column(df_mini, 'ParameterReset')

# %%
# Print the list
mini_pr_list
# Out:
# {'EWS III', nan}

# %% [markdown]
# The only change needed is to fill out the null values (nan).

# %%
df_mini['ParameterReset'].fillna('Information not available', inplace=True)
# Out:
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_13376\3079728211.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_mini['ParameterReset'].fillna('Information not available', inplace=True)
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_13376\3079728211.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
# Rename the column ParameterReset as it is not applicable to Mini
df_mini_rename_pr_column = df_mini.rename(columns={'ParameterReset': 'Mini Security System Additional Information'})

# %%
# Check if the column names are correct after updating
for column in df_mini_rename_pr_column.columns:
    print(column)
# Out:
# Year
# Make
# Model
# Security
# Mini Security System Additional Information

# %%
df_mini_updated.columns

# %%
# Save the df to pickle file
df_mini_updated.to_excel('df_mini_updated.xlsx')
