# %%
import pandas as pd

# %%
# Import all data from the main df noebook (Immo_Assistant.app) 
# %run Immo_Assistant.app.ipynb
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_2624\507487594.py:2: SyntaxWarning: invalid escape sequence '\L'
#   df = pd.read_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\data\year_make_model_df.xlsx')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3463 entries, 0 to 3462
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            3463 non-null   int64
#  1   Make            3463 non-null   object
#  2   Model           3463 non-null   string
#  3   Security        3156 non-null   object
#  4   ParameterReset  938 non-null    object
# dtypes: int64(1), object(3), string(1)
# memory usage: 135.4+ KB
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# ...

# %%
# Print the check list to confirm the next df should be created
print(make_to_be_done)
# Out:
# ['Pontiac', 'Mazda', 'Acura', 'Honda', 'BMW', 'Lexus', 'Toyota', 'Chrysler', 'Dodge', 'Infiniti', 'Jaguar', 'Lincoln', 'Nissan', 'Plymouth', 'Jeep', 'Audi', 'Mitsubishi', 'Volkswagen', 'Land Rover', 'Mini', 'Rolls-Royce', 'Scion', 'Subaru', 'Fiat']

# %%
# Plymouth is the next df to be created
df_plymouth = create_make_df('Plymouth')

# %%
# Check how the df is
df_plymouth.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16 entries, 277 to 1128
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            16 non-null     int64
#  1   Make            16 non-null     object
#  2   Model           16 non-null     string
#  3   Security        3 non-null      object
#  4   ParameterReset  0 non-null      object
# dtypes: int64(1), object(3), string(1)
# memory usage: 768.0+ bytes

# %%
# Create a list w/ strings/values from column model
plymouth_model_list = strings_from_column(df_plymouth, 'Model')

# %%
# Print the list
plymouth_model_list
# Out:
# {'Breeze', 'Prowler', 'Voyager'}

# %% [markdown]
# No changes needed.

# %%
# Create a list w/ strings/values from column security
plymouth_security_list = strings_from_column(df_plymouth, 'Security')

# %%
# Print the list
plymouth_security_list
# Out:
# {'Opt', nan}

# %% [markdown]
# The only change needed is to fill out null values.

# %%
# Fill out null values
df_plymouth['Security'].fillna('Information not available', inplace=True)
# Out:
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_2624\2768087878.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_plymouth['Security'].fillna('Information not available', inplace=True)
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_2624\2768087878.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
# Drop column 'ParameterReset'
df_plymouth_updated = df_plymouth.drop(columns=['ParameterReset'])

# %%
df_plymouth_updated.columns
# Out:
# Index(['Year', 'Make', 'Model', 'Security'], dtype='object')

# %%
# Download the scion df to .pkl file format
df_plymouth_updated.to_excel('df_plymouth_updated.xlsx')
