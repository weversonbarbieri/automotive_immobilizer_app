# %%
import pandas as pd

# %%
# %run Immo_Assistant.app.ipynb
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3463 entries, 0 to 3462
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            3463 non-null   int64
#  1   Make            3463 non-null   object
#  2   Model           3463 non-null   string
#  3   Security        3156 non-null   object
#  4   ParameterReset  938 non-null    object
# dtypes: int64(1), object(3), string(1)
# memory usage: 135.4+ KB
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# Built February 1st or earlier: PATS Type A (Stand Alone PATS Module)
# Built February 2nd or later: PATS Type E (Powertrain Control Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type B (Stand Alone PATS Module)
# ...

# %%
# Print the check list to confirm the next df should be created
print(make_to_be_done)
# Out:
# ['Acura', 'Honda', 'BMW', 'Lexus', 'Toyota', 'Chrysler', 'Dodge', 'Infiniti', 'Jaguar', 'Nissan', 'Plymouth', 'Jeep', 'Audi', 'Mitsubishi', 'Volkswagen', 'Land Rover', 'Mini', 'Rolls-Royce', 'Scion', 'Subaru', 'Fiat']

# %%
# Volkswagen is the next df to be created
df_volkswagen = create_make_df('Volkswagen')

# %%
# Check how the df is
df_volkswagen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 135 entries, 644 to 3419
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            135 non-null    int64
#  1   Make            135 non-null    object
#  2   Model           135 non-null    string
#  3   Security        133 non-null    object
#  4   ParameterReset  0 non-null      object
# dtypes: int64(1), object(3), string(1)
# memory usage: 6.3+ KB

# %%
# Create a list w/ strings/values from column model
volkswagen_model_list = strings_from_column(df_volkswagen, 'Model')

# %%
# Print the list
volkswagen_model_list
# Out:
# {'CC/Passat CC',
#  'Cabrio',
#  'City Golf Mk4.5',
#  'City Jetta Mk4.5',
#  'Eos',
#  'Euro Van',
#  'GTI',
#  'Golf A5',
#  'Golf City Mk4.5',
#  'Golf Mk4',
#  'Jetta (NF)',
#  'Jetta A5',
#  'Jetta City Mk4.5',
#  'Jetta Mk4',
#  'New Beetle',
#  'Passat “NMS”',
#  'Phaeton',
#  'R32',
#  'Rabbit',
#  'Routan',
#  'Tiguan',
#  'Touareg'}

# %% [markdown]
# CHANGES NEEDED:
# - Remove the charactere "CC/" from the model "CC/Passat CC"

# %%
# Remove the charactere "CC/" from the model "CC/Passat CC"
df_volkswagen['Model'] = df_volkswagen['Model'].str.replace('CC/Passat CC', 'Passat CC', regex=True)
# Out:
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_8692\2533734767.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_volkswagen['Model'] = df_volkswagen['Model'].str.replace('CC/Passat CC', 'Passat CC', regex=True)
