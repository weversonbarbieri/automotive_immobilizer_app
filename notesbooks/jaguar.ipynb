# %%
import pandas as pd

# %%
# Import all data from the main notebook (Immo_Assistant.app)
# %run Immo_Assistant.app.ipynb
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_18872\507487594.py:2: SyntaxWarning: invalid escape sequence '\L'
#   df = pd.read_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\data\year_make_model_df.xlsx')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3463 entries, 0 to 3462
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            3463 non-null   int64
#  1   Make            3463 non-null   object
#  2   Model           3463 non-null   string
#  3   Security        3156 non-null   object
#  4   ParameterReset  938 non-null    object
# dtypes: int64(1), object(3), string(1)
# memory usage: 135.4+ KB
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# ...

# %%
# Print the check list to see what is the next dataframe needs to be created
print(make_to_be_done)
# Out:
# ['Pontiac', 'Mazda', 'Acura', 'Honda', 'BMW', 'Lexus', 'Toyota', 'Chrysler', 'Dodge', 'Infiniti', 'Jaguar', 'Lincoln', 'Nissan', 'Plymouth', 'Jeep', 'Audi', 'Mitsubishi', 'Volkswagen', 'Land Rover', 'Mini', 'Rolls-Royce', 'Scion', 'Subaru', 'Fiat']

# %%
# Next make Jaguar to create the df
df_jaguar = create_make_df('Jaguar')

# %%
# Check the df to see it is
df_jaguar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 71 entries, 259 to 3308
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            71 non-null     int64
#  1   Make            71 non-null     object
#  2   Model           71 non-null     string
#  3   Security        65 non-null     object
#  4   ParameterReset  55 non-null     object
# dtypes: int64(1), object(3), string(1)
# memory usage: 3.3+ KB

# %%
# Create a list w/ values/strings from the column 'Model'
jaguar_model_list = strings_from_column(df_jaguar, 'Model')

# %%
# Print the list
print(jaguar_model_list)
# Out:
# {'S TYPE (All)', 'XK', 'XF', 'XJ', 'X TYPE', 'XK8', 'XJ8', 'S-Type'}

# %% [markdown]
# No changes needed on models from column 'Model'

# %%
# Create a list w/ values/strings from the column 'Security'
jaguar_security_list = strings_from_column(df_jaguar, 'Security')

# %%
# Print the list
print(jaguar_security_list)
# Out:
# {nan, 'No longer FNA', 'Std', 'Std on all'}

# %%
# Fill out null values
df_jaguar['Security'].fillna('Information not available', inplace=True)
# Out:
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_18872\3769090000.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_jaguar['Security'].fillna('Information not available', inplace=True)
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_18872\3769090000.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
# Create a list w/ values/strings from the column 'ParameterReset'
jaguar_pr_list = strings_from_column(df_jaguar, 'ParameterReset')

# %%
# Print the list
jaguar_pr_list
# Out:
# {'Indicates encryption technology was used', 'Std = Standard Equipment', nan}

# %%
# Rename column 'ParameterReset' to 'Security System Additional Information'
df_jaguar_updated = df_jaguar.rename(columns={'ParameterReset': 'Jaguar Security System Additional Information'})

# %%
# Fill out null values in column 'Security System Additional Information'
df_jaguar_updated['Jaguar Security System Additional Information'].fillna('Information not available', inplace=True)
# Out:
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_18872\1583802232.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_jaguar_updated['Jaguar Security System Additional Information'].fillna('Information not available', inplace=True)

# %%
df_jaguar_updated.columns
# Out:
# Index(['Year', 'Make', 'Model', 'Security',
#        'Jaguar Security System Additional Information'],
#       dtype='object')

# %%
# Download the scion df to .pkl file format
df_jaguar_up_to_dated.to_excel('df_jaguar_up_to_dated.xlsx')
