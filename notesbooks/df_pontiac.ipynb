# %%
import pandas as pd

# %%
# Import all data from the main notebook
# %run Immo_Assistant.app.ipynb
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_23448\507487594.py:2: SyntaxWarning: invalid escape sequence '\L'
#   df = pd.read_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\data\year_make_model_df.xlsx')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3463 entries, 0 to 3462
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            3463 non-null   int64
#  1   Make            3463 non-null   object
#  2   Model           3463 non-null   string
#  3   Security        3156 non-null   object
#  4   ParameterReset  938 non-null    object
# dtypes: int64(1), object(3), string(1)
# memory usage: 135.4+ KB
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# ...

# %%
# Create a dataframe only with Make: Pontiac
df_pontiac = df_chevrolet_renamed_column[df_chevrolet_renamed_column['Make'] == 'Pontiac']

# %%
# Check is the df is ok
df_pontiac.tail()
# Out:
#      Year     Make     Model             Security       Hardware Part Number  \
# 514  2009  Pontiac      Vibe  Toyota\nImmobilizer  Information not available
# 554  2010  Pontiac        G3                  Opt  Information not available
# 555  2010  Pontiac        G6                 PK3+  Information not available
# 556  2010  Pontiac        G8                 PK3+  Information not available
# 557  2010  Pontiac  Solstice                 PK3+  Information not available
#
#     Is this hardware clonable?
# 514                         No
# 554                         No
# 555                         No
# 556                         No
# 557                         No

# %%
# Create a list with all the models of Pontiac
pontiac_models_list = strings_from_column(df_pontiac, 'Model')

# %%
# Check the list
pontiac_models_list
# Out:
# {'Aztek',
#  'Bonneville',
#  'Firebird',
#  'G3',
#  'G5',
#  'G6',
#  'G8',
#  'GTO',
#  'Grand Am',
#  'Montana',
#  'Montana SV6',
#  'Solstice',
#  'Sunfire',
#  'Torrent',
#  'Vibe'}

# %% [markdown]
# No changes are needed on the Pontiac models.

# %%
# Create a list with all the elements from column 'Security'
pontiac_security_column_list = strings_from_column(df_pontiac, 'Security')

# %%
# Check the list
pontiac_security_column_list
# Out:
# {'GTA\nonly',
#  'Holden',
#  'Opt',
#  'PK1',
#  'PK2',
#  'PK3',
#  'PK3+',
#  'PL1',
#  'PL1 (GT\nonly*)',
#  'Toyota\nImmobilizer',
#  nan}

# %% [markdown]
# CHANGES NEEDED:
# - Replace charactere '\n' for space ' '.
# - Replace null values for the string 'Information not available'.

# %%
# Replace the charactere '\n' by space ' '
df_pontiac['Security'] = df_pontiac['Security'].str.replace('\n', ' ', regex=True)
# Out:
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_23448\3855990983.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pontiac['Security'] = df_pontiac['Security'].str.replace('\n', ' ', regex=True)

# %%
# Fill out null values
df_pontiac['Security'].fillna('Information not available', inplace=True)
# Out:
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_23448\3020168956.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_pontiac['Security'].fillna('Information not available', inplace=True)
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_23448\3020168956.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
# Reset the index
df_pontiac.reset_index(drop=True)
# Out:
#     Year     Make        Model                   Security  \
# 0   1988  Pontiac     Firebird                   GTA only
# 1   1989  Pontiac     Firebird                        PK1
# 2   1990  Pontiac     Firebird                        PK1
# 3   1991  Pontiac     Firebird                        PK1
# 4   1992  Pontiac     Firebird                        PK1
# 5   1992  Pontiac   Bonneville                        PK2
# 6   1993  Pontiac   Bonneville                        PK2
# 7   1993  Pontiac     Firebird                        PK2
# 8   1994  Pontiac   Bonneville                        PK2
# 9   1994  Pontiac     Firebird                        PK2
# 10  1994  Pontiac     Grand Am                        PK2
# 11  1995  Pontiac   Bonneville                        PK2
# 12  1995  Pontiac     Firebird                        PK2
# 13  1995  Pontiac     Grand Am                        PK2
# 14  1995  Pontiac      Sunfire             PL1 (GT only*)
# ...

# %%
# Download the scion df to .pkl file format
df_pontiac.to_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\dataframe_each_make_xlsx_file\df_pontiac.xlsx')
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\L'
# <>:2: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_23448\3577650362.py:2: SyntaxWarning: invalid escape sequence '\L'
#   df_pontiac.to_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\dataframe_each_make_xlsx_file\df_pontiac.xlsx')
