# %%
import pandas as pd

# %%
# %run Immo_Assistant.app.ipynb
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_8108\507487594.py:2: SyntaxWarning: invalid escape sequence '\L'
#   df = pd.read_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\data\year_make_model_df.xlsx')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3463 entries, 0 to 3462
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            3463 non-null   int64
#  1   Make            3463 non-null   object
#  2   Model           3463 non-null   string
#  3   Security        3156 non-null   object
#  4   ParameterReset  938 non-null    object
# dtypes: int64(1), object(3), string(1)
# memory usage: 135.4+ KB
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# ...

# %%
# Print the check list to see what is the next dataframe needs to be created
print(make_to_be_done)
# Out:
# ['Pontiac', 'Mazda', 'Acura', 'Honda', 'BMW', 'Lexus', 'Toyota', 'Chrysler', 'Dodge', 'Infiniti', 'Jaguar', 'Lincoln', 'Nissan', 'Plymouth', 'Jeep', 'Audi', 'Mitsubishi', 'Volkswagen', 'Land Rover', 'Mini', 'Rolls-Royce', 'Scion', 'Subaru', 'Fiat']

# %%
# Create Rolls-Royce dataframe
df_rolls_royce = create_make_df('Rolls-Royce')

# %%
# Check how the df is
df_rolls_royce.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 1326 to 3374
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            4 non-null      int64
#  1   Make            4 non-null      object
#  2   Model           4 non-null      string
#  3   Security        4 non-null      object
#  4   ParameterReset  2 non-null      object
# dtypes: int64(1), object(3), string(1)
# memory usage: 192.0+ bytes

# %%
# Create a list w/ all strings/values from column model
rolls_royce_model_list = strings_from_column(df_rolls_royce, 'Model')

# %%
# Print the list
rolls_royce_model_list
# Out:
# {'Ghost', 'Phantom'}

# %% [markdown]
# No changes are needed in the Model column as all models are correct described.

# %%
# Create a list w/ all strings/values from column security
rolls_royce_security_list = strings_from_column(df_rolls_royce, 'Security')

# %%
# Print the list
rolls_royce_security_list
# Out:
# {'Std'}

# %% [markdown]
# No changes needed in the Security column as all rows has the value/string 'Std'

# %%
# Create a list w/ all strings/values from column ParameterReset
rolls_royce_pr_list = strings_from_column(df_rolls_royce, 'ParameterReset')

# %%
# Print the list
rolls_royce_pr_list
# Out:
# {'EWS III', nan}

# %% [markdown]
# CHANGES NEEDED:
# - Fill out null values.
# - Rename the column name from ParameterReset to 'Rolls-Royce Security System Additional Information'

# %%
# Fill out null values
df_rolls_royce['ParameterReset'].fillna('Information not available', inplace=True)
# Out:
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_8108\2845690521.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_rolls_royce['ParameterReset'].fillna('Information not available', inplace=True)
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_8108\2845690521.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
# Rename the column name from ParameterReset to 'Rolls-Royce Security System Additional Information'
df_rolls_royce_rename_column = df_rolls_royce.rename(columns={'ParameterReset': 'Rolls-Royce Security System Additional Information'})

# %%
df_rolls_royce_rename_column.columns
# Out:
# Index(['Year', 'Make', 'Model', 'Security',
#        'Rolls-Royce Security System Additional Information'],
#       dtype='object')

# %%
# Save the df to pickle file
df_rolls_royce_updated = df_rolls_royce_rename_column.to_excel('df_rolls_royce_updated.xlsx')
