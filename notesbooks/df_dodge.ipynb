# %%
import pandas as pd

# %%
# %run Immo_Assistant.app.ipynb
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_21652\507487594.py:2: SyntaxWarning: invalid escape sequence '\L'
#   df = pd.read_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\data\year_make_model_df.xlsx')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3463 entries, 0 to 3462
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            3463 non-null   int64
#  1   Make            3463 non-null   object
#  2   Model           3463 non-null   string
#  3   Security        3156 non-null   object
#  4   ParameterReset  938 non-null    object
# dtypes: int64(1), object(3), string(1)
# memory usage: 135.4+ KB
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# Built February 1st or earlier: PATS Type A (Stand Alone PATS Module)
# Built February 2nd or later: PATS Type E (Powertrain Control Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type E (Powertrain Control Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type C (Instrument Cluster)
# PATS Type B (Stand Alone PATS Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type B (Stand Alone PATS Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type C (Instrument Cluster)
# PATS Type B (Stand Alone PATS Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type B (Stand Alone PATS Module)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type B (Stand Alone PATS Module)
# PATS Type E (Powertrain Control Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type C (Instrument Cluster)
# PATS Type B (Stand Alone PATS Module)
# Built July 23rd 2000 or Earlier: PATS Type B (Stand Alone PATS Module)
# Built July 24th 2000 or Later: PATS Type E (Powertrain Control Module)
# Built July 23rd 2000 or Earlier: PATS Type B (Stand Alone PATS Module)
# Built July 24th 2000 or Later: PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type E (Powertrain Control Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type E (Powertrain Control Module)
# PATS Type NA (No PATS)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type F (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type B (Stand Alone PATS Module)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type A (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type F (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type G (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type A (Instrument Cluster)
# Fleet Vehicles: PATS Type G (Instrument Cluster)
# Non-Fleet Vehicles: PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type G (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type G (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type A (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# Fleet Vehicles: PATS Type G (Instrument Cluster)
# Non-Fleet Vehicles: PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type G (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type G (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type A (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# Fleet Vehicles: PATS Type G (Instrument Cluster)
# Non-Fleet Vehicles: PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type G (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type G (Instrument Cluster)
# Keyed Ignition: PATS Type C (Instrument Cluster)
# Push To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type A (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type B (Body Control Module)
# PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type A (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type B (Body Control Module)
# PATS Type B (Body Control Module)
# PATS Type B (Body Control Module)
# Keyed Ignition: PATS Type A (Instrument Cluster)
# Push To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# Keyed Ignition: PATS Type C (Instrument Cluster)
# Push To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type A (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type B (Body Control Module)
# PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type A (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type B (Body Control Module)
# PATS Type B (Body Control Module)
# PATS Type B (Body Control Module)
# Keyed Ignition: PATS Type A (Instrument Cluster)
# Push To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type C (Instrument Cluster)
# Keyed Ignition: PATS Type C (Instrument Cluster)
# Push To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# Keyed Ignition: PATS Type C (Instrument Cluster)
# Push To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type A (Instrument Cluster)
# PATS Type B (Body Control Module)
# PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type B (Body Control Module)
# PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type B (Body Control Module)
# PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type A (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type B (Body Control Module)
# PATS Type B (Body Control Module)
# PATS Type B (Body Control Module)
# Keyed Ignition: PATS Type A (Instrument Cluster)
# Push To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type B (Body Control Module)
# PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# Keyed Ignition: PATS Type C (Instrument Cluster)
# Push To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type B (Body Control Module)
# PATS Type B (Body Control Module)
# PATS Type B (Body Control Module)
# PATS Type C (Instrument Cluster)
# Keyed Ignition: PATS Type C (Instrument Cluster)
# Push To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type A (Instrument Cluster)
# PATS Type B (Body Control Module)
# Stand Alone PATS Module)
# Built February 2nd or later: PATS Type E (Powertrain Control Module
# Year                                                                                                               2001
# Make                                                                                                               Ford
# Model                                                                                              Explorer Sport (2dr)
# ParameterReset                                                                                 Parameter Reset Required
# PATS Type                                                                 Built July 23rd 2000 or Earlier: PATS Type B
# PATS Module Location    Stand Alone PATS Module)\nBuilt July 24th 2000 or Later: PATS Type E (Powertrain Control Module
# Name: 705, dtype: object
# Year                                                                                                               2001
# Make                                                                                                               Ford
# Model                                                                                               Explorer Sport Trac
# ParameterReset                                                                                 Parameter Reset Required
# PATS Type                                                                 Built July 23rd 2000 or Earlier: PATS Type B
# PATS Module Location    Stand Alone PATS Module)\nBuilt July 24th 2000 or Later: PATS Type E (Powertrain Control Module
# Name: 706, dtype: object
# Year                                                                                        2008
# Make                                                                                        Ford
# Model                                                                                   E-Series
# ParameterReset                                                          Parameter Reset Required
# PATS Type                                                           Fleet Vehicles: PATS Type G
# PATS Module Location    Instrument Cluster)\nNon-Fleet Vehicles: PATS Type C (Instrument Cluster
# Name: 2069, dtype: object
# Year                                                                                        2009
# Make                                                                                        Ford
# Model                                                                                   E-Series
# ParameterReset                                                          Parameter Reset Required
# PATS Type                                                           Fleet Vehicles: PATS Type G
# PATS Module Location    Instrument Cluster)\nNon-Fleet Vehicles: PATS Type C (Instrument Cluster
# Name: 2316, dtype: object
# Year                                                                                        2010
# Make                                                                                        Ford
# Model                                                                                   E-Series
# ParameterReset                                                          Parameter Reset Required
# PATS Type                                                           Fleet Vehicles: PATS Type G
# PATS Module Location    Instrument Cluster)\nNon-Fleet Vehicles: PATS Type C (Instrument Cluster
# Name: 2563, dtype: object
# Year                                                                                                                  2010
# Make                                                                                                                  Ford
# Model                                                                                                               Taurus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 2576, dtype: object
# Year                                                                                                                  2011
# Make                                                                                                                  Ford
# Model                                                                                                               FIESTA
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type A
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 2806, dtype: object
# Year                                                                                                                  2011
# Make                                                                                                                  Ford
# Model                                                                                                               Taurus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 2812, dtype: object
# Year                                                                                                                  2012
# Make                                                                                                                  Ford
# Model                                                                                                               FIESTA
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type A
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3038, dtype: object
# Year                                                                                                                  2012
# Make                                                                                                                  Ford
# Model                                                                                                                Focus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3040, dtype: object
# Year                                                                                                                  2012
# Make                                                                                                                  Ford
# Model                                                                                                               Taurus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3045, dtype: object
# Year                                                                                                                  2013
# Make                                                                                                                  Ford
# Model                                                                                                               FIESTA
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type A
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3271, dtype: object
# Year                                                                                                                  2013
# Make                                                                                                                  Ford
# Model                                                                                                                Focus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3274, dtype: object
# Year                                                                                                                  2013
# Make                                                                                                                  Ford
# Model                                                                                                               Taurus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3280, dtype: object
# Year                                                                                                                  2010
# Make                                                                                                                  Ford
# Model                                                                                                               Taurus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 2576, dtype: object
# Year                                                                                                                  2011
# Make                                                                                                                  Ford
# Model                                                                                                               FIESTA
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type A
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 2806, dtype: object
# Year                                                                                                                  2011
# Make                                                                                                                  Ford
# Model                                                                                                               Taurus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 2812, dtype: object
# Year                                                                                                                  2012
# Make                                                                                                                  Ford
# Model                                                                                                               FIESTA
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type A
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3038, dtype: object
# Year                                                                                                                  2012
# Make                                                                                                                  Ford
# Model                                                                                                                Focus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3040, dtype: object
# Year                                                                                                                  2012
# Make                                                                                                                  Ford
# Model                                                                                                               Taurus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3045, dtype: object
# Year                                                                                                                  2013
# Make                                                                                                                  Ford
# Model                                                                                                               FIESTA
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type A
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3271, dtype: object
# Year                                                                                                                  2013
# Make                                                                                                                  Ford
# Model                                                                                                                Focus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3274, dtype: object
# Year                                                                                                                  2013
# Make                                                                                                                  Ford
# Model                                                                                                               Taurus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3280, dtype: object
# Year                                                                                                                  2010
# Make                                                                                                                  Ford
# Model                                                                                                               Taurus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 2576, dtype: object
# Year                                                                                                                  2011
# Make                                                                                                                  Ford
# Model                                                                                                               FIESTA
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type A
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 2806, dtype: object
# Year                                                                                                                  2011
# Make                                                                                                                  Ford
# Model                                                                                                               Taurus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 2812, dtype: object
# Year                                                                                                                  2012
# Make                                                                                                                  Ford
# Model                                                                                                               FIESTA
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type A
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3038, dtype: object
# Year                                                                                                                  2012
# Make                                                                                                                  Ford
# Model                                                                                                                Focus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3040, dtype: object
# Year                                                                                                                  2012
# Make                                                                                                                  Ford
# Model                                                                                                               Taurus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3045, dtype: object
# Year                                                                                                                  2013
# Make                                                                                                                  Ford
# Model                                                                                                               FIESTA
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type A
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3271, dtype: object
# Year                                                                                                                  2013
# Make                                                                                                                  Ford
# Model                                                                                                                Focus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3274, dtype: object
# Year                                                                                                                  2013
# Make                                                                                                                  Ford
# Model                                                                                                               Taurus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3280, dtype: object
# [2576, 2806, 2812, 3038, 3040, 3045, 3271, 3274, 3280]
# Year                                                                                                                  2009
# Make                                                                                                               Lincoln
# Model                                                                                                                  MKS
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 2384, dtype: object
# Year                                                                                                                  2010
# Make                                                                                                               Lincoln
# Model                                                                                                                  MKS
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 2630, dtype: object
# Year                                                                                                                  2011
# Make                                                                                                               Lincoln
# Model                                                                                                                  MKS
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 2862, dtype: object
# Year                                                                                                                  2012
# Make                                                                                                               Lincoln
# Model                                                                                                                  MKS
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3098, dtype: object
# 2384
# 2630
# 2862
# 3098
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_21652\3384685316.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ford[['PATS Type', 'PATS Module Location']] = df_ford['Security'].str.split('(', n=1, expand=True)
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_21652\3384685316.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ford[['PATS Type', 'PATS Module Location']] = df_ford['Security'].str.split('(', n=1, expand=True)
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_21652\370588408.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ford['PATS Module Location'] = df_ford['PATS Module Location'].str.strip(')')
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_21652\2886703368.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lincoln[['PATS Type', 'PATS Module Location']] = df_lincoln['Security'].str.split('(', n=1, expand=True)
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_21652\2886703368.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lincoln[['PATS Type', 'PATS Module Location']] = df_lincoln['Security'].str.split('(', n=1, expand=True)
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_21652\3965777578.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mercury[['PATS Type', 'PATS Module Location']] = df_mercury['Security'].str.split('(', n=1, expand=True)
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_21652\3965777578.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mercury[['PATS Type', 'PATS Module Location']] = df_mercury['Security'].str.split('(', n=1, expand=True)
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_21652\4086986821.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mercury['PATS Module Location'] = df_mercury['PATS Module Location'].str.strip(')')
# <>:2: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_21652\394097893.py:2: SyntaxWarning: invalid escape sequence '\L'
#   df_chevrolet = pd.read_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\data\chevrolet_hardware_list.xlsx')
# <>:2: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_21652\1625161208.py:2: SyntaxWarning: invalid escape sequence '\L'
#   list_clonable_modules = pd.read_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\data\List of Clonable Modules.xlsx')
# Year: 2005
# Make: Cadillac
# Model: CTS
# Security: PK3+
# Hardware Part Number: U44G-G45
# Is this hardware clonable?: No
# <>:3: SyntaxWarning: invalid escape sequence '\L'
# <>:4: SyntaxWarning: invalid escape sequence '\L'
# <>:5: SyntaxWarning: invalid escape sequence '\L'
# <>:6: SyntaxWarning: invalid escape sequence '\L'
# <>:7: SyntaxWarning: invalid escape sequence '\L'
# <>:8: SyntaxWarning: invalid escape sequence '\L'
# <>:9: SyntaxWarning: invalid escape sequence '\L'
# <>:10: SyntaxWarning: invalid escape sequence '\L'
# <>:11: SyntaxWarning: invalid escape sequence '\L'
# <>:12: SyntaxWarning: invalid escape sequence '\L'
# <>:13: SyntaxWarning: invalid escape sequence '\L'
# <>:14: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_21652\3684713339.py:3: SyntaxWarning: invalid escape sequence '\L'
#   df_ford_new.to_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\dataframe_each_make_xlsx_file\df_ford_new.xlsx')
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_21652\3684713339.py:4: SyntaxWarning: invalid escape sequence '\L'
#   df_lincoln_updated.to_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\dataframe_each_make_xlsx_file\df_lincoln_updated.xlsx')
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_21652\3684713339.py:5: SyntaxWarning: invalid escape sequence '\L'
#   df_mercury_updated.to_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\dataframe_each_make_xlsx_file\df_mercury_updated.xlsx')
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_21652\3684713339.py:6: SyntaxWarning: invalid escape sequence '\L'
#   df_mazda_updated.to_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\dataframe_each_make_xlsx_file\df_mazda_updated.xlsx')
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_21652\3684713339.py:7: SyntaxWarning: invalid escape sequence '\L'
#   df_chevy_filtered.to_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\dataframe_each_make_xlsx_file\df_chevy_filtered.xlsx')
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_21652\3684713339.py:8: SyntaxWarning: invalid escape sequence '\L'
#   df_pontiac.to_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\dataframe_each_make_xlsx_file\df_pontiac.xlsx')
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_21652\3684713339.py:9: SyntaxWarning: invalid escape sequence '\L'
#   df_cadillac.to_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\dataframe_each_make_xlsx_file\df_cadillac.xlsx')
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_21652\3684713339.py:10: SyntaxWarning: invalid escape sequence '\L'
#   df_buick.to_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\dataframe_each_make_xlsx_file\df_buick.xlsx')
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_21652\3684713339.py:11: SyntaxWarning: invalid escape sequence '\L'
#   df_oldsmobile.to_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\dataframe_each_make_xlsx_file\df_oldsmobile.xlsx')
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_21652\3684713339.py:12: SyntaxWarning: invalid escape sequence '\L'
#   df_gmc.to_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\dataframe_each_make_xlsx_file\df_gmc.xlsx')
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_21652\3684713339.py:13: SyntaxWarning: invalid escape sequence '\L'
#   df_saturn.to_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\dataframe_each_make_xlsx_file\df_saturn.xlsx')
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_21652\3684713339.py:14: SyntaxWarning: invalid escape sequence '\L'
#   df_hummer.to_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\dataframe_each_make_xlsx_file\df_hummer.xlsx')
# ['Acura', 'Honda', 'BMW', 'Lexus', 'Toyota', 'Chrysler', 'Dodge', 'Infiniti', 'Jaguar', 'Nissan', 'Plymouth', 'Jeep', 'Audi', 'Mitsubishi', 'Volkswagen', 'Land Rover', 'Mini', 'Rolls-Royce', 'Scion', 'Subaru', 'Fiat']
# ['Acura', 'Honda', 'BMW', 'Lexus', 'Toyota', 'Chrysler', 'Dodge', 'Infiniti', 'Jaguar', 'Nissan', 'Plymouth', 'Jeep', 'Audi', 'Mitsubishi', 'Volkswagen', 'Land Rover', 'Mini', 'Rolls-Royce', 'Scion', 'Subaru', 'Fiat']
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_21652\3767471067.py:1: FutureWarning: Passing bytes to 'read_excel' is deprecated and will be removed in a future version. To read from a byte string, wrap it in a `BytesIO` object.
#   pkl_file = pd.read_excel(get_content)

# %%
# Create the dataframe to Dodge
df_dodge = create_make_df('Dodge')

# %%
# Check how the df is
df_dodge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 194 entries, 241 to 3258
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            194 non-null    int64
#  1   Make            194 non-null    object
#  2   Model           194 non-null    string
#  3   Security        149 non-null    object
#  4   ParameterReset  12 non-null     object
# dtypes: int64(1), object(3), string(1)
# memory usage: 9.1+ KB

# %%
# Create a list w/ strings from the column 'Model'
dodge_model_list = strings_from_column(df_dodge, 'Model')

# %%
# Print the list to decide what changes need to be done
print(dodge_model_list)
# Out:
# {'Caravan', 'Charger', 'Dart', 'Challenger', 'Neon', 'Magnum', 'Ram 3500', 'Viper', 'Ram 1500', 'Ram 4500', 'Avenger Sedan', 'Journey', 'Nitro', 'Caliber', 'Stratus sedan', 'Stratus coupe', 'Ram 2500', 'Avenger', 'Ram C/V', 'Ram', 'Intrepid', 'Durango', 'Ram Van', 'Sprinter', 'Ram 5500', 'Dakota'}

# %% [markdown]
# No changes are needed in column 'Model'

# %%
# Create a list w/ strings from the column 'Security'
dodge_security_list = strings_from_column(df_dodge, 'Security')

# %%
# Print the list to decide what changes need to be done
print(dodge_security_list)
# Out:
# {'Opt', 'Std with power\nwindows & power locks', 'Std\nw/o  power windows & power locks', 'Std\nwith power windows & power locks', 'Opt (Std in Canada)', 'Std (Except Base)', 'Std', 'Std\nw/o power windows\n& power locks', nan, 'Std\nw/o  power windows\n& power locks'}

# %% [markdown]
# CHANGES NEEDED:
# - Fill out rows with null values
# - Replace the caractere '\n'

# %%
# Fill out the rows with null values
df_dodge['Security'].fillna('Information not available', inplace=True)
# Out:
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_21652\684934966.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_dodge['Security'].fillna('Information not available', inplace=True)
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_21652\684934966.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dodge['Security'].fillna('Information not available', inplace=True)

# %%
# Replace the caractere '\n' by space ' '
df_dodge['Security'] = df_dodge['Security'].str.replace('\n', ' ', regex=False)
# Out:
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_21652\1023540618.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dodge['Security'] = df_dodge['Security'].str.replace('\n', ' ', regex=False)

# %% [markdown]
# Dodge PCMs do not require a parameter reset, but there are 12 rows w/ strings and before dropping this column, checking the strings to see what they are.

# %%
# Create a list w/ all strings from column 'ParameterReset'
dodge_security_list = strings_from_column(df_dodge, 'ParameterReset')

# %%
# Print the list to see the strings
print(dodge_security_list)
# Out:
# {nan, '“SKREES” Sentry Key Remote Entry System (same as SKIS, the key remote entry module was combined with the Sentry Key Immobilizer Module, it’s still Sentry Key)', 'Sentry Key Immobilizer System = Standard equipment'}

# %% [markdown]
# CHANGES NEEDED at column 'ParameterReset':
# - Rename the column's name to 'Security System Addiotional info'
# - Fill out all null values

# %%
# Fill out all null values
df_dodge['ParameterReset'].fillna('Information not available', inplace=True)
# Out:
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_21652\2262564047.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_dodge['ParameterReset'].fillna('Information not available', inplace=True)
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_21652\2262564047.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dodge['ParameterReset'].fillna('Information not available', inplace=True)

# %%
# Rename the column's name to 'Security System Addiotional info'
df_dodge_updated = df_dodge.rename(columns={'ParameterReset': 'Dodge Security System Addiotional Info'})

# %%
# Reset index
df_dodge_updated.reset_index(drop=True)
# Out:
#      Year   Make          Model                   Security  \
# 0    1997  Dodge        Caravan  Information not available
# 1    1997  Dodge         Dakota  Information not available
# 2    1997  Dodge           Neon  Information not available
# 3    1997  Dodge        Ram Van  Information not available
# 4    1997  Dodge  Stratus sedan  Information not available
# ..    ...    ...            ...                        ...
# 189  2013  Dodge       Ram 3500                        Std
# 190  2013  Dodge       Ram 4500                        Std
# 191  2013  Dodge       Ram 5500                        Std
# 192  2013  Dodge        Ram C/V                        Std
# 193  2013  Dodge          Viper                        Std
#
#     Dodge Security System Addiotional Info
# 0                Information not available
# 1                Information not available
# 2                Information not available
# 3                Information not available
# 4                Information not available
# ..                                     ...
# 189              Information not available
# 190              Information not available
# 191              Information not available
# 192              Information not available
# 193              Information not available
#
# [194 rows x 5 columns]

# %%
# Download the scion df to .pkl file format
df_dodge_updated.to_excel('df_dodge_updated.xlsx')
