# %%
import pandas as pd
import import_ipynb

# %% [markdown]
# As the next dataframes to each make will be created in separate notebooks, importing the data from the main notebook Immo_Assistant.app is needed.

# %%
# Import all data from the main df noebook (Immo_Assistant.app) 
# %run Immo_Assistant.app.ipynb
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_18316\507487594.py:2: SyntaxWarning: invalid escape sequence '\L'
#   df = pd.read_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\data\year_make_model_df.xlsx')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3463 entries, 0 to 3462
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            3463 non-null   int64
#  1   Make            3463 non-null   object
#  2   Model           3463 non-null   string
#  3   Security        3156 non-null   object
#  4   ParameterReset  938 non-null    object
# dtypes: int64(1), object(3), string(1)
# memory usage: 135.4+ KB
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# ...

# %%
# Check the list of makes to confirm the next dataframe to be created
print(make_to_be_done)
# Out:
# ['Pontiac', 'Mazda', 'Acura', 'Honda', 'BMW', 'Lexus', 'Toyota', 'Chrysler', 'Dodge', 'Infiniti', 'Jaguar', 'Lincoln', 'Nissan', 'Plymouth', 'Jeep', 'Audi', 'Mitsubishi', 'Volkswagen', 'Land Rover', 'Mini', 'Rolls-Royce', 'Scion', 'Subaru', 'Fiat']

# %%
# Create Lexus dataframe
df_lexus = create_make_df("Lexus")

# %%
# Check if there are null values
df_lexus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 134 entries, 196 to 3331
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            134 non-null    int64
#  1   Make            134 non-null    object
#  2   Model           134 non-null    string
#  3   Security        125 non-null    object
#  4   ParameterReset  0 non-null      object
# dtypes: int64(1), object(3), string(1)
# memory usage: 6.3+ KB

# %%
# Create a list to show all models and decide if changes need to be done in this column
lexus_model_list = strings_from_column(df_lexus, 'Model')

# %%
# Print the list to be analysed
print(lexus_model_list)
# Out:
# {'GS', 'LFA', 'RX', 'IS/ISF', 'ISF', 'LS', 'SC', 'GX', 'ES', 'IS', 'LX'}

# %% [markdown]
# The list above shows models 'IS/ISF' in the same row for some reason, but they should be splitted in different lines.

# %%
# Separare/split models 'IS/ISF' in  columns
df_lexus = df_lexus.assign(Model=df_lexus['Model'].str.split('/')).explode('Model')

# %%
# Check how the models are after splitting 'IS/ISF' in lines
lexus_model_list = strings_from_column(df_lexus, 'Model')

# %%
# Print the updated list
print(lexus_model_list)
# Out:
# {'GS', 'LFA', 'RX', 'ISF', 'LS', 'SC', 'GX', 'ES', 'IS', 'LX'}

# %%
# Call this function to show all values in column 'Security', analyse the strings and confirm if changes need to be done
lexus_security_string_list = strings_from_column(df_lexus, 'Security')

# %%
# Print the list
print(lexus_security_string_list)
# Out:
# {'Smart\nKey', 'Std', 'Smart Key Std', 'Smart\nKey Std', nan, 'Smart Key'}

# %% [markdown]
# CHANGES NEEDED:
# - Fill the rows with null values 'nan'
# - Remove the caractere '\n'

# %%
# Fill the rows with null values from column 'Security'
df_lexus['Security'].fillna('Information not available', inplace=True)
# Out:
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_18316\1657257667.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_lexus['Security'].fillna('Information not available', inplace=True)

# %%
# Confirm if the rows w/ null values were filled out
df_lexus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 144 entries, 196 to 3331
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            144 non-null    int64
#  1   Make            144 non-null    object
#  2   Model           144 non-null    object
#  3   Security        144 non-null    object
#  4   ParameterReset  0 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 6.8+ KB

# %%
# Remove the caractere '\n'
df_lexus['Security'] = df_lexus['Security'].str.replace("\n", " ", regex=False)

# %%
# Confirm if the above changes were done
lexus_security_string_list = strings_from_column(df_lexus, 'Security')

# %%
# Print the list updated
print(lexus_security_string_list)
# Out:
# {'Std', 'Smart Key Std', 'Information not available', 'Smart Key'}

# %%
# Reset the index
df_lexus = df_lexus.reset_index()

# %%
# Drop columns 'ParameterReset' and 'index' w/ the old indexes
df_lexus_updated = df_lexus.drop(['index', 'ParameterReset'], axis=1)

# %%
# Check the duplicated rows and save them in a new dataframe
lexus_ducplcates_rows = df_lexus_updated[df_lexus_updated.duplicated()]

# %%
# Print the duplicated rows
lexus_ducplcates_rows
# Out:
#      Year   Make Model   Security
# 107  2010  Lexus   ISF  Smart Key
# 120  2011  Lexus   ISF  Smart Key
# 130  2012  Lexus   ISF  Smart Key
# 141  2013  Lexus   ISF  Smart Key

# %%
# Drop the duplicated rows
df_lexus_dropped_duplicates = df_lexus_updated.drop_duplicates()

# %%
# Check if the duplicated rows were dropped
df_lexus_dropped_duplicates.duplicated().sum()
# Out:
# 0

# %%
df_lexus_dropped_duplicates.columns
# Out:
# Index(['Year', 'Make', 'Model', 'Security'], dtype='object')

# %%
# Download the scion df to .pkl file format
df_lexus_dropped_duplicates.to_excel('df_lexus_updated.xlsx')
