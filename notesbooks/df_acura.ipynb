# %%
import pandas as pd

# %%
# %run Immo_Assistant.app.ipynb
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3463 entries, 0 to 3462
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            3463 non-null   int64
#  1   Make            3463 non-null   object
#  2   Model           3463 non-null   string
#  3   Security        3156 non-null   object
#  4   ParameterReset  938 non-null    object
# dtypes: int64(1), object(3), string(1)
# memory usage: 135.4+ KB
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# Built February 1st or earlier: PATS Type A (Stand Alone PATS Module)
# Built February 2nd or later: PATS Type E (Powertrain Control Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type B (Stand Alone PATS Module)
# ...

# %%
# Acura is the next df to be created
df_acura = create_make_df('Acura')

# %%
# Check how the df is
df_acura.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 124 entries, 22 to 3191
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            124 non-null    int64
#  1   Make            124 non-null    object
#  2   Model           124 non-null    string
#  3   Security        90 non-null     object
#  4   ParameterReset  0 non-null      object
# dtypes: int64(1), object(3), string(1)
# memory usage: 5.8+ KB

# %%
# Create a list with strings/values from column Model
acura_model_list = strings_from_column(df_acura, 'Model')

# %%
# Print the list
acura_model_list
# Out:
# {'CL',
#  'ILX',
#  'Integra',
#  'Legend',
#  'MDX',
#  'NSX',
#  'NV',
#  'RDX',
#  'RL',
#  'RSX',
#  'SLX (Isuzu)',
#  'TL',
#  'TSX',
#  'Vigor',
#  'ZDX'}

# %% [markdown]
# No changes are needed as all models are correct.

# %%
# Create a list with strings/values from column Security
acura_security_list = strings_from_column(df_acura, 'Security')

# %%
# Print the list
acura_security_list
# Out:
# {'Opt with\nPower package, SV Std',
#  'S=Opt with Power\npackage, SV Std\nNV200 Std',
#  'Std',
#  'Std*',
#  nan}

# %% [markdown]
# CHANGES NEEDED:
# - Remove/replace the charactere '\n' for space ' '
# - Fill out null values.

# %%
# Remove/replace the charactere '\n' for space ' '
df_acura['Security'] = df_acura['Security'].str.replace('\n', ' ', regex=False)
# Out:
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_13412\3527984921.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_acura['Security'] = df_acura['Security'].str.replace('\n', ' ', regex=False)

# %%
# Fill out null values
df_acura['Security'].fillna('Information not available', inplace=True)
# Out:
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_13412\3135954917.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_acura['Security'].fillna('Information not available', inplace=True)

# %%
# Drop column ParameterReset
df_acura_dropped_column = df_acura.drop(columns=['ParameterReset'])

# %%
# Reset index
df_acura_updated = df_acura_dropped_column.reset_index(drop=True)

# %%
# Download the scion df to .pkl file format
df_acura_updated.to_pickle('df_acura_updated.pkl')
