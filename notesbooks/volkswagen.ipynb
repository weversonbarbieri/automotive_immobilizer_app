# %%
import pandas as pd

# %%
# %run Immo_Assistant.app.ipynb
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_17632\507487594.py:2: SyntaxWarning: invalid escape sequence '\L'
#   df = pd.read_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\data\year_make_model_df.xlsx')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3463 entries, 0 to 3462
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            3463 non-null   int64
#  1   Make            3463 non-null   object
#  2   Model           3463 non-null   string
#  3   Security        3156 non-null   object
#  4   ParameterReset  938 non-null    object
# dtypes: int64(1), object(3), string(1)
# memory usage: 135.4+ KB
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# ...

# %%
# Print the check list to confirm the next df should be created
print(make_to_be_done)
# Out:
# ['Pontiac', 'Mazda', 'Acura', 'Honda', 'BMW', 'Lexus', 'Toyota', 'Chrysler', 'Dodge', 'Infiniti', 'Jaguar', 'Lincoln', 'Nissan', 'Plymouth', 'Jeep', 'Audi', 'Mitsubishi', 'Volkswagen', 'Land Rover', 'Mini', 'Rolls-Royce', 'Scion', 'Subaru', 'Fiat']

# %%
# Volkswagen is the next df to be created
df_vw = create_make_df('Volkswagen')

# %%
# Check how the df is
df_vw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 135 entries, 644 to 3419
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            135 non-null    int64
#  1   Make            135 non-null    object
#  2   Model           135 non-null    string
#  3   Security        133 non-null    object
#  4   ParameterReset  0 non-null      object
# dtypes: int64(1), object(3), string(1)
# memory usage: 6.3+ KB

# %%
# Create a list w/ strings/values from column model
volkswagen_model_list = strings_from_column(df_vw, 'Model')

# %%
# Print the list
volkswagen_model_list
# Out:
# {'CC/Passat CC',
#  'Cabrio',
#  'City Golf Mk4.5',
#  'City Jetta Mk4.5',
#  'Eos',
#  'Euro Van',
#  'GTI',
#  'Golf A5',
#  'Golf City Mk4.5',
#  'Golf Mk4',
#  'Jetta (NF)',
#  'Jetta A5',
#  'Jetta City Mk4.5',
#  'Jetta Mk4',
#  'New Beetle',
#  'Passat “NMS”',
#  'Phaeton',
#  'R32',
#  'Rabbit',
#  'Routan',
#  'Tiguan',
#  'Touareg'}

# %% [markdown]
# CHANGES NEEDED:
# - Remove the charactere "CC/" from the model "CC/Passat CC"

# %%
# Remove the charactere "CC/" from the model "CC/Passat CC"
df_vw['Model'] = df_vw['Model'].str.replace('CC/Passat CC', 'Passat CC', regex=True)
# Out:
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_17632\2122471330.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_vw['Model'] = df_vw['Model'].str.replace('CC/Passat CC', 'Passat CC', regex=True)

# %%
# Create a list with strings/values from column security
vw_security_list = strings_from_column(df_vw, 'Security')

# %%
# Print the list
vw_security_list
# Out:
# {'Gen II',
#  'Gen III',
#  'Gen III\nor IV',
#  'Gen III or IV',
#  'Gen IV',
#  'Gen IV/ Gen\nV**',
#  'Gen V',
#  'WIN',
#  nan}

# %% [markdown]
# CHANGES NEEDED:
# - Remove/replace the charactere '\n' for space ' '
# - Fill out null values.

# %%
# Remove/replace the charactere '\n' for space ' '
df_vw['Security'] = df_vw['Security'].str.replace('\n', ' ', regex=False)
# Out:
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_17632\3086187480.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_vw['Security'] = df_vw['Security'].str.replace('\n', ' ', regex=False)

# %%
# Fill out null values
df_vw['Security'].fillna('Information not available', inplace=True)
# Out:
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_17632\3372342053.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_vw['Security'].fillna('Information not available', inplace=True)
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_17632\3372342053.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
# Create a list w/ strings/values from column security after updating
vw_security_list_updated = strings_from_column(df_vw, 'Security')

# %%
# Print the list
vw_security_list_updated
# Out:
# {'Gen II',
#  'Gen III',
#  'Gen III or IV',
#  'Gen IV',
#  'Gen IV/ Gen V**',
#  'Gen V',
#  'Information not available',
#  'WIN'}

# %%
# Drop the column ParameterReset
df_vw_dropped_column = df_vw.drop(columns=['ParameterReset'])

# %%
df_vw_dropped_column.columns
# Out:
# Index(['Year', 'Make', 'Model', 'Security'], dtype='object')

# %%
# Download the scion df to .pkl file format
df_vw_updated.to_excel('df_vw_updated.xlsx')
