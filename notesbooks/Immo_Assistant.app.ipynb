# %%
import pandas as pd

# %%
# Read the DataFrame and save it in the variable df.
df = pd.read_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\data\year_make_model_df.xlsx')
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\L'
# <>:2: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_28448\507487594.py:2: SyntaxWarning: invalid escape sequence '\L'
#   df = pd.read_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\data\year_make_model_df.xlsx')

# %%
# Converting all values in column Model to string, as some of models are numbers, for instance BMWs 318, 328, 525
df = df.astype({'Model':'string'})

# %%
# Confirm if the Dtype from the column Model changed to string.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3463 entries, 0 to 3462
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            3463 non-null   int64
#  1   Make            3463 non-null   object
#  2   Model           3463 non-null   object
#  3   Security        3156 non-null   object
#  4   ParameterReset  938 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 135.4+ KB

# %%
# Check which models the df has and print only the unique values
models = df['Model'].unique()

# %%
# Filter only Ford models and create a df.
df_ford = df[df['Make'] == 'Ford']

# %%
# Iterate on column 'Security' to verify all
for security_info in df_ford['Security']:
    print(security_info)
# Out:
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# Built February 1st or earlier: PATS Type A (Stand Alone PATS Module)
# Built February 2nd or later: PATS Type E (Powertrain Control Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type E (Powertrain Control Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type C (Instrument Cluster)
# PATS Type B (Stand Alone PATS Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type B (Stand Alone PATS Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type C (Instrument Cluster)
# PATS Type B (Stand Alone PATS Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type B (Stand Alone PATS Module)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type B (Stand Alone PATS Module)
# PATS Type E (Powertrain Control Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type C (Instrument Cluster)
# PATS Type B (Stand Alone PATS Module)
# Built July 23rd 2000 or Earlier: PATS Type B (Stand Alone PATS Module)
# Built July 24th 2000 or Later: PATS Type E (Powertrain Control Module)
# Built July 23rd 2000 or Earlier: PATS Type B (Stand Alone PATS Module)
# Built July 24th 2000 or Later: PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type E (Powertrain Control Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type B (Stand Alone PATS Module)
# PATS Type E (Powertrain Control Module)
# PATS Type NA (No PATS)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type F (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type B (Stand Alone PATS Module)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type A (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type F (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type G (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type A (Instrument Cluster)
# Fleet Vehicles: PATS Type G (Instrument Cluster)
# Non-Fleet Vehicles: PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type E (Powertrain Control Module)
# PATS Type G (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type G (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type A (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# Fleet Vehicles: PATS Type G (Instrument Cluster)
# Non-Fleet Vehicles: PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type G (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type G (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type A (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# Fleet Vehicles: PATS Type G (Instrument Cluster)
# Non-Fleet Vehicles: PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type G (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type G (Instrument Cluster)
# Keyed Ignition: PATS Type C (Instrument Cluster)
# Push To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type A (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type B (Body Control Module)
# PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type A (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type B (Body Control Module)
# PATS Type B (Body Control Module)
# PATS Type B (Body Control Module)
# Keyed Ignition: PATS Type A (Instrument Cluster)
# Push To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# Keyed Ignition: PATS Type C (Instrument Cluster)
# Push To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type A (Instrument Cluster)
# PATS Type E (Powertrain Control Module)
# PATS Type B (Body Control Module)
# PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type A (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type B (Body Control Module)
# PATS Type B (Body Control Module)
# PATS Type B (Body Control Module)
# Keyed Ignition: PATS Type A (Instrument Cluster)
# Push To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type C (Instrument Cluster)
# Keyed Ignition: PATS Type C (Instrument Cluster)
# Push To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# Keyed Ignition: PATS Type C (Instrument Cluster)
# Push To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type A (Instrument Cluster)
# PATS Type B (Body Control Module)
# PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type B (Body Control Module)
# PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type B (Body Control Module)
# PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type A (Instrument Cluster)
# PATS Type C (Instrument Cluster)
# PATS Type B (Body Control Module)
# PATS Type B (Body Control Module)
# PATS Type B (Body Control Module)
# Keyed Ignition: PATS Type A (Instrument Cluster)
# Push To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type B (Body Control Module)
# PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# Keyed Ignition: PATS Type C (Instrument Cluster)
# Push To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type B (Body Control Module)
# PATS Type B (Body Control Module)
# PATS Type B (Body Control Module)
# PATS Type C (Instrument Cluster)
# Keyed Ignition: PATS Type C (Instrument Cluster)
# Push To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module)
# PATS Type A (Instrument Cluster)
# PATS Type B (Body Control Module)

# %%
# Split column 'Security' between 2 columns, where one column shows the PATS Type and the other one shows the PATS module location
df_ford[['PATS Type', 'PATS Module Location']] = df_ford['Security'].str.split('(', n=1, expand=True)
# Out:
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_28448\3384685316.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ford[['PATS Type', 'PATS Module Location']] = df_ford['Security'].str.split('(', n=1, expand=True)
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_28448\3384685316.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ford[['PATS Type', 'PATS Module Location']] = df_ford['Security'].str.split('(', n=1, expand=True)

# %%
# Remove the ')' that remained at the values of the column 'PATS Module Location'
df_ford['PATS Module Location'] = df_ford['PATS Module Location'].str.strip(')')
# Out:
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_28448\370588408.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ford['PATS Module Location'] = df_ford['PATS Module Location'].str.strip(')')

# %%
# Drop column security as its values were split in 2 columns
df_ford.drop(columns=['Security'])
# Out:
#       Year  Make                        Model                ParameterReset  \
# 190   1996  Ford                      Mustang  Parameter Reset Not Required
# 191   1996  Ford  Taurus (Duratec & SHO only)  Parameter Reset Not Required
# 247   1997  Ford                   Expedition  Parameter Reset Not Required
# 248   1997  Ford                      Mustang  Parameter Reset Not Required
# 249   1997  Ford  Taurus (Duratec & SHO only)  Parameter Reset Not Required
# ...    ...   ...                          ...                           ...
# 3278  2013  Ford                    FUSION EV      Parameter Reset Required
# 3279  2013  Ford                      Mustang      Parameter Reset Required
# 3280  2013  Ford                       Taurus      Parameter Reset Required
# 3281  2013  Ford              TRANSIT CONNECT      Parameter Reset Required
# 3282  2013  Ford                      TRANSIT      Parameter Reset Required
#
#                          PATS Type  \
# 190                   PATS Type A
# 191                   PATS Type A
# 247                   PATS Type A
# 248                   PATS Type A
# 249                   PATS Type A
# ...                            ...
# 3278                  PATS Type B
# 3279                  PATS Type C
# 3280  Keyed Ignition: PATS Type C
# 3281                  PATS Type A
# 3282                  PATS Type B
#
#                                    PATS Module Location
# 190                             Stand Alone PATS Module
# 191                             Stand Alone PATS Module
# 247                             Stand Alone PATS Module
# 248                             Stand Alone PATS Module
# 249                             Stand Alone PATS Module
# ...                                                 ...
# 3278                                Body Control Module
# 3279                                 Instrument Cluster
# 3280  Instrument Cluster)\nPush To Start: PATS Type ...
# 3281                                 Instrument Cluster
# 3282                                Body Control Module
#
# [264 rows x 6 columns]

# %%
# Filter the models that has strings more than the PATS Type included in the row and drop column 'Security'
contour_info = df_ford[df_ford['Model'] == 'Contour (V6-only)'].drop(columns=['Security'])
contour_info_1998 = contour_info[contour_info['Year'] == 1998]

# %%
# Iterate in the PATS Module Location column of the Contour model to verify all strings available
for info in contour_info_1998['PATS Module Location']:
    print(info)
# Out:
# Stand Alone PATS Module)
# Built February 2nd or later: PATS Type E (Powertrain Control Module

# %%
# Duplicate line '1998 Contour (V6-only)' between 2: 1998 Contour (V6-only) / Built >= February 2st and 1998 Contour (V6-only) / Built <= February 1st
contour_new1 = pd.DataFrame({'Year': [1998, 1998], 'Make': ['Ford', 'Ford'], 'Model': ['Contour (V6-only) / Built >= February 2st', 'Contour (V6-only) / Built <= February 1st'], 
                             'ParameterReset': ['Parameter Reset Not Required', 'Parameter Reset Not Required'], 'PATS Type': ['PATS Type E', 'PATS Type A'], 
                             'PATS Module Location': ['Powertrain Control Module', 'Powertrain Control Module']})

# %%
# Print the lines
contour_new1
# Out:
#    Year  Make                                      Model  \
# 0  1998  Ford  Contour (V6-only) / Built >= February 2st
# 1  1998  Ford  Contour (V6-only) / Built <= February 1st
#
#                  ParameterReset    PATS Type       PATS Module Location
# 0  Parameter Reset Not Required  PATS Type E  Powertrain Control Module
# 1  Parameter Reset Not Required  PATS Type A  Powertrain Control Module

# %%
# Concatenate the new 2 lines to the main df and drop 'Security' column drop the old 1998 Contour (V6-only) line (index 325) and 
# store the updated df_ford into a new variable.
df_ford_new = pd.concat([df_ford, contour_new1]).drop(columns=['Security']).drop([325])
df_ford_new
# Out:
#       Year  Make                                      Model  \
# 190   1996  Ford                                    Mustang
# 191   1996  Ford                Taurus (Duratec & SHO only)
# 247   1997  Ford                                 Expedition
# 248   1997  Ford                                    Mustang
# 249   1997  Ford                Taurus (Duratec & SHO only)
# ...    ...   ...                                        ...
# 3280  2013  Ford                                     Taurus
# 3281  2013  Ford                            TRANSIT CONNECT
# 3282  2013  Ford                                    TRANSIT
# 0     1998  Ford  Contour (V6-only) / Built >= February 2st
# 1     1998  Ford  Contour (V6-only) / Built <= February 1st
#
#                     ParameterReset                     PATS Type  \
# 190   Parameter Reset Not Required                  PATS Type A
# 191   Parameter Reset Not Required                  PATS Type A
# 247   Parameter Reset Not Required                  PATS Type A
# 248   Parameter Reset Not Required                  PATS Type A
# 249   Parameter Reset Not Required                  PATS Type A
# ...                            ...                           ...
# 3280      Parameter Reset Required  Keyed Ignition: PATS Type C
# 3281      Parameter Reset Required                  PATS Type A
# 3282      Parameter Reset Required                  PATS Type B
# 0     Parameter Reset Not Required                   PATS Type E
# 1     Parameter Reset Not Required                   PATS Type A
#
#                                    PATS Module Location
# 190                             Stand Alone PATS Module
# 191                             Stand Alone PATS Module
# 247                             Stand Alone PATS Module
# 248                             Stand Alone PATS Module
# 249                             Stand Alone PATS Module
# ...                                                 ...
# 3280  Instrument Cluster)\nPush To Start: PATS Type ...
# 3281                                 Instrument Cluster
# 3282                                Body Control Module
# 0                             Powertrain Control Module
# 1                             Powertrain Control Module
#
# [265 rows x 6 columns]

# %%
# Show the entire information the column contains
pd.set_option('display.max_colwidth', None)
# Iterate in the columns 'PATS Type' and 'PATS Module Location' and find the string 'Built'
for index, row in df_ford_new.iterrows():
    if 'Built' in row['PATS Type'] or 'Built' in row['PATS Module Location']:
        print(row)
# Out:
# Year                                                                                                               2001
# Make                                                                                                               Ford
# Model                                                                                              Explorer Sport (2dr)
# ParameterReset                                                                                 Parameter Reset Required
# PATS Type                                                                 Built July 23rd 2000 or Earlier: PATS Type B
# PATS Module Location    Stand Alone PATS Module)\nBuilt July 24th 2000 or Later: PATS Type E (Powertrain Control Module
# Name: 705, dtype: object
# Year                                                                                                               2001
# Make                                                                                                               Ford
# Model                                                                                               Explorer Sport Trac
# ParameterReset                                                                                 Parameter Reset Required
# PATS Type                                                                 Built July 23rd 2000 or Earlier: PATS Type B
# PATS Module Location    Stand Alone PATS Module)\nBuilt July 24th 2000 or Later: PATS Type E (Powertrain Control Module
# Name: 706, dtype: object

# %%
# As the 'Explorer Sport (2dr) built <= July 23rd 2000 and the ones built >= July 24th 2000 are equipped with different PATS Types,
# separate those 2 different pats types in 2 columns and add at the end of the df_ford_new
df_ford_new.loc[len(df_ford_new.index)] = [2001, 'Ford', 'Explorer Sport (2dr) <= July 23rd 2000', 'Parameter Reset Required', 
                                           'PATS Type B', 'Stand Alone PATS Module']
df_ford_new.loc[len(df_ford_new.index)] = [2001, 'Ford', 'Explorer Sport (2dr) >= July 24th 2000', 'Parameter Reset Required', 
                                           'PATS Type E', 'Stand Alone PATS Module']

# %%
# Drop index 705, it was duplicated in 2 rows
df_ford_new.drop(index=705)
# Out:
#       Year  Make                                      Model  \
# 190   1996  Ford                                    Mustang
# 191   1996  Ford                Taurus (Duratec & SHO only)
# 247   1997  Ford                                 Expedition
# 248   1997  Ford                                    Mustang
# 249   1997  Ford                Taurus (Duratec & SHO only)
# ...    ...   ...                                        ...
# 3282  2013  Ford                                    TRANSIT
# 0     1998  Ford  Contour (V6-only) / Built >= February 2st
# 1     1998  Ford  Contour (V6-only) / Built <= February 1st
# 265   2001  Ford     Explorer Sport (2dr) <= July 23rd 2000
# 266   2001  Ford     Explorer Sport (2dr) >= July 24th 2000
#
#                     ParameterReset     PATS Type       PATS Module Location
# 190   Parameter Reset Not Required  PATS Type A     Stand Alone PATS Module
# 191   Parameter Reset Not Required  PATS Type A     Stand Alone PATS Module
# 247   Parameter Reset Not Required  PATS Type A     Stand Alone PATS Module
# 248   Parameter Reset Not Required  PATS Type A     Stand Alone PATS Module
# 249   Parameter Reset Not Required  PATS Type A     Stand Alone PATS Module
# ...                            ...           ...                        ...
# 3282      Parameter Reset Required  PATS Type B         Body Control Module
# 0     Parameter Reset Not Required   PATS Type E  Powertrain Control Module
# 1     Parameter Reset Not Required   PATS Type A  Powertrain Control Module
# 265       Parameter Reset Required   PATS Type B    Stand Alone PATS Module
# 266       Parameter Reset Required   PATS Type E    Stand Alone PATS Module
#
# [266 rows x 6 columns]

# %%
# Iterate into columns 'PATS Type" and 'PATS Module Location" and find the string 'Fleet Vehicles' 
for index, row in df_ford_new.iterrows():
    if 'Fleet Vehicles' in row['PATS Type'] or 'Fleet Vehicles' in row['PATS Module Location']:
        print(row)
# Out:
# Year                                                                                        2008
# Make                                                                                        Ford
# Model                                                                                   E-Series
# ParameterReset                                                          Parameter Reset Required
# PATS Type                                                           Fleet Vehicles: PATS Type G
# PATS Module Location    Instrument Cluster)\nNon-Fleet Vehicles: PATS Type C (Instrument Cluster
# Name: 2069, dtype: object
# Year                                                                                        2009
# Make                                                                                        Ford
# Model                                                                                   E-Series
# ParameterReset                                                          Parameter Reset Required
# PATS Type                                                           Fleet Vehicles: PATS Type G
# PATS Module Location    Instrument Cluster)\nNon-Fleet Vehicles: PATS Type C (Instrument Cluster
# Name: 2316, dtype: object
# Year                                                                                        2010
# Make                                                                                        Ford
# Model                                                                                   E-Series
# ParameterReset                                                          Parameter Reset Required
# PATS Type                                                           Fleet Vehicles: PATS Type G
# PATS Module Location    Instrument Cluster)\nNon-Fleet Vehicles: PATS Type C (Instrument Cluster
# Name: 2563, dtype: object

# %%
# As E-Series models fleet vehicles has PATS G and non-fleet vehicles has PATS C from 2008 to 2010, separate those 2 PATS types between 2 rows
# and add the new rows to the df_ford_new

# Fleet vehicles has PATS G from 2008 to 2010
df_ford_new.loc[len(df_ford_new.index)] = [2008, 'Ford', 'E-Series / Fleet Vehicles', 'Parameter Reset Required', 'PATS Type G', 'Instrument Cluster']
df_ford_new.loc[len(df_ford_new.index)] = [2009, 'Ford', 'E-Series / Fleet Vehicles', 'Parameter Reset Required', 'PATS Type G', 'Instrument Cluster']
df_ford_new.loc[len(df_ford_new.index)] = [2010, 'Ford', 'E-Series / Fleet Vehicles', 'Parameter Reset Required', 'PATS Type G', 'Instrument Cluster']

# Non-fleet vehicles has PATS C 2008 to 2010
df_ford_new.loc[len(df_ford_new.index)] = [2008, 'Ford', 'E-Series / non-Fleet Vehicles', 'Parameter Reset Required', 'PATS Type C', 'Instrument Cluster']
df_ford_new.loc[len(df_ford_new.index)] = [2009, 'Ford', 'E-Series / non-Fleet Vehicles', 'Parameter Reset Required', 'PATS Type C', 'Instrument Cluster']
df_ford_new.loc[len(df_ford_new.index)] = [2010, 'Ford', 'E-Series / non-Fleet Vehicles', 'Parameter Reset Required', 'PATS Type C', 'Instrument Cluster']

# %%
# Drop the old 2008 'E-Series, PATS G and C' based on the index rows 
df_ford_new.drop([2069, 2316, 2563])
# Out:
#      Year  Make                          Model                ParameterReset  \
# 190  1996  Ford                        Mustang  Parameter Reset Not Required
# 191  1996  Ford    Taurus (Duratec & SHO only)  Parameter Reset Not Required
# 247  1997  Ford                     Expedition  Parameter Reset Not Required
# 248  1997  Ford                        Mustang  Parameter Reset Not Required
# 249  1997  Ford    Taurus (Duratec & SHO only)  Parameter Reset Not Required
# ..    ...   ...                            ...                           ...
# 268  2009  Ford      E-Series / Fleet Vehicles      Parameter Reset Required
# 269  2010  Ford      E-Series / Fleet Vehicles      Parameter Reset Required
# 270  2008  Ford  E-Series / non-Fleet Vehicles      Parameter Reset Required
# 271  2009  Ford  E-Series / non-Fleet Vehicles      Parameter Reset Required
# 272  2010  Ford  E-Series / non-Fleet Vehicles      Parameter Reset Required
#
#         PATS Type     PATS Module Location
# 190  PATS Type A   Stand Alone PATS Module
# 191  PATS Type A   Stand Alone PATS Module
# 247  PATS Type A   Stand Alone PATS Module
# 248  PATS Type A   Stand Alone PATS Module
# 249  PATS Type A   Stand Alone PATS Module
# ..            ...                      ...
# 268   PATS Type G       Instrument Cluster
# 269   PATS Type G       Instrument Cluster
# 270   PATS Type C       Instrument Cluster
# 271   PATS Type C       Instrument Cluster
# 272   PATS Type C       Instrument Cluster
#
# [270 rows x 6 columns]

# %%
# Iterate into columns 'PATS Type' and 'PATS Module Location' and find the string 'Push To Start: PATS Type C'
for index, row in df_ford_new.iterrows():
    if 'Push To Start: PATS Type C' in row['PATS Type'] or 'Push To Start: PATS Type C' in row['PATS Module Location']:
        print(row)
# Out:
# Year                                                                                                                  2010
# Make                                                                                                                  Ford
# Model                                                                                                               Taurus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 2576, dtype: object
# Year                                                                                                                  2011
# Make                                                                                                                  Ford
# Model                                                                                                               FIESTA
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type A
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 2806, dtype: object
# Year                                                                                                                  2011
# Make                                                                                                                  Ford
# Model                                                                                                               Taurus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 2812, dtype: object
# Year                                                                                                                  2012
# Make                                                                                                                  Ford
# Model                                                                                                               FIESTA
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type A
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3038, dtype: object
# Year                                                                                                                  2012
# Make                                                                                                                  Ford
# Model                                                                                                                Focus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3040, dtype: object
# Year                                                                                                                  2012
# Make                                                                                                                  Ford
# Model                                                                                                               Taurus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3045, dtype: object
# Year                                                                                                                  2013
# Make                                                                                                                  Ford
# Model                                                                                                               FIESTA
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type A
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3271, dtype: object
# Year                                                                                                                  2013
# Make                                                                                                                  Ford
# Model                                                                                                                Focus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3274, dtype: object
# Year                                                                                                                  2013
# Make                                                                                                                  Ford
# Model                                                                                                               Taurus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3280, dtype: object

# %% [markdown]
# - The 'Push To Start' info, is mixed with the PATS module location and the PATS Type info is repeated in the 'PATS Type' column and in the 'PATS module location.
# - These are the changes to be made:
#     * Relocate the string 'Push To Start' to 'Model' column,
#     * Remove the 'PATS Type C' from the 'Module Location' and leave this string only in the column 'PATS Type'
#     * Split in 2 rows eg:
#         1th row: Taurus (Keyed Ignition), PATS module location = Instrument Cluster.
#         2nd row: Taurus (Push To Start), PATS module location = Remote Function Actuator / Keyless Vehicle Module

# %%
# Add 1 new row for 2010 Taurus (Keyed Ignition)
df_ford_new.loc[len(df_ford_new.index)] = [2010, 'Ford', 'Taurus (Keyed Ignition)', 'Parameter Reset Required', 'PATS Type C', 'Instrument Cluster']

# %%
# Add 1 new row for 2010 Taurus (Push To Start)
df_ford_new.loc[len(df_ford_new.index)] = [2010, 'Ford', 'Taurus (Push To Start)', 'Parameter Reset Required', 'PATS Type C', 'Remote Function Actuator / Keyless Vehicle Module']

# %%
# Add 1 new row for 2011 FIESTA (Keyed Ignition)
df_ford_new.loc[len(df_ford_new.index)] = [2011, 'Ford', 'FIESTA (Keyed Ignition)', 'Parameter Reset Required', 'PATS Type A', 'Instrument Cluster']

# %%
# Add 1 new row for 2011 FIESTA (Push To Start)
df_ford_new.loc[len(df_ford_new.index)] = [2011, 'Ford', 'FIESTA (Push To Start)', 'Parameter Reset Required', 'PATS Type C', 'Remote Function Actuator / Keyless Vehicle Module']

# %%
# Add 1 new row for 2011 Taurus (Keyed Ignition)
df_ford_new.loc[len(df_ford_new.index)] = [2011, 'Ford', 'Taurus (Keyed Ignition)', 'Parameter Reset Required', 'PATS Type C', 'Instrument Cluster']

# %%
# Add 1 new row for 2011 Taurus (Push To Start)
df_ford_new.loc[len(df_ford_new.index)] = [2011, 'Ford', 'Taurus (Push To Start)', 'Parameter Reset Required', 'PATS Type C', 'Remote Function Actuator / Keyless Vehicle Module']

# %%
# As the first iteration to verify the word the string 'Push To Start: PATS Type C', iterate again to verify the more rows containing this string 
for index, row in df_ford_new.iterrows():
    if 'Push To Start: PATS Type C' in row['PATS Type'] or 'Push To Start: PATS Type C' in row['PATS Module Location']:
        print(row)
# Out:
# Year                                                                                                                  2010
# Make                                                                                                                  Ford
# Model                                                                                                               Taurus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 2576, dtype: object
# Year                                                                                                                  2011
# Make                                                                                                                  Ford
# Model                                                                                                               FIESTA
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type A
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 2806, dtype: object
# Year                                                                                                                  2011
# Make                                                                                                                  Ford
# Model                                                                                                               Taurus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 2812, dtype: object
# Year                                                                                                                  2012
# Make                                                                                                                  Ford
# Model                                                                                                               FIESTA
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type A
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3038, dtype: object
# Year                                                                                                                  2012
# Make                                                                                                                  Ford
# Model                                                                                                                Focus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3040, dtype: object
# Year                                                                                                                  2012
# Make                                                                                                                  Ford
# Model                                                                                                               Taurus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3045, dtype: object
# Year                                                                                                                  2013
# Make                                                                                                                  Ford
# Model                                                                                                               FIESTA
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type A
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3271, dtype: object
# Year                                                                                                                  2013
# Make                                                                                                                  Ford
# Model                                                                                                                Focus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3274, dtype: object
# Year                                                                                                                  2013
# Make                                                                                                                  Ford
# Model                                                                                                               Taurus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3280, dtype: object

# %%
# Add 1 new row for 2012 FIESTA (Keyed Ignition) PATS Type A
df_ford_new.loc[len(df_ford_new.index)] = [2012, 'Ford', 'FIESTA (Keyed Ignition)', 'Parameter Reset Required', 'PATS Type A', 'Instrument Cluster']

# %%
# Add 1 new row for 2012 FIESTA (Push To Start) PATS Type C
df_ford_new.loc[len(df_ford_new.index)] = [2012, 'Ford', 'FIESTA (Push To Start)', 'Parameter Reset Required', 'PATS Type C', 'Remote Function Actuator / Keyless Vehicle Module']

# %%
# Add 1 new row for 2012 Focus (Keyed Ignition)
df_ford_new.loc[len(df_ford_new.index)] = [2012, 'Ford', 'Focus (Keyed Ignition)', 'Parameter Reset Required', 'PATS Type C', 'Instrument Cluster']

# %%
# Add 1 new row for 2012 Focus (Push To Start)
df_ford_new.loc[len(df_ford_new.index)] = [2012, 'Ford', 'Focus (Push To Start)', 'Parameter Reset Required', 'PATS Type C', 'Remote Function Actuator / Keyless Vehicle Module']

# %%
# Add 1 new row for 2012 Taurus (Keyed Ignition)
df_ford_new.loc[len(df_ford_new.index)] = [2012, 'Ford', 'Taurus (Keyed Ignition)', 'Parameter Reset Required', 'PATS Type C', 'Instrument Cluster']

# %%
# Add 1 new row for 2012 Taurus (Push To Start)
df_ford_new.loc[len(df_ford_new.index)] = [2012, 'Ford', 'Taurus (Push To Start)', 'Parameter Reset Required', 'PATS Type C', 'Remote Function Actuator / Keyless Vehicle Module']

# %%
# As the first iteration to verify the string 'Push To Start: PATS Type C', iterate again to verify the more rows containing this string 
for index, row in df_ford_new.iterrows():
    if 'Push To Start: PATS Type C' in row['PATS Type'] or 'Push To Start: PATS Type C' in row['PATS Module Location']:
        print(row)
# Out:
# Year                                                                                                                  2010
# Make                                                                                                                  Ford
# Model                                                                                                               Taurus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 2576, dtype: object
# Year                                                                                                                  2011
# Make                                                                                                                  Ford
# Model                                                                                                               FIESTA
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type A
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 2806, dtype: object
# Year                                                                                                                  2011
# Make                                                                                                                  Ford
# Model                                                                                                               Taurus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 2812, dtype: object
# Year                                                                                                                  2012
# Make                                                                                                                  Ford
# Model                                                                                                               FIESTA
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type A
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3038, dtype: object
# Year                                                                                                                  2012
# Make                                                                                                                  Ford
# Model                                                                                                                Focus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3040, dtype: object
# Year                                                                                                                  2012
# Make                                                                                                                  Ford
# Model                                                                                                               Taurus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3045, dtype: object
# Year                                                                                                                  2013
# Make                                                                                                                  Ford
# Model                                                                                                               FIESTA
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type A
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3271, dtype: object
# Year                                                                                                                  2013
# Make                                                                                                                  Ford
# Model                                                                                                                Focus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3274, dtype: object
# Year                                                                                                                  2013
# Make                                                                                                                  Ford
# Model                                                                                                               Taurus
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3280, dtype: object

# %%
# Add 1 new row for 2013 FIESTA (Keyed Ignition) and PATS Type A
df_ford_new.loc[len(df_ford_new.index)] = [2013, 'Ford', 'FIESTA (Keyed Ignition)', 'Parameter Reset Required', 'PATS Type A', 'Instrument Cluster']

# %%
# Add 1 new row for 2013 FIESTA (Push To Start)
df_ford_new.loc[len(df_ford_new.index)] = [2013, 'Ford', 'FIESTA (Push To Start)', 'Parameter Reset Required', 'PATS Type C', 'Instrument Cluster']

# %%
# Add 1 new row for 2013 Focus (Keyed Ignition)
df_ford_new.loc[len(df_ford_new.index)] = [2013, 'Ford', 'Focus (Keyed Ignition)', 'Parameter Reset Required', 'PATS Type C', 'Instrument Cluster']

# %%
# Add 1 new row for 2013 Focus (Push To Start)
df_ford_new.loc[len(df_ford_new.index)] = [2013, 'Ford', 'Focus (Push To Start)', 'Parameter Reset Required', 'PATS Type C', 'Instrument Cluster']

# %%
# Add 1 new row for 2013 Taurus (Keyed Ignition)
df_ford_new.loc[len(df_ford_new.index)] = [2013, 'Ford', 'Taurus (Keyed Ignition)', 'Parameter Reset Required', 'PATS Type C', 'Instrument Cluster']

# %%
# Add 1 new row for 2013 Taurus (Push To Start)
df_ford_new.loc[len(df_ford_new.index)] = [2013, 'Ford', 'Taurus (Push To Start)', 'Parameter Reset Required', 'PATS Type C', 'Instrument Cluster']

# %%
# Create a list to store the indexes
df_ford_indexes_to_drop = []

# Iterate in the column 'PATS Module Location' and store the indexes from the rows 
# containing the string 'Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module'
for index, value in df_ford_new['PATS Module Location'].items():
    if value == 'Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module':
        df_ford_indexes_to_drop.append(index)

# Print the indexes
print(df_ford_indexes_to_drop)
# Out:
# [2576, 2806, 2812, 3038, 3040, 3045, 3271, 3274, 3280]

# %%
# Drop all old rows after splitting between 'keyed ignition' and 'push to start' configuration
df_ford_updated = df_ford_new.drop([2576, 2806, 2812, 3038, 3040, 3045, 3271, 3274, 3280])

# %%
# Verify if there are rows containing the string 'Push To Start: PATS Type C' 
for index, row in df_ford_updated.iterrows():
    if 'Push To Start: PATS Type C' in row['PATS Type'] or 'Push To Start: PATS Type C' in row['PATS Module Location']:
        print(row)

# %%
# Remove duplicates rows
df_ford_updated.drop_duplicates()
# Out:
#       Year  Make                                           Model  \
# 190   1996  Ford                                         Mustang
# 191   1996  Ford                     Taurus (Duratec & SHO only)
# 247   1997  Ford                                      Expedition
# 248   1997  Ford                                         Mustang
# 249   1997  Ford                     Taurus (Duratec & SHO only)
# 326   1998  Ford                                  Crown Victoria
# 327   1998  Ford                                      Expedition
# 328   1998  Ford                                  Explorer (4dr)
# 329   1998  Ford                            Explorer Sport (2dr)
# 330   1998  Ford                                         Mustang
# 331   1998  Ford                     Taurus (Duratec & SHO only)
# 429   1999  Ford                               Contour (V6-only)
# 430   1999  Ford                                  Crown Victoria
# 431   1999  Ford                                      Expedition
# 432   1999  Ford                                  Explorer (4dr)
# 433   1999  Ford                            Explorer Sport (2dr)
# 434   1999  Ford                                  F-150 Heritage
# 435   1999  Ford                         F-250 (under 8500# GVW)
# 436   1999  Ford                                         Mustang
# 437   1999  Ford                       Ranger (3.0L & 4.0L only)
# 438   1999  Ford                     Taurus (Duratec & SHO only)
# 439   1999  Ford                                        Windstar
# 547   2000  Ford                               Contour (V6-only)
# 548   2000  Ford                                  Crown Victoria
# 549   2000  Ford                                       Excursion
# 550   2000  Ford                                      Expedition
# 551   2000  Ford                                  Explorer (4dr)
# 552   2000  Ford                            Explorer Sport (2dr)
# 553   2000  Ford                                  F-150 Heritage
# 554   2000  Ford                         F-250 (under 8500# GVW)
# 555   2000  Ford                                           Focus
# 556   2000  Ford                                         Mustang
# 557   2000  Ford                       Ranger (3.0L & 4.0L only)
# 558   2000  Ford                                          Taurus
# 559   2000  Ford                                        Windstar
# 700   2001  Ford                                  Crown Victoria
# 701   2001  Ford                                          Escape
# 702   2001  Ford                                       Excursion
# 703   2001  Ford                                      Expedition
# 704   2001  Ford                                  Explorer (4dr)
# 705   2001  Ford                            Explorer Sport (2dr)
# 706   2001  Ford                             Explorer Sport Trac
# 707   2001  Ford                           F-150 Harley-Davidson
# 708   2001  Ford                                  F-150 Heritage
# 709   2001  Ford                                           Focus
# 710   2001  Ford                                         Mustang
# 711   2001  Ford                     Ranger (2.3L, 3.0L, & 4.0L)
# 712   2001  Ford                                          Taurus
# 713   2001  Ford                                        Windstar
# 861   2002  Ford                                  Crown Victoria
# 862   2002  Ford                                          Escape
# 863   2002  Ford                                       Excursion
# 864   2002  Ford                                      Expedition
# 865   2002  Ford                                  Explorer (4dr)
# 866   2002  Ford                            Explorer Sport (2dr)
# 867   2002  Ford                             Explorer Sport Trac
# 868   2002  Ford                           F-150 Harley-Davidson
# 869   2002  Ford                                  F-150 Heritage
# 870   2002  Ford                                           Focus
# 871   2002  Ford                                         Mustang
# 872   2002  Ford                     Ranger (2.3L, 3.0L, & 4.0L)
# 873   2002  Ford                                          Taurus
# 874   2002  Ford                                     Thunderbird
# 875   2002  Ford                                        Windstar
# 1032  2003  Ford                                  Crown Victoria
# 1033  2003  Ford                                          Escape
# 1034  2003  Ford                                       Excursion
# 1035  2003  Ford                                      Expedition
# 1036  2003  Ford                                  Explorer (4dr)
# 1037  2003  Ford                            Explorer Sport (2dr)
# 1038  2003  Ford                             Explorer Sport Trac
# 1039  2003  Ford                           F-150 Harley-Davidson
# 1040  2003  Ford                                  F-150 Heritage
# 1041  2003  Ford                                           Focus
# 1042  2003  Ford                                         Mustang
# 1043  2003  Ford                     Ranger (2.3L, 3.0L, & 4.0L)
# 1044  2003  Ford                                          Taurus
# 1045  2003  Ford                                     Thunderbird
# 1046  2003  Ford                                        Windstar
# 1221  2004  Ford                                  Crown Victoria
# 1222  2004  Ford                                          Escape
# 1223  2004  Ford                                       Excursion
# 1224  2004  Ford                                      Expedition
# 1225  2004  Ford                                  Explorer (4dr)
# 1226  2004  Ford                             Explorer Sport Trac
# 1227  2004  Ford                                           F-150
# 1228  2004  Ford                                  F-150 Heritage
# 1229  2004  Ford                                           Focus
# 1230  2004  Ford                                        Freestar
# 1231  2004  Ford                                         Mustang
# 1232  2004  Ford                     Ranger (2.3L, 3.0L, & 4.0L)
# 1233  2004  Ford                                          Taurus
# 1234  2004  Ford                                     Thunderbird
# 1414  2005  Ford                                  Crown Victoria
# 1415  2005  Ford                                          Escape
# 1416  2005  Ford                                       Excursion
# 1417  2005  Ford                                      Expedition
# 1418  2005  Ford                                  Explorer (4dr)
# 1419  2005  Ford                             Explorer Sport Trac
# 1420  2005  Ford                                           F-150
# 1421  2005  Ford                                  F-150 Heritage
# 1422  2005  Ford                                    Five Hundred
# 1423  2005  Ford                                           Focus
# 1424  2005  Ford                                        Freestar
# 1425  2005  Ford                                       Freestyle
# 1426  2005  Ford                                              GT
# 1427  2005  Ford                                         Mustang
# 1428  2005  Ford                       Ranger (3.0L & 4.0L only)
# 1429  2005  Ford                                          Taurus
# 1430  2005  Ford                                     Thunderbird
# 1601  2006  Ford                                  Crown Victoria
# 1602  2006  Ford                                          Escape
# 1603  2006  Ford                                 Escape (Hybrid)
# 1604  2006  Ford                                      Expedition
# 1605  2006  Ford                                  Explorer (4dr)
# 1606  2006  Ford                                           F-150
# 1607  2006  Ford                           F-150 Harley-Davidson
# 1608  2006  Ford                                  F-150 Heritage
# 1609  2006  Ford                                    Five Hundred
# 1610  2006  Ford                                           Focus
# 1611  2006  Ford                                        Freestar
# 1612  2006  Ford                                       Freestyle
# 1613  2006  Ford                                          Fusion
# 1614  2006  Ford                                              GT
# 1615  2006  Ford                                         Mustang
# 1616  2006  Ford                       Ranger (3.0L & 4.0L only)
# 1617  2006  Ford                                          Taurus
# 1618  2006  Ford                                     Thunderbird
# 1823  2007  Ford                                  Crown Victoria
# 1824  2007  Ford                                            Edge
# 1825  2007  Ford                                          Escape
# 1826  2007  Ford                                 Escape (Hybrid)
# 1827  2007  Ford                                      Expedition
# 1828  2007  Ford                                  Explorer (4dr)
# 1829  2007  Ford                             Explorer Sport Trac
# 1830  2007  Ford                                           F-150
# 1831  2007  Ford                           F-150 Harley-Davidson
# 1832  2007  Ford                                    Five Hundred
# 1833  2007  Ford                                           Focus
# 1834  2007  Ford                                        Freestar
# 1835  2007  Ford                                       Freestyle
# 1836  2007  Ford                                          Fusion
# 1837  2007  Ford                                         Mustang
# 1838  2007  Ford                     Ranger (2.3L, 3.0L, & 4.0L)
# 2067  2008  Ford                                  Crown Victoria
# 2068  2008  Ford                                            Edge
# 2069  2008  Ford                                        E-Series
# 2070  2008  Ford                                      Expedition
# 2071  2008  Ford                                  Explorer (4dr)
# 2072  2008  Ford                             Explorer Sport Trac
# 2073  2008  Ford                                           F-150
# 2074  2008  Ford                           F-150 Harley-Davidson
# 2075  2008  Ford  F-Series > 8500 (Stripped Chassis/Cab Chassis)
# 2076  2008  Ford                                           Focus
# 2077  2008  Ford                                       Freestyle
# 2078  2008  Ford                                          Fusion
# 2079  2008  Ford                                         Mustang
# 2080  2008  Ford                     Ranger (2.3L, 3.0L, & 4.0L)
# 2081  2008  Ford                                          Taurus
# 2082  2008  Ford                                        Taurus X
# 2309  2009  Ford                                  Crown Victoria
# 2310  2009  Ford                                            Edge
# 2311  2009  Ford                                          Escape
# 2314  2009  Ford                                 Escape (Hybrid)
# 2316  2009  Ford                                        E-Series
# 2317  2009  Ford                                      Expedition
# 2318  2009  Ford                                  Explorer (4dr)
# 2319  2009  Ford                             Explorer Sport Trac
# 2320  2009  Ford                                           F-150
# 2321  2009  Ford  F-Series > 8500 (Stripped Chassis/Cab Chassis)
# 2322  2009  Ford                                            Flex
# 2323  2009  Ford                                           Focus
# 2324  2009  Ford                                       Freestyle
# 2325  2009  Ford                                          Fusion
# 2326  2009  Ford                                         Mustang
# 2327  2009  Ford                     Ranger (2.3L, 3.0L, & 4.0L)
# 2328  2009  Ford                                          Taurus
# 2329  2009  Ford                                        Taurus X
# 2558  2010  Ford                                  Crown Victoria
# 2559  2010  Ford                                            Edge
# 2560  2010  Ford                                          Escape
# 2562  2010  Ford                                 Escape (Hybrid)
# 2563  2010  Ford                                        E-Series
# 2564  2010  Ford                                      Expedition
# 2565  2010  Ford                                  Explorer (4dr)
# 2566  2010  Ford                             Explorer Sport Trac
# 2567  2010  Ford                                           F-150
# 2568  2010  Ford  F-Series > 8500 (Stripped Chassis/Cab Chassis)
# 2569  2010  Ford                                            Flex
# 2570  2010  Ford                                           Focus
# 2571  2010  Ford                                       Freestyle
# 2572  2010  Ford                                          Fusion
# 2573  2010  Ford                                 Fusion (Hybrid)
# 2574  2010  Ford                                         Mustang
# 2575  2010  Ford                     Ranger (2.3L, 3.0L, & 4.0L)
# 2577  2010  Ford                                 TRANSIT CONNECT
# 2795  2011  Ford                                  Crown Victoria
# 2796  2011  Ford                                            Edge
# 2797  2011  Ford                             Edge(Push to Start)
# 2798  2011  Ford                                          Escape
# 2800  2011  Ford                                 Escape (Hybrid)
# 2801  2011  Ford                                        E-Series
# 2802  2011  Ford                                      Expedition
# 2803  2011  Ford                                  Explorer (4dr)
# 2804  2011  Ford                                           F-150
# 2805  2011  Ford         F-SERIES Super Duty (F-350/450/650/750)
# 2807  2011  Ford                                            Flex
# 2808  2011  Ford                                           Focus
# 2809  2011  Ford                                          Fusion
# 2810  2011  Ford                                 Fusion (Hybrid)
# 2811  2011  Ford                                         Mustang
# 2813  2011  Ford                                 TRANSIT CONNECT
# 3027  2012  Ford                                  Crown Victoria
# 3028  2012  Ford                                            Edge
# 3029  2012  Ford                             Edge(Push to Start)
# 3030  2012  Ford                                          Escape
# 3032  2012  Ford                                 Escape (Hybrid)
# 3033  2012  Ford                                        E-Series
# 3034  2012  Ford                                      Expedition
# 3035  2012  Ford                                  Explorer (4dr)
# 3036  2012  Ford                                           F-150
# 3037  2012  Ford         F-SERIES Super Duty (F-350/450/650/750)
# 3039  2012  Ford                                            Flex
# 3041  2012  Ford                                        FOCUS EV
# 3042  2012  Ford                                          Fusion
# 3043  2012  Ford                                 Fusion (Hybrid)
# 3044  2012  Ford                                         Mustang
# 3046  2012  Ford                                 TRANSIT CONNECT
# 3260  2013  Ford                                  C-MAX (Hybrid)
# 3261  2013  Ford                  C-MAX (Hybrid) (Push to Start)
# 3262  2013  Ford                                            Edge
# 3263  2013  Ford                             Edge(Push to Start)
# 3264  2013  Ford                                          Escape
# 3265  2013  Ford                          ESCAPE (Push to Start)
# 3266  2013  Ford                                        E-Series
# 3267  2013  Ford                                      Expedition
# 3268  2013  Ford                                  Explorer (4dr)
# 3269  2013  Ford                                           F-150
# 3270  2013  Ford         F-SERIES Super Duty (F-350/450/650/750)
# 3272  2013  Ford                                            Flex
# 3273  2013  Ford                            FLEX (Push to Start)
# 3275  2013  Ford                                        FOCUS EV
# 3276  2013  Ford                                          FUSION
# 3277  2013  Ford                                 FUSION (Hybrid)
# 3278  2013  Ford                                       FUSION EV
# 3279  2013  Ford                                         Mustang
# 3281  2013  Ford                                 TRANSIT CONNECT
# 3282  2013  Ford                                         TRANSIT
# 0     1998  Ford       Contour (V6-only) / Built >= February 2st
# 1     1998  Ford       Contour (V6-only) / Built <= February 1st
# 265   2001  Ford          Explorer Sport (2dr) <= July 23rd 2000
# 266   2001  Ford          Explorer Sport (2dr) >= July 24th 2000
# 267   2008  Ford                       E-Series / Fleet Vehicles
# 268   2009  Ford                       E-Series / Fleet Vehicles
# 269   2010  Ford                       E-Series / Fleet Vehicles
# 270   2008  Ford                   E-Series / non-Fleet Vehicles
# 271   2009  Ford                   E-Series / non-Fleet Vehicles
# 272   2010  Ford                   E-Series / non-Fleet Vehicles
# 273   2010  Ford                         Taurus (Keyed Ignition)
# 274   2010  Ford                          Taurus (Push To Start)
# 275   2011  Ford                         FIESTA (Keyed Ignition)
# 276   2011  Ford                          FIESTA (Push To Start)
# 277   2011  Ford                         Taurus (Keyed Ignition)
# 278   2011  Ford                          Taurus (Push To Start)
# 279   2012  Ford                         FIESTA (Keyed Ignition)
# 280   2012  Ford                          FIESTA (Push To Start)
# 281   2012  Ford                          Focus (Keyed Ignition)
# 282   2012  Ford                           Focus (Push To Start)
# 283   2012  Ford                         Taurus (Keyed Ignition)
# 284   2012  Ford                          Taurus (Push To Start)
# 285   2013  Ford                         FIESTA (Keyed Ignition)
# 286   2013  Ford                          FIESTA (Push To Start)
# 287   2013  Ford                          Focus (Keyed Ignition)
# 288   2013  Ford                           Focus (Push To Start)
# 289   2013  Ford                         Taurus (Keyed Ignition)
# 290   2013  Ford                          Taurus (Push To Start)
#
#                     ParameterReset  \
# 190   Parameter Reset Not Required
# 191   Parameter Reset Not Required
# 247   Parameter Reset Not Required
# 248   Parameter Reset Not Required
# 249   Parameter Reset Not Required
# 326       Parameter Reset Required
# 327   Parameter Reset Not Required
# 328       Parameter Reset Required
# 329       Parameter Reset Required
# 330       Parameter Reset Required
# 331       Parameter Reset Required
# 429   Parameter Reset Not Required
# 430       Parameter Reset Required
# 431       Parameter Reset Required
# 432       Parameter Reset Required
# 433       Parameter Reset Required
# 434       Parameter Reset Required
# 435       Parameter Reset Required
# 436       Parameter Reset Required
# 437       Parameter Reset Required
# 438       Parameter Reset Required
# 439       Parameter Reset Required
# 547   Parameter Reset Not Required
# 548       Parameter Reset Required
# 549       Parameter Reset Required
# 550       Parameter Reset Required
# 551       Parameter Reset Required
# 552       Parameter Reset Required
# 553       Parameter Reset Required
# 554       Parameter Reset Required
# 555   Parameter Reset Not Required
# 556       Parameter Reset Required
# 557       Parameter Reset Required
# 558   Parameter Reset Not Required
# 559       Parameter Reset Required
# 700       Parameter Reset Required
# 701   Parameter Reset Not Required
# 702       Parameter Reset Required
# 703       Parameter Reset Required
# 704       Parameter Reset Required
# 705       Parameter Reset Required
# 706       Parameter Reset Required
# 707       Parameter Reset Required
# 708       Parameter Reset Required
# 709   Parameter Reset Not Required
# 710       Parameter Reset Required
# 711   Parameter Reset Not Required
# 712   Parameter Reset Not Required
# 713   Parameter Reset Not Required
# 861       Parameter Reset Required
# 862   Parameter Reset Not Required
# 863       Parameter Reset Required
# 864       Parameter Reset Required
# 865   Parameter Reset Not Required
# 866   Parameter Reset Not Required
# 867   Parameter Reset Not Required
# 868       Parameter Reset Required
# 869       Parameter Reset Required
# 870   Parameter Reset Not Required
# 871       Parameter Reset Required
# 872   Parameter Reset Not Required
# 873   Parameter Reset Not Required
# 874       Parameter Reset Required
# 875   Parameter Reset Not Required
# 1032  Parameter Reset Not Required
# 1033  Parameter Reset Not Required
# 1034      Parameter Reset Required
# 1035  Parameter Reset Not Required
# 1036  Parameter Reset Not Required
# 1037  Parameter Reset Not Required
# 1038  Parameter Reset Not Required
# 1039      Parameter Reset Required
# 1040      Parameter Reset Required
# 1041  Parameter Reset Not Required
# 1042      Parameter Reset Required
# 1043  Parameter Reset Not Required
# 1044  Parameter Reset Not Required
# 1045      Parameter Reset Required
# 1046  Parameter Reset Not Required
# 1221  Parameter Reset Not Required
# 1222  Parameter Reset Not Required
# 1223      Parameter Reset Required
# 1224  Parameter Reset Not Required
# 1225  Parameter Reset Not Required
# 1226  Parameter Reset Not Required
# 1227  Parameter Reset Not Required
# 1228      Parameter Reset Required
# 1229  Parameter Reset Not Required
# 1230  Parameter Reset Not Required
# 1231      Parameter Reset Required
# 1232  Parameter Reset Not Required
# 1233  Parameter Reset Not Required
# 1234      Parameter Reset Required
# 1414  Parameter Reset Not Required
# 1415  Parameter Reset Not Required
# 1416      Parameter Reset Required
# 1417  Parameter Reset Not Required
# 1418  Parameter Reset Not Required
# 1419  Parameter Reset Not Required
# 1420  Parameter Reset Not Required
# 1421      Parameter Reset Required
# 1422  Parameter Reset Not Required
# 1423  Parameter Reset Not Required
# 1424  Parameter Reset Not Required
# 1425  Parameter Reset Not Required
# 1426      Parameter Reset Required
# 1427  Parameter Reset Not Required
# 1428  Parameter Reset Not Required
# 1429  Parameter Reset Not Required
# 1430      Parameter Reset Required
# 1601  Parameter Reset Not Required
# 1602  Parameter Reset Not Required
# 1603      Parameter Reset Required
# 1604  Parameter Reset Not Required
# 1605      Parameter Reset Required
# 1606  Parameter Reset Not Required
# 1607  Parameter Reset Not Required
# 1608      Parameter Reset Required
# 1609  Parameter Reset Not Required
# 1610  Parameter Reset Not Required
# 1611  Parameter Reset Not Required
# 1612  Parameter Reset Not Required
# 1613      Parameter Reset Required
# 1614      Parameter Reset Required
# 1615  Parameter Reset Not Required
# 1616  Parameter Reset Not Required
# 1617  Parameter Reset Not Required
# 1618      Parameter Reset Required
# 1823  Parameter Reset Not Required
# 1824      Parameter Reset Required
# 1825  Parameter Reset Not Required
# 1826      Parameter Reset Required
# 1827      Parameter Reset Required
# 1828      Parameter Reset Required
# 1829      Parameter Reset Required
# 1830  Parameter Reset Not Required
# 1831  Parameter Reset Not Required
# 1832  Parameter Reset Not Required
# 1833  Parameter Reset Not Required
# 1834  Parameter Reset Not Required
# 1835  Parameter Reset Not Required
# 1836      Parameter Reset Required
# 1837  Parameter Reset Not Required
# 1838      Parameter Reset Required
# 2067  Parameter Reset Not Required
# 2068      Parameter Reset Required
# 2069      Parameter Reset Required
# 2070      Parameter Reset Required
# 2071      Parameter Reset Required
# 2072      Parameter Reset Required
# 2073  Parameter Reset Not Required
# 2074  Parameter Reset Not Required
# 2075      Parameter Reset Required
# 2076      Parameter Reset Required
# 2077      Parameter Reset Required
# 2078      Parameter Reset Required
# 2079  Parameter Reset Not Required
# 2080      Parameter Reset Required
# 2081      Parameter Reset Required
# 2082      Parameter Reset Required
# 2309  Parameter Reset Not Required
# 2310      Parameter Reset Required
# 2311      Parameter Reset Required
# 2314      Parameter Reset Required
# 2316      Parameter Reset Required
# 2317      Parameter Reset Required
# 2318      Parameter Reset Required
# 2319      Parameter Reset Required
# 2320      Parameter Reset Required
# 2321      Parameter Reset Required
# 2322      Parameter Reset Required
# 2323      Parameter Reset Required
# 2324      Parameter Reset Required
# 2325      Parameter Reset Required
# 2326  Parameter Reset Not Required
# 2327      Parameter Reset Required
# 2328      Parameter Reset Required
# 2329      Parameter Reset Required
# 2558  Parameter Reset Not Required
# 2559      Parameter Reset Required
# 2560      Parameter Reset Required
# 2562      Parameter Reset Required
# 2563      Parameter Reset Required
# 2564      Parameter Reset Required
# 2565      Parameter Reset Required
# 2566      Parameter Reset Required
# 2567      Parameter Reset Required
# 2568      Parameter Reset Required
# 2569      Parameter Reset Required
# 2570      Parameter Reset Required
# 2571      Parameter Reset Required
# 2572      Parameter Reset Required
# 2573      Parameter Reset Required
# 2574      Parameter Reset Required
# 2575      Parameter Reset Required
# 2577      Parameter Reset Required
# 2795  Parameter Reset Not Required
# 2796      Parameter Reset Required
# 2797      Parameter Reset Required
# 2798      Parameter Reset Required
# 2800      Parameter Reset Required
# 2801      Parameter Reset Required
# 2802      Parameter Reset Required
# 2803      Parameter Reset Required
# 2804      Parameter Reset Required
# 2805      Parameter Reset Required
# 2807      Parameter Reset Required
# 2808      Parameter Reset Required
# 2809      Parameter Reset Required
# 2810      Parameter Reset Required
# 2811      Parameter Reset Required
# 2813      Parameter Reset Required
# 3027  Parameter Reset Not Required
# 3028      Parameter Reset Required
# 3029      Parameter Reset Required
# 3030      Parameter Reset Required
# 3032      Parameter Reset Required
# 3033      Parameter Reset Required
# 3034      Parameter Reset Required
# 3035      Parameter Reset Required
# 3036      Parameter Reset Required
# 3037      Parameter Reset Required
# 3039      Parameter Reset Required
# 3041      Parameter Reset Required
# 3042      Parameter Reset Required
# 3043      Parameter Reset Required
# 3044      Parameter Reset Required
# 3046      Parameter Reset Required
# 3260      Parameter Reset Required
# 3261      Parameter Reset Required
# 3262      Parameter Reset Required
# 3263      Parameter Reset Required
# 3264      Parameter Reset Required
# 3265      Parameter Reset Required
# 3266      Parameter Reset Required
# 3267      Parameter Reset Required
# 3268      Parameter Reset Required
# 3269      Parameter Reset Required
# 3270      Parameter Reset Required
# 3272      Parameter Reset Required
# 3273      Parameter Reset Required
# 3275      Parameter Reset Required
# 3276      Parameter Reset Required
# 3277      Parameter Reset Required
# 3278      Parameter Reset Required
# 3279      Parameter Reset Required
# 3281      Parameter Reset Required
# 3282      Parameter Reset Required
# 0     Parameter Reset Not Required
# 1     Parameter Reset Not Required
# 265       Parameter Reset Required
# 266       Parameter Reset Required
# 267       Parameter Reset Required
# 268       Parameter Reset Required
# 269       Parameter Reset Required
# 270       Parameter Reset Required
# 271       Parameter Reset Required
# 272       Parameter Reset Required
# 273       Parameter Reset Required
# 274       Parameter Reset Required
# 275       Parameter Reset Required
# 276       Parameter Reset Required
# 277       Parameter Reset Required
# 278       Parameter Reset Required
# 279       Parameter Reset Required
# 280       Parameter Reset Required
# 281       Parameter Reset Required
# 282       Parameter Reset Required
# 283       Parameter Reset Required
# 284       Parameter Reset Required
# 285       Parameter Reset Required
# 286       Parameter Reset Required
# 287       Parameter Reset Required
# 288       Parameter Reset Required
# 289       Parameter Reset Required
# 290       Parameter Reset Required
#
#                                           PATS Type  \
# 190                                    PATS Type A
# 191                                    PATS Type A
# 247                                    PATS Type A
# 248                                    PATS Type A
# 249                                    PATS Type A
# 326                                    PATS Type B
# 327                                    PATS Type A
# 328                                    PATS Type B
# 329                                    PATS Type B
# 330                                    PATS Type B
# 331                                    PATS Type B
# 429                                    PATS Type E
# 430                                    PATS Type B
# 431                                    PATS Type C
# 432                                    PATS Type B
# 433                                    PATS Type B
# 434                                    PATS Type C
# 435                                    PATS Type C
# 436                                    PATS Type C
# 437                                    PATS Type B
# 438                                    PATS Type B
# 439                                    PATS Type C
# 547                                    PATS Type E
# 548                                    PATS Type B
# 549                                    PATS Type B
# 550                                    PATS Type C
# 551                                    PATS Type B
# 552                                    PATS Type B
# 553                                    PATS Type C
# 554                                    PATS Type C
# 555                                    PATS Type E
# 556                                    PATS Type C
# 557                                    PATS Type B
# 558                                    PATS Type E
# 559                                    PATS Type C
# 700                                    PATS Type B
# 701                                    PATS Type E
# 702                                    PATS Type B
# 703                                    PATS Type C
# 704                                    PATS Type B
# 705   Built July 23rd 2000 or Earlier: PATS Type B
# 706   Built July 23rd 2000 or Earlier: PATS Type B
# 707                                    PATS Type C
# 708                                    PATS Type C
# 709                                    PATS Type E
# 710                                    PATS Type C
# 711                                    PATS Type E
# 712                                    PATS Type E
# 713                                    PATS Type E
# 861                                    PATS Type B
# 862                                    PATS Type E
# 863                                    PATS Type B
# 864                                    PATS Type C
# 865                                    PATS Type E
# 866                                    PATS Type E
# 867                                    PATS Type E
# 868                                    PATS Type C
# 869                                    PATS Type C
# 870                                    PATS Type E
# 871                                    PATS Type C
# 872                                    PATS Type E
# 873                                    PATS Type E
# 874                                    PATS Type C
# 875                                    PATS Type E
# 1032                                   PATS Type E
# 1033                                   PATS Type E
# 1034                                   PATS Type B
# 1035                                   PATS Type E
# 1036                                   PATS Type E
# 1037                                   PATS Type E
# 1038                                   PATS Type E
# 1039                                   PATS Type C
# 1040                                   PATS Type C
# 1041                                   PATS Type E
# 1042                                   PATS Type C
# 1043                                   PATS Type E
# 1044                                   PATS Type E
# 1045                                   PATS Type C
# 1046                                   PATS Type E
# 1221                                   PATS Type E
# 1222                                   PATS Type E
# 1223                                   PATS Type B
# 1224                                   PATS Type E
# 1225                                   PATS Type E
# 1226                                   PATS Type E
# 1227                                   PATS Type E
# 1228                                   PATS Type C
# 1229                                   PATS Type E
# 1230                                   PATS Type E
# 1231                                   PATS Type C
# 1232                                   PATS Type E
# 1233                                   PATS Type E
# 1234                                   PATS Type C
# 1414                                   PATS Type E
# 1415                                   PATS Type E
# 1416                                   PATS Type B
# 1417                                   PATS Type E
# 1418                                   PATS Type E
# 1419                                   PATS Type E
# 1420                                   PATS Type E
# 1421                                   PATS Type C
# 1422                                   PATS Type E
# 1423                                   PATS Type E
# 1424                                   PATS Type E
# 1425                                   PATS Type E
# 1426                                   PATS Type B
# 1427                                   PATS Type E
# 1428                                  PATS Type NA
# 1429                                   PATS Type E
# 1430                                   PATS Type C
# 1601                                   PATS Type E
# 1602                                   PATS Type E
# 1603                                   PATS Type F
# 1604                                   PATS Type E
# 1605                                   PATS Type C
# 1606                                   PATS Type E
# 1607                                   PATS Type E
# 1608                                   PATS Type C
# 1609                                   PATS Type E
# 1610                                   PATS Type E
# 1611                                   PATS Type E
# 1612                                   PATS Type E
# 1613                                   PATS Type C
# 1614                                   PATS Type B
# 1615                                   PATS Type E
# 1616                                   PATS Type C
# 1617                                   PATS Type E
# 1618                                   PATS Type C
# 1823                                   PATS Type E
# 1824                                   PATS Type A
# 1825                                   PATS Type E
# 1826                                   PATS Type F
# 1827                                   PATS Type C
# 1828                                   PATS Type C
# 1829                                   PATS Type C
# 1830                                   PATS Type E
# 1831                                   PATS Type E
# 1832                                   PATS Type E
# 1833                                   PATS Type E
# 1834                                   PATS Type E
# 1835                                   PATS Type E
# 1836                                   PATS Type C
# 1837                                   PATS Type E
# 1838                                   PATS Type G
# 2067                                   PATS Type E
# 2068                                   PATS Type A
# 2069                   Fleet Vehicles: PATS Type G
# 2070                                   PATS Type C
# 2071                                   PATS Type C
# 2072                                   PATS Type C
# 2073                                   PATS Type E
# 2074                                   PATS Type E
# 2075                                   PATS Type G
# 2076                                   PATS Type C
# 2077                                   PATS Type C
# 2078                                   PATS Type C
# 2079                                   PATS Type E
# 2080                                   PATS Type G
# 2081                                   PATS Type C
# 2082                                   PATS Type C
# 2309                                   PATS Type E
# 2310                                   PATS Type A
# 2311                                   PATS Type C
# 2314                                   PATS Type C
# 2316                   Fleet Vehicles: PATS Type G
# 2317                                   PATS Type C
# 2318                                   PATS Type C
# 2319                                   PATS Type C
# 2320                                   PATS Type C
# 2321                                   PATS Type G
# 2322                                   PATS Type C
# 2323                                   PATS Type C
# 2324                                   PATS Type C
# 2325                                   PATS Type C
# 2326                                   PATS Type E
# 2327                                   PATS Type G
# 2328                                   PATS Type C
# 2329                                   PATS Type C
# 2558                                   PATS Type E
# 2559                                   PATS Type A
# 2560                                   PATS Type C
# 2562                                   PATS Type C
# 2563                   Fleet Vehicles: PATS Type G
# 2564                                   PATS Type C
# 2565                                   PATS Type C
# 2566                                   PATS Type C
# 2567                                   PATS Type C
# 2568                                   PATS Type G
# 2569                                   PATS Type C
# 2570                                   PATS Type C
# 2571                                   PATS Type C
# 2572                                   PATS Type C
# 2573                                   PATS Type C
# 2574                                   PATS Type C
# 2575                                   PATS Type G
# 2577                                   PATS Type A
# 2795                                   PATS Type E
# 2796                                   PATS Type B
# 2797                                   PATS Type C
# 2798                                   PATS Type C
# 2800                                   PATS Type C
# 2801                                   PATS Type A
# 2802                                   PATS Type C
# 2803                                   PATS Type B
# 2804                                   PATS Type B
# 2805                                   PATS Type B
# 2807                                   PATS Type C
# 2808                                   PATS Type C
# 2809                                   PATS Type C
# 2810                                   PATS Type C
# 2811                                   PATS Type C
# 2813                                   PATS Type A
# 3027                                   PATS Type E
# 3028                                   PATS Type B
# 3029                                   PATS Type C
# 3030                                   PATS Type C
# 3032                                   PATS Type C
# 3033                                   PATS Type A
# 3034                                   PATS Type C
# 3035                                   PATS Type B
# 3036                                   PATS Type B
# 3037                                   PATS Type B
# 3039                                   PATS Type C
# 3041                                   PATS Type C
# 3042                                   PATS Type C
# 3043                                   PATS Type C
# 3044                                   PATS Type C
# 3046                                   PATS Type A
# 3260                                   PATS Type B
# 3261                                   PATS Type C
# 3262                                   PATS Type B
# 3263                                   PATS Type C
# 3264                                   PATS Type B
# 3265                                   PATS Type C
# 3266                                   PATS Type A
# 3267                                   PATS Type C
# 3268                                   PATS Type B
# 3269                                   PATS Type B
# 3270                                   PATS Type B
# 3272                                   PATS Type B
# 3273                                   PATS Type C
# 3275                                   PATS Type C
# 3276                                   PATS Type B
# 3277                                   PATS Type B
# 3278                                   PATS Type B
# 3279                                   PATS Type C
# 3281                                   PATS Type A
# 3282                                   PATS Type B
# 0                                       PATS Type E
# 1                                       PATS Type A
# 265                                     PATS Type B
# 266                                     PATS Type E
# 267                                     PATS Type G
# 268                                     PATS Type G
# 269                                     PATS Type G
# 270                                     PATS Type C
# 271                                     PATS Type C
# 272                                     PATS Type C
# 273                                     PATS Type C
# 274                                     PATS Type C
# 275                                     PATS Type A
# 276                                     PATS Type C
# 277                                     PATS Type C
# 278                                     PATS Type C
# 279                                     PATS Type A
# 280                                     PATS Type C
# 281                                     PATS Type C
# 282                                     PATS Type C
# 283                                     PATS Type C
# 284                                     PATS Type C
# 285                                     PATS Type A
# 286                                     PATS Type C
# 287                                     PATS Type C
# 288                                     PATS Type C
# 289                                     PATS Type C
# 290                                     PATS Type C
#
#                                                                                  PATS Module Location
# 190                                                                           Stand Alone PATS Module
# 191                                                                           Stand Alone PATS Module
# 247                                                                           Stand Alone PATS Module
# 248                                                                           Stand Alone PATS Module
# 249                                                                           Stand Alone PATS Module
# 326                                                                           Stand Alone PATS Module
# 327                                                                           Stand Alone PATS Module
# 328                                                                           Stand Alone PATS Module
# 329                                                                           Stand Alone PATS Module
# 330                                                                           Stand Alone PATS Module
# 331                                                                           Stand Alone PATS Module
# 429                                                                         Powertrain Control Module
# 430                                                                           Stand Alone PATS Module
# 431                                                                                Instrument Cluster
# 432                                                                           Stand Alone PATS Module
# 433                                                                           Stand Alone PATS Module
# 434                                                                                Instrument Cluster
# 435                                                                                Instrument Cluster
# 436                                                                                Instrument Cluster
# 437                                                                           Stand Alone PATS Module
# 438                                                                           Stand Alone PATS Module
# 439                                                                                Instrument Cluster
# 547                                                                         Powertrain Control Module
# 548                                                                           Stand Alone PATS Module
# 549                                                                           Stand Alone PATS Module
# 550                                                                                Instrument Cluster
# 551                                                                           Stand Alone PATS Module
# 552                                                                           Stand Alone PATS Module
# 553                                                                                Instrument Cluster
# 554                                                                                Instrument Cluster
# 555                                                                         Powertrain Control Module
# ...
# 1614                                                                          Stand Alone PATS Module
# 1615                                                                        Powertrain Control Module
# 1616                                                                        Powertrain Control Module
# 1617                                                                        Powertrain Control Module
# 1618                                                                               Instrument Cluster
# 1823                                                                        Powertrain Control Module
# 1824                                                                               Instrument Cluster
# 1825                                                                        Powertrain Control Module
# 1826                                                                        Powertrain Control Module
# 1827                                                                               Instrument Cluster
# 1828                                                                               Instrument Cluster
# 1829                                                                               Instrument Cluster
# 1830                                                                        Powertrain Control Module
# 1831                                                                        Powertrain Control Module
# 1832                                                                        Powertrain Control Module
# 1833                                                                        Powertrain Control Module
# 1834                                                                        Powertrain Control Module
# 1835                                                                        Powertrain Control Module
# 1836                                                                               Instrument Cluster
# 1837                                                                        Powertrain Control Module
# 1838                                                                               Instrument Cluster
# 2067                                                                        Powertrain Control Module
# 2068                                                                               Instrument Cluster
# 2069                         Instrument Cluster)\nNon-Fleet Vehicles: PATS Type C (Instrument Cluster
# 2070                                                                               Instrument Cluster
# 2071                                                                               Instrument Cluster
# 2072                                                                               Instrument Cluster
# 2073                                                                        Powertrain Control Module
# 2074                                                                        Powertrain Control Module
# 2075                                                                               Instrument Cluster
# 2076                                                                               Instrument Cluster
# 2077                                                                               Instrument Cluster
# 2078                                                                               Instrument Cluster
# 2079                                                                        Powertrain Control Module
# 2080                                                                               Instrument Cluster
# 2081                                                                               Instrument Cluster
# 2082                                                                               Instrument Cluster
# 2309                                                                        Powertrain Control Module
# 2310                                                                               Instrument Cluster
# 2311                                                                               Instrument Cluster
# 2314                                                                               Instrument Cluster
# 2316                         Instrument Cluster)\nNon-Fleet Vehicles: PATS Type C (Instrument Cluster
# 2317                                                                               Instrument Cluster
# 2318                                                                               Instrument Cluster
# 2319                                                                               Instrument Cluster
# 2320                                                                               Instrument Cluster
# 2321                                                                               Instrument Cluster
# 2322                                                                               Instrument Cluster
# 2323                                                                               Instrument Cluster
# 2324                                                                               Instrument Cluster
# 2325                                                                               Instrument Cluster
# 2326                                                                        Powertrain Control Module
# 2327                                                                               Instrument Cluster
# 2328                                                                               Instrument Cluster
# 2329                                                                               Instrument Cluster
# 2558                                                                        Powertrain Control Module
# 2559                                                                               Instrument Cluster
# 2560                                                                               Instrument Cluster
# 2562                                                                               Instrument Cluster
# 2563                         Instrument Cluster)\nNon-Fleet Vehicles: PATS Type C (Instrument Cluster
# 2564                                                                               Instrument Cluster
# 2565                                                                               Instrument Cluster
# 2566                                                                               Instrument Cluster
# 2567                                                                               Instrument Cluster
# 2568                                                                               Instrument Cluster
# 2569                                                                               Instrument Cluster
# 2570                                                                               Instrument Cluster
# 2571                                                                               Instrument Cluster
# 2572                                                                               Instrument Cluster
# 2573                                                                               Instrument Cluster
# 2574                                                                               Instrument Cluster
# 2575                                                                               Instrument Cluster
# 2577                                                                               Instrument Cluster
# 2795                                                                        Powertrain Control Module
# 2796                                                                              Body Control Module
# 2797                                                Remote Function Actuator / Keyless Vehicle Module
# 2798                                                                               Instrument Cluster
# 2800                                                                               Instrument Cluster
# 2801                                                                               Instrument Cluster
# 2802                                                                               Instrument Cluster
# 2803                                                                              Body Control Module
# 2804                                                                              Body Control Module
# 2805                                                                              Body Control Module
# 2807                                                                               Instrument Cluster
# 2808                                                                               Instrument Cluster
# 2809                                                                               Instrument Cluster
# 2810                                                                               Instrument Cluster
# 2811                                                                               Instrument Cluster
# 2813                                                                               Instrument Cluster
# 3027                                                                        Powertrain Control Module
# 3028                                                                              Body Control Module
# 3029                                                Remote Function Actuator / Keyless Vehicle Module
# 3030                                                                               Instrument Cluster
# 3032                                                                               Instrument Cluster
# 3033                                                                               Instrument Cluster
# 3034                                                                               Instrument Cluster
# 3035                                                                              Body Control Module
# 3036                                                                              Body Control Module
# 3037                                                                              Body Control Module
# 3039                                                                               Instrument Cluster
# 3041                                                Remote Function Actuator / Keyless Vehicle Module
# 3042                                                                               Instrument Cluster
# 3043                                                                               Instrument Cluster
# 3044                                                                               Instrument Cluster
# 3046                                                                               Instrument Cluster
# 3260                                                                              Body Control Module
# 3261                                                Remote Function Actuator / Keyless Vehicle Module
# 3262                                                                              Body Control Module
# 3263                                                Remote Function Actuator / Keyless Vehicle Module
# 3264                                                                              Body Control Module
# 3265                                                Remote Function Actuator / Keyless Vehicle Module
# 3266                                                                               Instrument Cluster
# 3267                                                                               Instrument Cluster
# 3268                                                                              Body Control Module
# 3269                                                                              Body Control Module
# 3270                                                                              Body Control Module
# 3272                                                                              Body Control Module
# 3273                                                Remote Function Actuator / Keyless Vehicle Module
# 3275                                                Remote Function Actuator / Keyless Vehicle Module
# 3276                                                                              Body Control Module
# 3277                                                                              Body Control Module
# 3278                                                                              Body Control Module
# 3279                                                                               Instrument Cluster
# 3281                                                                               Instrument Cluster
# 3282                                                                              Body Control Module
# 0                                                                           Powertrain Control Module
# 1                                                                           Powertrain Control Module
# 265                                                                           Stand Alone PATS Module
# 266                                                                           Stand Alone PATS Module
# 267                                                                                Instrument Cluster
# 268                                                                                Instrument Cluster
# 269                                                                                Instrument Cluster
# 270                                                                                Instrument Cluster
# 271                                                                                Instrument Cluster
# 272                                                                                Instrument Cluster
# 273                                                                                Instrument Cluster
# 274                                                 Remote Function Actuator / Keyless Vehicle Module
# 275                                                                                Instrument Cluster
# 276                                                 Remote Function Actuator / Keyless Vehicle Module
# 277                                                                                Instrument Cluster
# 278                                                 Remote Function Actuator / Keyless Vehicle Module
# 279                                                                                Instrument Cluster
# 280                                                 Remote Function Actuator / Keyless Vehicle Module
# 281                                                                                Instrument Cluster
# 282                                                 Remote Function Actuator / Keyless Vehicle Module
# 283                                                                                Instrument Cluster
# 284                                                 Remote Function Actuator / Keyless Vehicle Module
# 285                                                                                Instrument Cluster
# 286                                                                                Instrument Cluster
# 287                                                                                Instrument Cluster
# 288                                                                                Instrument Cluster
# 289                                                                                Instrument Cluster
# 290                                                                                Instrument Cluster

# %%
# Filter only rows from make "Lincoln" to manipulate the data
df_lincoln = df[df['Make'] == 'Lincoln']

# %%
# Split column 'Security' between 2 columns, where one column shows the PATS Type and the other one shows the PATS module location
df_lincoln[['PATS Type', 'PATS Module Location']] = df_lincoln['Security'].str.split('(', n=1, expand=True)
# Out:
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_28448\2886703368.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lincoln[['PATS Type', 'PATS Module Location']] = df_lincoln['Security'].str.split('(', n=1, expand=True)
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_28448\2886703368.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lincoln[['PATS Type', 'PATS Module Location']] = df_lincoln['Security'].str.split('(', n=1, expand=True)

# %%
# Drop column security as its values were split in 2 columns
df_lincoln_new = df_lincoln.drop(columns=['Security'])

# %%
# Remove the ')' that remained at the values of the column 'PATS Module Location'
df_lincoln_new['PATS Module Location'] = df_lincoln_new['PATS Module Location'].str.strip(')')

# %%
# The model 'Keyed Ignition:' and 'Push To Start:' confuguration are located in the same rows.
# Identifies which rows have the strings 'Keyed Ignition:' and 'Push To Start:' to separate them in 2 rows.
# Iterates in the column 'PATS Type' and bring the rows which contains the strings 'Keyed Ignition:'
for index, row in df_lincoln_new.iterrows():
    if 'Keyed Ignition:' in row['PATS Type']:
        print(row)
# Out:
# Year                                                                                                                  2009
# Make                                                                                                               Lincoln
# Model                                                                                                                  MKS
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 2384, dtype: object
# Year                                                                                                                  2010
# Make                                                                                                               Lincoln
# Model                                                                                                                  MKS
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 2630, dtype: object
# Year                                                                                                                  2011
# Make                                                                                                               Lincoln
# Model                                                                                                                  MKS
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 2862, dtype: object
# Year                                                                                                                  2012
# Make                                                                                                               Lincoln
# Model                                                                                                                  MKS
# ParameterReset                                                                                    Parameter Reset Required
# PATS Type                                                                                     Keyed Ignition: PATS Type C
# PATS Module Location    Instrument Cluster)\nPush To Start: PATS Type C (Remote Function Actuator / Keyless Vehicle Module
# Name: 3098, dtype: object

# %%
# Separate in 2 lines the 'Keyed Ignition' configuration and 'Push To Start" configuration.
df_lincoln_new.loc[len(df_lincoln_new.index)] = [2009, 'Lincoln', 'MKS (Keyed Ignition)', 'Parameter Reset Required', 'PATS Type C', 'Instrument Cluster']
df_lincoln_new.loc[len(df_lincoln_new.index)] = [2009, 'Lincoln', 'MKS (Push To Start)', 'Parameter Reset Required', 'PATS Type C', 'Remote Function Actuator / Keyless Vehicle Module']
df_lincoln_new.loc[len(df_lincoln_new.index)] = [2010, 'Lincoln', 'MKS (Keyed Ignition)', 'Parameter Reset Required', 'PATS Type C', 'Instrument Cluster']
df_lincoln_new.loc[len(df_lincoln_new.index)] = [2010, 'Lincoln', 'MKS (Push To Start)', 'Parameter Reset Required', 'PATS Type C', 'Remote Function Actuator / Keyless Vehicle Module']
df_lincoln_new.loc[len(df_lincoln_new.index)] = [2011, 'Lincoln', 'MKS (Keyed Ignition)', 'Parameter Reset Required', 'PATS Type C', 'Instrument Cluster']
df_lincoln_new.loc[len(df_lincoln_new.index)] = [2011, 'Lincoln', 'MKS (Push To Start)', 'Parameter Reset Required', 'PATS Type C', 'Remote Function Actuator / Keyless Vehicle Module']
df_lincoln_new.loc[len(df_lincoln_new.index)] = [2012, 'Lincoln', 'MKS (Keyed Ignition)', 'Parameter Reset Required', 'PATS Type C', 'Instrument Cluster']
df_lincoln_new.loc[len(df_lincoln_new.index)] = [2012, 'Lincoln', 'MKS (Push To Start)', 'Parameter Reset Required', 'PATS Type C', 'Remote Function Actuator / Keyless Vehicle Module']

# %%
# Iterate in the new data (after new lines included) to get all index numbers containing the string 'Keyed Ignition'
for index, row in df_lincoln_new.iterrows():
    if 'Keyed Ignition' in row['PATS Type']:
        print(index)
# Out:
# 2384
# 2630
# 2862
# 3098

# %%
# Drop all old rows after splitting between 'keyed ignition' and 'push to start' configuration
df_lincoln_new.drop([2384, 2630, 2862, 3098])
# Out:
#       Year     Make                 Model                ParameterReset  \
# 267   1997  Lincoln             Mark VIII  Parameter Reset Not Required
# 360   1998  Lincoln           Continental      Parameter Reset Required
# 361   1998  Lincoln             Mark VIII  Parameter Reset Not Required
# 362   1998  Lincoln             Navigator  Parameter Reset Not Required
# 363   1998  Lincoln              Town Car      Parameter Reset Required
# 466   1999  Lincoln           Continental      Parameter Reset Required
# 467   1999  Lincoln             Navigator      Parameter Reset Required
# 468   1999  Lincoln              Town Car      Parameter Reset Required
# 593   2000  Lincoln           Continental      Parameter Reset Required
# 594   2000  Lincoln                    LS      Parameter Reset Required
# 595   2000  Lincoln             Navigator      Parameter Reset Required
# 596   2000  Lincoln              Town Car      Parameter Reset Required
# 748   2001  Lincoln           Continental      Parameter Reset Required
# 749   2001  Lincoln                    LS      Parameter Reset Required
# 750   2001  Lincoln             Navigator      Parameter Reset Required
# 751   2001  Lincoln              Town Car      Parameter Reset Required
# 912   2002  Lincoln             Blackwood      Parameter Reset Required
# 913   2002  Lincoln           Continental      Parameter Reset Required
# 914   2002  Lincoln                    LS      Parameter Reset Required
# 915   2002  Lincoln             Navigator      Parameter Reset Required
# 916   2002  Lincoln              Town Car      Parameter Reset Required
# 1092  2003  Lincoln               Aviator  Parameter Reset Not Required
# 1093  2003  Lincoln             Blackwood      Parameter Reset Required
# 1094  2003  Lincoln                    LS      Parameter Reset Required
# 1095  2003  Lincoln             Navigator  Parameter Reset Not Required
# 1096  2003  Lincoln              Town Car  Parameter Reset Not Required
# 1281  2004  Lincoln               Aviator  Parameter Reset Not Required
# 1282  2004  Lincoln                    LS      Parameter Reset Required
# 1283  2004  Lincoln             Navigator  Parameter Reset Not Required
# 1284  2004  Lincoln              Town Car  Parameter Reset Not Required
# 1476  2005  Lincoln               Aviator  Parameter Reset Not Required
# 1477  2005  Lincoln                    LS      Parameter Reset Required
# 1478  2005  Lincoln             Navigator  Parameter Reset Not Required
# 1479  2005  Lincoln              Town Car  Parameter Reset Not Required
# 1663  2006  Lincoln                    LS      Parameter Reset Required
# 1664  2006  Lincoln               Mark LT  Parameter Reset Not Required
# 1665  2006  Lincoln             Navigator  Parameter Reset Not Required
# 1666  2006  Lincoln              Town Car  Parameter Reset Not Required
# 1667  2006  Lincoln                Zephyr      Parameter Reset Required
# 1892  2007  Lincoln                    LS      Parameter Reset Required
# 1893  2007  Lincoln               Mark LT  Parameter Reset Not Required
# 1894  2007  Lincoln                   MKX      Parameter Reset Required
# 1895  2007  Lincoln                   MKZ      Parameter Reset Required
# 1896  2007  Lincoln             Navigator      Parameter Reset Required
# 1897  2007  Lincoln              Town Car  Parameter Reset Not Required
# 2135  2008  Lincoln                   MKS                           NaN
# 2136  2008  Lincoln               Mark LT  Parameter Reset Not Required
# 2137  2008  Lincoln                   MKX      Parameter Reset Required
# 2138  2008  Lincoln                   MKZ      Parameter Reset Required
# 2139  2008  Lincoln             Navigator      Parameter Reset Required
# 2140  2008  Lincoln              Town Car  Parameter Reset Not Required
# 2383  2009  Lincoln                   MKT                           NaN
# 2385  2009  Lincoln                   MKX      Parameter Reset Required
# 2386  2009  Lincoln                   MKZ      Parameter Reset Required
# 2387  2009  Lincoln             Navigator      Parameter Reset Required
# 2388  2009  Lincoln              Town Car  Parameter Reset Not Required
# 2631  2010  Lincoln                   MKT      Parameter Reset Required
# 2632  2010  Lincoln                   MKX      Parameter Reset Required
# 2633  2010  Lincoln                   MKZ      Parameter Reset Required
# 2634  2010  Lincoln             Navigator      Parameter Reset Required
# 2635  2010  Lincoln              Town Car  Parameter Reset Not Required
# 2863  2011  Lincoln                   MKT      Parameter Reset Required
# 2864  2011  Lincoln                   MKX      Parameter Reset Required
# 2865  2011  Lincoln                   MKZ      Parameter Reset Required
# 2866  2011  Lincoln             Navigator      Parameter Reset Required
# 2867  2011  Lincoln              Town Car  Parameter Reset Not Required
# 3099  2012  Lincoln                   MKT      Parameter Reset Required
# 3100  2012  Lincoln                   MKX      Parameter Reset Required
# 3101  2012  Lincoln                   MKZ      Parameter Reset Required
# 3102  2012  Lincoln             Navigator      Parameter Reset Required
# 3332  2013  Lincoln                   MKS      Parameter Reset Required
# 3333  2013  Lincoln                   MKT      Parameter Reset Required
# 3334  2013  Lincoln                   MKX      Parameter Reset Required
# 3335  2013  Lincoln   MKZ (Push to Start)      Parameter Reset Required
# 3336  2013  Lincoln             Navigator      Parameter Reset Required
# 79    2009  Lincoln  MKS (Keyed Ignition)      Parameter Reset Required
# 80    2009  Lincoln   MKS (Push To Start)      Parameter Reset Required
# 81    2010  Lincoln  MKS (Keyed Ignition)      Parameter Reset Required
# 82    2010  Lincoln   MKS (Push To Start)      Parameter Reset Required
# 83    2011  Lincoln  MKS (Keyed Ignition)      Parameter Reset Required
# 84    2011  Lincoln   MKS (Push To Start)      Parameter Reset Required
# 85    2012  Lincoln  MKS (Keyed Ignition)      Parameter Reset Required
# 86    2012  Lincoln   MKS (Push To Start)      Parameter Reset Required
#
#          PATS Type                               PATS Module Location
# 267   PATS Type D                Steering Column Ignition Lock Module
# 360   PATS Type C                                  Instrument Cluster
# 361   PATS Type D                Steering Column Ignition Lock Module
# 362   PATS Type A                             Stand Alone PATS Module
# 363   PATS Type C                                  Instrument Cluster
# 466   PATS Type C                                  Instrument Cluster
# 467   PATS Type C                                  Instrument Cluster
# 468   PATS Type C                                  Instrument Cluster
# 593   PATS Type C                                  Instrument Cluster
# 594   PATS Type C                                  Instrument Cluster
# 595   PATS Type C                                  Instrument Cluster
# 596   PATS Type C                                  Instrument Cluster
# 748   PATS Type C                                  Instrument Cluster
# 749   PATS Type C                                  Instrument Cluster
# 750   PATS Type C                                  Instrument Cluster
# 751   PATS Type C                                  Instrument Cluster
# 912   PATS Type C                                  Instrument Cluster
# 913   PATS Type C                                  Instrument Cluster
# 914   PATS Type C                                  Instrument Cluster
# 915   PATS Type C                                  Instrument Cluster
# 916   PATS Type C                                  Instrument Cluster
# 1092  PATS Type E                           Powertrain Control Module
# 1093  PATS Type C                                  Instrument Cluster
# 1094  PATS Type C                                  Instrument Cluster
# 1095  PATS Type E                           Powertrain Control Module
# 1096  PATS Type E                           Powertrain Control Module
# 1281  PATS Type E                           Powertrain Control Module
# 1282  PATS Type C                                  Instrument Cluster
# 1283  PATS Type E                           Powertrain Control Module
# 1284  PATS Type E                           Powertrain Control Module
# 1476  PATS Type E                           Powertrain Control Module
# 1477  PATS Type C                                  Instrument Cluster
# 1478  PATS Type E                           Powertrain Control Module
# 1479  PATS Type E                           Powertrain Control Module
# 1663  PATS Type C                                  Instrument Cluster
# 1664  PATS Type E                           Powertrain Control Module
# 1665  PATS Type E                           Powertrain Control Module
# 1666  PATS Type E                           Powertrain Control Module
# 1667  PATS Type C                                  Instrument Cluster
# 1892  PATS Type C                                  Instrument Cluster
# 1893  PATS Type E                           Powertrain Control Module
# 1894  PATS Type C                                  Instrument Cluster
# 1895  PATS Type C                                  Instrument Cluster
# 1896  PATS Type C                                  Instrument Cluster
# 1897  PATS Type E                           Powertrain Control Module
# 2135   New in 2009                                               None
# 2136  PATS Type E                           Powertrain Control Module
# 2137  PATS Type C                                  Instrument Cluster
# 2138  PATS Type C                                  Instrument Cluster
# 2139  PATS Type C                                  Instrument Cluster
# 2140  PATS Type E                           Powertrain Control Module
# 2383   New in 2010                                               None
# 2385  PATS Type C                                  Instrument Cluster
# 2386  PATS Type C                                  Instrument Cluster
# 2387  PATS Type C                                  Instrument Cluster
# 2388  PATS Type E                           Powertrain Control Module
# 2631  PATS Type C   Remote Function Actuator / Keyless Vehicle Module
# 2632  PATS Type C                                  Instrument Cluster
# 2633  PATS Type C                                  Instrument Cluster
# 2634  PATS Type C                                  Instrument Cluster
# 2635  PATS Type E                           Powertrain Control Module
# 2863  PATS Type C   Remote Function Actuator / Keyless Vehicle Module
# 2864  PATS Type C   Remote Function Actuator / Keyless Vehicle Module
# 2865  PATS Type C                                  Instrument Cluster
# 2866  PATS Type C                                  Instrument Cluster
# 2867  PATS Type E                           Powertrain Control Module
# 3099  PATS Type C   Remote Function Actuator / Keyless Vehicle Module
# 3100  PATS Type C   Remote Function Actuator / Keyless Vehicle Module
# 3101  PATS Type C                                  Instrument Cluster
# 3102  PATS Type C                                  Instrument Cluster
# 3332  PATS Type C   Remote Function Actuator / Keyless Vehicle Module
# 3333  PATS Type C   Remote Function Actuator / Keyless Vehicle Module
# 3334  PATS Type C   Remote Function Actuator / Keyless Vehicle Module
# 3335  PATS Type B                                 Body Control Module
# 3336  PATS Type C                                  Instrument Cluster
# 79     PATS Type C                                 Instrument Cluster
# 80     PATS Type C  Remote Function Actuator / Keyless Vehicle Module
# 81     PATS Type C                                 Instrument Cluster
# 82     PATS Type C  Remote Function Actuator / Keyless Vehicle Module
# 83     PATS Type C                                 Instrument Cluster
# 84     PATS Type C  Remote Function Actuator / Keyless Vehicle Module
# 85     PATS Type C                                 Instrument Cluster
# 86     PATS Type C  Remote Function Actuator / Keyless Vehicle Module

# %%
# Concatenate both new dataframes after manipulating the data and making some changes
df_lincoln_updated = pd.concat([df_lincoln_new, df_lincoln_new])

# %%
# Filter the df by based on the Mercury into a varible to analyse a manipulate the data
df_mercury = df[df['Make'] == 'Mercury']

# %%
# Split the 'Security' column in 2 columns to separate the Pats module location and the pats type
df_mercury[['PATS Type', 'PATS Module Location']] = df_mercury['Security'].str.split('(', n=1, expand=True)
# Out:
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_28448\3965777578.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mercury[['PATS Type', 'PATS Module Location']] = df_mercury['Security'].str.split('(', n=1, expand=True)
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_28448\3965777578.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mercury[['PATS Type', 'PATS Module Location']] = df_mercury['Security'].str.split('(', n=1, expand=True)

# %%
# Remove the caractere ')' from all rows in the column 'PATS Module Location'
df_mercury['PATS Module Location'] = df_mercury['PATS Module Location'].str.strip(')')
# Out:
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_28448\4086986821.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mercury['PATS Module Location'] = df_mercury['PATS Module Location'].str.strip(')')

# %%
# Drop the column 'Security'. The info split into 2 columns
df_mercury_dropped_security = df_mercury.drop(columns=['Security'])

# %% [markdown]
# Only the index 370 model Mystique (V-6 only) should be split in 2 columns. Models built February 1st 1998 or Earlier are equipped with PATS Type A and the models Built February 2nd 1998 or Later, are equipped with PATS Type E. Also, the module location are different as well.

# %%
# Add 2 lines to separate the model 'Mystique (V-6 only)' in 2 rows: built < February 1st 1998 or Earlier and built > February 2nd 1998 or Later   Contour (V6-only) / Built >= February 2st
df_mercury_dropped_security.loc[len(df_mercury.index)] = [1998, 'Mercury', 'Mystique (V-6 only) / Built <= February 1st', 'Parameter Reset Not Required', 'PATS Type A', 'Stand Alone PATS Module']
df_mercury_dropped_security.loc[len(df_mercury.index)] = [1998, 'Mercury', 'Mystique (V-6 only) / Built >= February 2nd', 'Parameter Reset Not Required', 'PATS Type E', 'Powertrain Control Module']

# %%
# Drop index 370 containing the old info
df_mercury_updated = df_mercury_dropped_security.drop([370])

# %%
# Filter the Mazda and store into a variable
df_mazda = df[df['Make'] == 'Mazda']

# %%
# Create a list to store the rows with caractere \n
mazda_caractere_list = []
# Create a list to store the indexes to be removed 
mazda_caractere_index_list = []

# Loop in the lines of the df_mazda to find the caractere \n
for index, row in df_mazda.iterrows():
    # Condition when finding '\n' in the rows of column 'Security'
    if '\n' in row['Security']:
        # Store the rows with the said caractere in the list 
        mazda_caractere_list.append(row)
        # Store the indexes numbers containing the said caractere
        mazda_caractere_index_list.append(index)

# Change 'mazda_caractere_list' to dataframe
df_mazda_w_caract = pd.DataFrame(mazda_caractere_list)

# %%
# Check if the df is correct
df_mazda_w_caract.head()
# Out:
#       Year   Make         Model  \
# 1670  2006  Mazda        Mazda6
# 1672  2006  Mazda  MX-5 (Miata)
# 1673  2006  Mazda          RX-8
# 1899  2007  Mazda          CX-7
# 1900  2007  Mazda          CX-9
#
#                                                                                  Security  \
# 1670                                           Keyed Ignition: M-B\nAdvanced Keyless: M-D
# 1672  Advanced Keyless Entry w/ Keyless Start): M-D\nKeyless Entry w/ Keyed Ignition: M-C
# 1673                                           Keyed Ignition: M-C\nAdvanced Keyless: M-D
# 1899                                            Keyed Ignition: M-C\nAdvanced Keyless: MD
# 1900                                           Keyed Ignition: M-C\nAdvanced Keyless: M-D
#
#                     ParameterReset
# 1670  Parameter Reset Not Required
# 1672      Parameter Reset Required
# 1673      Parameter Reset Required
# 1899      Parameter Reset Required
# 1900      Parameter Reset Required

# %%
# Split the security types in 2 lines (keeping year/model), using the caractere '\n' as delimiter
df_mazda_w_caract = df_mazda_w_caract.assign(Security=df_mazda_w_caract['Security'].str.split('\n')).explode('Security')

# %%
# Clear the df_mazda by removing the rows containing the caractere '\n' based on the index list
df_mazda = df_mazda.drop(index=mazda_caractere_index_list)

# %%
# Concatenate the dataframe after splitting lines with the main df_mazda
df_mazda_updated = pd.concat([df_mazda_w_caract, df_mazda])

# %%
# Sort the dataframe using the column 'Year' and reset index
df_mazda_updated = df_mazda_updated.sort_values(['Year']).reset_index().drop(columns=['index'])

# %%
# Explode column 'Security' to create new lines
# df_mazda_updated = df_mazda.explode('Security')

# %%
# Create a new dataframe containing only Chevrolet: 'Chevrolet', 'Pontiac', 'Cadillac', 'Buick', 'Oldsmobile', 'GMC', 'Saturn', 'Hummer'
chevrolet_list = ['Chevrolet', 'Pontiac', 'Cadillac', 'Buick', 'Oldsmobile', 'GMC', 'Saturn', 'Hummer']

# %%
# Create a dataframe containing only chevrolet brands 
df_chevrolet = df[df['Make'].isin(chevrolet_list)]

# %%
df_chevrolet
# Out:
#       Year       Make         Model         Security ParameterReset
# 0     1986  Chevrolet      Corvette             VATS            NaN
# 1     1987  Chevrolet      Corvette             VATS            NaN
# 2     1988  Chevrolet      Corvette             VATS            NaN
# 3     1988    Pontiac      Firebird        GTA\nonly            NaN
# 4     1989   Cadillac       Allante              PK1            NaN
# ...    ...        ...           ...              ...            ...
# 3284  2013        GMC        Savana             PK3+            NaN
# 3285  2013        GMC        Sierra             PK3+            NaN
# 3286  2013        GMC      Yukon XL             PK3+            NaN
# 3287  2013        GMC  Yukon/Denali             PK3+            NaN
# 3288  2013        GMC       Terrain  PK3+\nSmart Key            NaN
#
# [663 rows x 5 columns]

# %%
# Drop the column 'ParameterReset' as it is not applicable to Chevrolet
df_chevrolet_dropped_column = df_chevrolet.drop(columns=['ParameterReset'])

# %%
# Rename column 'Security'
df_chevrolet_dropped_column.rename(columns={'Security': 'Security Type'})
# Out:
#       Year       Make         Model    Security Type
# 0     1986  Chevrolet      Corvette             VATS
# 1     1987  Chevrolet      Corvette             VATS
# 2     1988  Chevrolet      Corvette             VATS
# 3     1988    Pontiac      Firebird        GTA\nonly
# 4     1989   Cadillac       Allante              PK1
# ...    ...        ...           ...              ...
# 3284  2013        GMC        Savana             PK3+
# 3285  2013        GMC        Sierra             PK3+
# 3286  2013        GMC      Yukon XL             PK3+
# 3287  2013        GMC  Yukon/Denali             PK3+
# 3288  2013        GMC       Terrain  PK3+\nSmart Key
#
# [663 rows x 4 columns]

# %% [markdown]
# A column name 'Is this hardware clonable' will be included in the Chevrolet dataframe to show which hardwares are clonable based on the part number. As the hardware part numbers are not available and their values will need to be added manually, these are the next steps to add the hardware part numbers:
# 1. Download the 'df_chevrolet_dropped_column' in excel format.
# 2. Add the hardware part numbers manually from the GM compatibility chart.
# 3. Fill out the column 'Is this hardware clonable' rows comparing the 'df_chevrolet_dropped_column' with the 'List of Cloneable Modules'.

# %%
# Download the dateframe 'chevrolet_list_filtered' in xlsx format and name the file 'chevrolet_hardware_list
# df_chevrolet_dropped_column.to_excel('chevrolet_hardware_list.xlsx', index=False)

# %%
# Load the xlsx file containing the dataframe after adding the hardware part numbers
df_chevrolet = pd.read_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\data\chevrolet_hardware_list.xlsx')
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\L'
# <>:2: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_28448\394097893.py:2: SyntaxWarning: invalid escape sequence '\L'
#   df_chevrolet = pd.read_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\data\chevrolet_hardware_list.xlsx')

# %%
df_chevrolet.head()
# Out:
#    Year       Make     Model   Security       hardware_part_number
# 0  1986  Chevrolet  Corvette       VATS  Information not available
# 1  1987  Chevrolet  Corvette       VATS  Information not available
# 2  1988  Chevrolet  Corvette       VATS  Information not available
# 3  1988    Pontiac  Firebird  GTA\nonly  Information not available
# 4  1989   Cadillac   Allante        PK1  Information not available

# %%
# Load the xlsx file containing the clonable hardware part numbers   
list_clonable_modules = pd.read_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\data\List of Clonable Modules.xlsx')
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\L'
# <>:2: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_28448\1625161208.py:2: SyntaxWarning: invalid escape sequence '\L'
#   list_clonable_modules = pd.read_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\data\List of Clonable Modules.xlsx')

# %%
# Show all columns of the dataframe
list_clonable_modules.columns
# Out:
# Index(['Cloning Tools', 'ECM Hardware', 'cloning_status', 'ECU Brand', 'Year',
#        'Year/Model/Engine Size/HP', 'Manufacturer', 'Vehicle Type', 'Notes'],
#       dtype='object')

# %%
# Drop most columns and leave only 2 columns named: 'ECM Hardware' and 'cloning_status' and store in a variable
list_clonable_modules_updated = list_clonable_modules.drop(columns=['Cloning Tools', 'ECU Brand', 'Year', 'Year/Model/Engine Size/HP', 'Manufacturer', 'Vehicle Type', 'Notes'])

# %%
# Print the first rows on the dataframe updated
list_clonable_modules_updated.head()
# Out:
#   ECM Hardware      cloning_status
# 0     E83 (GM)  Currently possible
# 1     E78 (GM)  Currently possible
# 2     E87 (GM)  Currently possible
# 3     E39 (GM)  Currently possible
# 4    E39A (GM)  Currently possible

# %%
# Filter the hardware pn# that can be clonable
list_clonable_modules_filtered = list_clonable_modules_updated[list_clonable_modules_updated['cloning_status'] == 'Currently possible']

# %%
# Create a list to store the hardwares prefixes got from the clonable list
clonable_modules_list = []

# Iterate in the column 'ECM Hardware' to get their prefixes
for part_number in list_clonable_modules_filtered['ECM Hardware']:
    ecm_hardware_prefix = part_number.split(' ')[0]
    clonable_modules_list.append(ecm_hardware_prefix)

# %%
# Print the last rows on the dataframe containing the hardware part number values
df_chevrolet.tail()
# Out:
#      Year Make         Model         Security       hardware_part_number
# 657  2013  GMC        Savana             PK3+                    E38-AK8
# 658  2013  GMC        Sierra             PK3+                    E86-A24
# 659  2013  GMC      Yukon XL             PK3+  Information not available
# 660  2013  GMC  Yukon Denali             PK3+                    E38-AK8
# 661  2013  GMC       Terrain  PK3+\nSmart Key                  E39A-H98S

# %%
# Create a list to store hardware prefixes
hardware_prefix_list = []

# Iterate into the main dataframe to get the prefixes 
for hardware_pn in df_chevrolet['hardware_part_number']:
    hardware_prefix = hardware_pn.split('-')[0] # [0] indicates the first part of the list where the string needed is located, eg: 'E39', 'E38', etc.
    hardware_prefix_list.append(hardware_prefix)
    
# Add a new column contaning the prefixes
df_chevrolet['hardware_prefix'] = hardware_prefix_list

# %%
# Create a list to store the the string "Yes" or "No"
hardware_clonable_list = []
# Variable containing the string "Yes" to be used when a given part number is in the clonable_modules_list
yes_clonable = 'Yes'
# Variable containing the string "No" to be used when a given part number IS NOT in the clonable_modules_list
not_clonable = 'No'
# Loop in the 'hardware_prefix' column to check whether or not the part numbers are clonable 
for hardware_pn in df_chevrolet['hardware_prefix']:
    if hardware_pn in clonable_modules_list:
        hardware_clonable_list.append(yes_clonable)
    else:
        hardware_clonable_list.append(not_clonable)

# Create a new column after confirming the part numbers are clonable or not 
df_chevrolet['Is this hardware clonable?'] = hardware_clonable_list

# %%
# Drop column 'hardware_prefix' as it was used only to confirm the clonable hardwares
df_chevrolet_dropped_hardwarepre = df_chevrolet.drop(columns='hardware_prefix')

# %% [markdown]
# * CREATING SEPARATE DATAFRAMES FOR EACH MAKE:
#
# The intended application will use the streamlit library to show the makes available and their security system information. As most makes have different security system and information-related, it is needed to create separate Dataframes for all/most of them.
#
# For instance, Ford vehicles requires parameter reset and there is a column showing whether or not this procedure is required. However, Chevrolet vehicles requires a different procedure and some hardwares can be cloned. That is, Ford and Chevrolet vehicles do not match the security information-related. The solution for this will be to create separate Dataframes for all makes.

# %%
# Show all makes under Chevrolet and use this list to guide when creating separate Dataframes
df_chevrolet_dropped_hardwarepre['Make'].unique()
# Out:
# array(['Chevrolet', 'Pontiac', 'Cadillac', 'Buick', 'Oldsmobile', 'GMC',
#        'Saturn', 'Hummer'], dtype=object)

# %%
# Rename the column 'hardware_part_number' to 'Hardware Part Number'
df_chevrolet_renamed_column = df_chevrolet_dropped_hardwarepre.rename(columns={'hardware_part_number':'Hardware Part Number'})

# %%
# Create a dataframe only with Make: Chevrolet
df_chevy_filtered = df_chevrolet_renamed_column[df_chevrolet_renamed_column['Make'] == 'Chevrolet']

# %%
# Check is the df is ok
df_chevy_filtered.tail()
# Out:
#      Year       Make   Model         Security Hardware Part Number  \
# 651  2013  Chevrolet  Malibu  PK3+\nSmart Key            E39A-H98S
# 652  2013  Chevrolet   Sonic  PK3+\nSmart Key              E78-AB8
# 653  2013  Chevrolet   Spark  PK3+\nSmart Key                  E83
# 654  2013  Chevrolet   Cruze  PK3+\nSmart Key              E78-AB8
# 655  2013  Chevrolet    Volt  PK3+\nSmart Key              E78-AB8
#
#     Is this hardware clonable?
# 651                        Yes
# 652                        Yes
# 653                        Yes
# 654                        Yes
# 655                        Yes

# %%
# Create a dataframe only with Make: Pontiac
df_pontiac = df_chevrolet_renamed_column[df_chevrolet_renamed_column['Make'] == 'Pontiac']

# %%
# Check is the df is ok
df_pontiac.tail()
# Out:
#      Year     Make     Model             Security       Hardware Part Number  \
# 514  2009  Pontiac      Vibe  Toyota\nImmobilizer  Information not available
# 554  2010  Pontiac        G3                  Opt  Information not available
# 555  2010  Pontiac        G6                 PK3+  Information not available
# 556  2010  Pontiac        G8                 PK3+  Information not available
# 557  2010  Pontiac  Solstice                 PK3+  Information not available
#
#     Is this hardware clonable?
# 514                         No
# 554                         No
# 555                         No
# 556                         No
# 557                         No

# %%
# Create a dataframe only with Make: Cadillac
df_cadillac = df_chevrolet_renamed_column[df_chevrolet_renamed_column['Make'] == 'Cadillac']

# %%
# Check is the df is ok
df_cadillac.tail()
# Out:
#      Year      Make         Model         Security       Hardware Part Number  \
# 634  2013  Cadillac  Escalade ESV             PK3+  Information not available
# 635  2013  Cadillac           ATS  PK3+\nSmart Key                  E39A-H98S
# 636  2013  Cadillac           SRX  PK3+\nSmart Key                  E39A-H98S
# 637  2013  Cadillac           XTS  PK3+\nSmart Key                  E39A-H98S
# 638  2013  Cadillac           CTS          PK3+/KA                   E39-X94S
#
#     Is this hardware clonable?
# 634                         No
# 635                        Yes
# 636                        Yes
# 637                        Yes
# 638                        Yes

# %%
# Create a dataframe only with Make: Buick
df_buick = df_chevrolet_renamed_column[df_chevrolet_renamed_column['Make'] == 'Buick']

# %%
# Check is the df is ok
df_buick.tail()
# Out:
#      Year   Make     Model         Security Hardware Part Number  \
# 628  2013  Buick   Enclave             PK3+            E39A-H98S
# 629  2013  Buick    Encore  PK3+\nSmart Key              E78-AB8
# 630  2013  Buick  LaCrosse  PK3+\nSmart Key            E39A-H98S
# 631  2013  Buick     Regal  PK3+\nSmart Key            E39A-H98S
# 632  2013  Buick    Verano  PK3+\nSmart Key             E39-X94S
#
#     Is this hardware clonable?
# 628                        Yes
# 629                        Yes
# 630                        Yes
# 631                        Yes
# 632                        Yes

# %%
# Create a dataframe only with Make: Oldsmobile
df_oldsmobile = df_chevrolet_renamed_column[df_chevrolet_renamed_column['Make'] == 'Oldsmobile']

# %%
# Check is the df is ok
df_oldsmobile.tail()
# Out:
#      Year        Make       Model Security Hardware Part Number  \
# 237  2003  Oldsmobile       Alero      PL2             U44C-482
# 238  2003  Oldsmobile     Bravada      PL2                  P10
# 272  2004  Oldsmobile  Silhouette      PK3             U44C-721
# 273  2004  Oldsmobile       Alero      PL2             U44C-721
# 274  2004  Oldsmobile     Bravada      PL2                  P10
#
#     Is this hardware clonable?
# 237                         No
# 238                         No
# 272                         No
# 273                         No
# 274                         No

# %%
# Create a dataframe only with Make: GMC
df_gmc = df_chevrolet_renamed_column[df_chevrolet_renamed_column['Make'] == 'GMC']

# %%
# Check is the df is ok
df_gmc.tail()
# Out:
#      Year Make         Model         Security       Hardware Part Number  \
# 657  2013  GMC        Savana             PK3+                    E38-AK8
# 658  2013  GMC        Sierra             PK3+                    E86-A24
# 659  2013  GMC      Yukon XL             PK3+  Information not available
# 660  2013  GMC  Yukon Denali             PK3+                    E38-AK8
# 661  2013  GMC       Terrain  PK3+\nSmart Key                  E39A-H98S
#
#     Is this hardware clonable?
# 657                        Yes
# 658                         No
# 659                         No
# 660                        Yes
# 661                        Yes

# %%
# Create a dataframe only with Make: Saturn
df_saturn = df_chevrolet_renamed_column[df_chevrolet_renamed_column['Make'] == 'Saturn']

# %%
# Check is the df is ok
df_saturn.tail()
# Out:
#      Year    Make    Model Security       Hardware Part Number  \
# 519  2009  Saturn      Vue     PK3+                    E67-TP1
# 558  2010  Saturn     Aura     PK3+  Information not available
# 559  2010  Saturn  Outlook     PK3+  Information not available
# 560  2010  Saturn      Sky     PK3+  Information not available
# 561  2010  Saturn      Vue     PK3+  Information not available
#
#     Is this hardware clonable?
# 519                         No
# 558                         No
# 559                         No
# 560                         No
# 561                         No

# %%
# Create a dataframe only with Make: Hummer
df_hummer = df_chevrolet_renamed_column[df_chevrolet_renamed_column['Make'] == 'Hummer']

# %%
# Check is the df is ok
df_hummer.tail()
# Out:
#      Year    Make   Model  Security       Hardware Part Number  \
# 504  2009  Hummer  H2 SUT      PK3+  Information not available
# 505  2009  Hummer      H3  PL3/PK3+  Information not available
# 551  2010  Hummer      H2      PK3+  Information not available
# 552  2010  Hummer  H2 SUT      PK3+  Information not available
# 553  2010  Hummer      H3  PL3/PK3+  Information not available
#
#     Is this hardware clonable?
# 504                         No
# 505                         No
# 551                         No
# 552                         No
# 553                         No

# %%
# Create a dictionary with the dataframes from each make
dataframes_each_make = {
                        'Ford': df_ford_updated,
                        'Lincoln': df_lincoln_updated,
                        'Mercury': df_mercury_updated,
                        'Mazda': df_mazda_updated,
                        'Chevrolet': df_chevy_filtered,
                        'Pontiac': df_pontiac,
                        'Cadillac': df_cadillac,
                        'Buick': df_buick,
                        'Oldsmobile': df_oldsmobile,
                        'GMC': df_gmc,
                        'Saturn': df_saturn,
                        'Hummer': df_hummer
}

# %% [markdown]
# This is a test to confirm if the dictionary works as intended.

# %%
# These variables similate the ones the user customer will see on the application.
selected_year = 2005
selected_make = 'Cadillac'
selected_model = 'CTS'

# %%
# Get the dataframe from the dictionary based on the selected_make variable
selected_df = dataframes_each_make.get(selected_make)

# %%
# Filter the dataframe chosen based on the year and model selected. The dataframe will become one line where the values will be shown to the user.
df_selected_filtered = selected_df[(selected_df['Year'] == selected_year) & (selected_df['Model'] == selected_model)]

# %%
# Print
df_selected_filtered
# Out:
#      Year      Make Model Security Hardware Part Number  \
# 288  2005  Cadillac   CTS     PK3+             U44G-G45
#
#     Is this hardware clonable?
# 288                         No

# %%
# Acess the values of the 1st (and the only line) and store in a variable
row_df_selected_filtered = df_selected_filtered.iloc[0]

# %%
# Iterate in each column of the dataframe and print the values of each line
for column in df_selected_filtered.columns:
    print(f"{column}: {row_df_selected_filtered[column]}")
# Out:
# Year: 2005
# Make: Cadillac
# Model: CTS
# Security: PK3+
# Hardware Part Number: U44G-G45
# Is this hardware clonable?: No

# %%
df_lincoln_updated.to_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\dataframe_each_make_xlsx_file\df_lincoln_updated.xlsx')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\L'
# <>:1: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_28448\1676507596.py:1: SyntaxWarning: invalid escape sequence '\L'
#   df_lincoln_updated.to_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\dataframe_each_make_xlsx_file\df_lincoln_updated.xlsx')

# %%
# Instead of copying all the code above, used to manipulate the main dataframe named df in this notebook, the dataframes created from the main one will be 
# saved in excel format and then loaded in immo_Assistant.py, followed by the code to create the application with the Streamlit library.
df_ford_new.to_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\dataframe_each_make_xlsx_file\df_ford_new.xlsx')
df_lincoln_updated.to_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\dataframe_each_make_xlsx_file\df_lincoln_updated.xlsx')
df_mercury_updated.to_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\dataframe_each_make_xlsx_file\df_mercury_updated.xlsx')
df_mazda_updated.to_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\dataframe_each_make_xlsx_file\df_mazda_updated.xlsx')
df_chevy_filtered.to_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\dataframe_each_make_xlsx_file\df_chevy_filtered.xlsx')
df_pontiac.to_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\dataframe_each_make_xlsx_file\df_pontiac.xlsx')
df_cadillac.to_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\dataframe_each_make_xlsx_file\df_cadillac.xlsx')
df_buick.to_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\dataframe_each_make_xlsx_file\df_buick.xlsx')
df_oldsmobile.to_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\dataframe_each_make_xlsx_file\df_oldsmobile.xlsx')
df_gmc.to_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\dataframe_each_make_xlsx_file\df_gmc.xlsx')
df_saturn.to_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\dataframe_each_make_xlsx_file\df_saturn.xlsx')
df_hummer.to_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\dataframe_each_make_xlsx_file\df_hummer.xlsx')
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\L'
# <>:4: SyntaxWarning: invalid escape sequence '\L'
# <>:5: SyntaxWarning: invalid escape sequence '\L'
# <>:6: SyntaxWarning: invalid escape sequence '\L'
# <>:7: SyntaxWarning: invalid escape sequence '\L'
# <>:8: SyntaxWarning: invalid escape sequence '\L'
# <>:9: SyntaxWarning: invalid escape sequence '\L'
# <>:10: SyntaxWarning: invalid escape sequence '\L'
# <>:11: SyntaxWarning: invalid escape sequence '\L'
# <>:12: SyntaxWarning: invalid escape sequence '\L'
# <>:13: SyntaxWarning: invalid escape sequence '\L'
# <>:14: SyntaxWarning: invalid escape sequence '\L'
# <>:3: SyntaxWarning: invalid escape sequence '\L'
# <>:4: SyntaxWarning: invalid escape sequence '\L'
# <>:5: SyntaxWarning: invalid escape sequence '\L'
# <>:6: SyntaxWarning: invalid escape sequence '\L'
# <>:7: SyntaxWarning: invalid escape sequence '\L'
# <>:8: SyntaxWarning: invalid escape sequence '\L'
# <>:9: SyntaxWarning: invalid escape sequence '\L'
# <>:10: SyntaxWarning: invalid escape sequence '\L'
# <>:11: SyntaxWarning: invalid escape sequence '\L'
# <>:12: SyntaxWarning: invalid escape sequence '\L'
# <>:13: SyntaxWarning: invalid escape sequence '\L'
# <>:14: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_28448\3684713339.py:3: SyntaxWarning: invalid escape sequence '\L'
#   df_ford_new.to_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\dataframe_each_make_xlsx_file\df_ford_new.xlsx')
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_28448\3684713339.py:4: SyntaxWarning: invalid escape sequence '\L'
#   df_lincoln_updated.to_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\dataframe_each_make_xlsx_file\df_lincoln_updated.xlsx')
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_28448\3684713339.py:5: SyntaxWarning: invalid escape sequence '\L'
#   df_mercury_updated.to_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\dataframe_each_make_xlsx_file\df_mercury_updated.xlsx')
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_28448\3684713339.py:6: SyntaxWarning: invalid escape sequence '\L'
#   df_mazda_updated.to_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\dataframe_each_make_xlsx_file\df_mazda_updated.xlsx')
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_28448\3684713339.py:7: SyntaxWarning: invalid escape sequence '\L'
#   df_chevy_filtered.to_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\dataframe_each_make_xlsx_file\df_chevy_filtered.xlsx')
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_28448\3684713339.py:8: SyntaxWarning: invalid escape sequence '\L'
#   df_pontiac.to_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\dataframe_each_make_xlsx_file\df_pontiac.xlsx')
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_28448\3684713339.py:9: SyntaxWarning: invalid escape sequence '\L'
#   df_cadillac.to_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\dataframe_each_make_xlsx_file\df_cadillac.xlsx')
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_28448\3684713339.py:10: SyntaxWarning: invalid escape sequence '\L'
#   df_buick.to_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\dataframe_each_make_xlsx_file\df_buick.xlsx')
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_28448\3684713339.py:11: SyntaxWarning: invalid escape sequence '\L'
#   df_oldsmobile.to_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\dataframe_each_make_xlsx_file\df_oldsmobile.xlsx')
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_28448\3684713339.py:12: SyntaxWarning: invalid escape sequence '\L'
#   df_gmc.to_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\dataframe_each_make_xlsx_file\df_gmc.xlsx')
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_28448\3684713339.py:13: SyntaxWarning: invalid escape sequence '\L'
#   df_saturn.to_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\dataframe_each_make_xlsx_file\df_saturn.xlsx')
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_28448\3684713339.py:14: SyntaxWarning: invalid escape sequence '\L'
#   df_hummer.to_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\dataframe_each_make_xlsx_file\df_hummer.xlsx')

# %%
# Create an array with all makes of the main df
make_list = df['Make'].unique()

# %%
# Create a list of all makes the dataframe is ready
list_df_make_ready = []

# Loop in the dictionary to get the make names
for make in dataframes_each_make:
    # Store the makes of the dictironary into a list
    list_df_make_ready.append(make)

# %%
# Create a check_list with makes the df is not ready yet using list comprehensions
make_to_be_done = [make for make in make_list if make not in list_df_make_ready]

# %%
# Print the check list
print(make_to_be_done)
# Out:
# ['Acura', 'Honda', 'BMW', 'Lexus', 'Toyota', 'Chrysler', 'Dodge', 'Infiniti', 'Jaguar', 'Nissan', 'Plymouth', 'Jeep', 'Audi', 'Mitsubishi', 'Volkswagen', 'Land Rover', 'Mini', 'Rolls-Royce', 'Scion', 'Subaru', 'Fiat']

# %%
# Print make check list to see what is the next make to create the df
print(make_to_be_done)
# Out:
# ['Acura', 'Honda', 'BMW', 'Lexus', 'Toyota', 'Chrysler', 'Dodge', 'Infiniti', 'Jaguar', 'Nissan', 'Plymouth', 'Jeep', 'Audi', 'Mitsubishi', 'Volkswagen', 'Land Rover', 'Mini', 'Rolls-Royce', 'Scion', 'Subaru', 'Fiat']

# %%
# Create a function to create the dataframe for each make
def create_make_df(make):
    return df[df['Make'] == make]

# %%
# Function to create a list w/ unique values from the columns 
def strings_from_column(df_make, column):
    # List to store the strings from the columns
    strings_from_column_list = []
    # Loop to get the strings from each row based on the column given
    for string in df_make[column]:
        # Store the strings in the list
        strings_from_column_list.append(string)
    # Return a list w/ unique values/strings from the column given
    return set(strings_from_column_list)

# %%
# Count the makes to confirm if all dataframes were created
make_count = strings_from_column(df, 'Make')

# %%
# Count the makes
pd.DataFrame(make_list).count()
# Out:
# 0    33
# dtype: int64
