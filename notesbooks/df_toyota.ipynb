# %%
import pandas as pd

# %%
# Import all data from the main df noebook (Immo_Assistant.app)
# %run Immo_Assistant.app.ipynb
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_21292\507487594.py:2: SyntaxWarning: invalid escape sequence '\L'
#   df = pd.read_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\data\year_make_model_df.xlsx')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3463 entries, 0 to 3462
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            3463 non-null   int64
#  1   Make            3463 non-null   object
#  2   Model           3463 non-null   string
#  3   Security        3156 non-null   object
#  4   ParameterReset  938 non-null    object
# dtypes: int64(1), object(3), string(1)
# memory usage: 135.4+ KB
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# ...

# %%
# Print the list of makes to be done and confirm the next dataframe to be created
make_to_be_done
# Out:
# ['Acura',
#  'Honda',
#  'BMW',
#  'Lexus',
#  'Toyota',
#  'Chrysler',
#  'Dodge',
#  'Infiniti',
#  'Jaguar',
#  'Nissan',
#  'Plymouth',
#  'Jeep',
#  'Audi',
#  'Mitsubishi',
#  'Volkswagen',
#  'Land Rover',
#  'Mini',
#  'Rolls-Royce',
#  'Scion',
#  'Subaru',
#  'Fiat']

# %%
# Next df to be created 'Toyota'
df_toyota = create_make_df("Toyota")

# %%
# Check if there are null values
df_toyota.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 272 entries, 215 to 3408
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            272 non-null    int64
#  1   Make            272 non-null    object
#  2   Model           272 non-null    string
#  3   Security        210 non-null    object
#  4   ParameterReset  0 non-null      object
# dtypes: int64(1), object(3), string(1)
# memory usage: 12.8+ KB

# %%
# Drop column 'ParameterReset' as it is not useful in this dataframe
df_toyota = df_toyota.drop(['ParameterReset'], axis=1)

# %%
# Create a list w/ all strings from column 'Model', analyse the strings and decide is changes need to be done
toyota_model_list = strings_from_column(df_toyota, 'Model')

# %%
# Print the list
toyota_model_list
# Out:
# {'4 Runner',
#  'Avalon',
#  'Avalon\nLimited',
#  'Avalon Limited',
#  'Camry',
#  'Celica',
#  'Corolla',
#  'Echo',
#  'FJ Cruiser',
#  'Highlander',
#  'Landcruiser',
#  'MR2\nSpyder',
#  'MR2 Spyder',
#  'Matrix',
#  'Prius',
#  'Prius C',
#  'Prius Plug\nIn',
#  'Prius V',
#  'RAV 4',
#  'RAV4 Plug\nin',
#  'Sequoia',
#  'Sienna',
#  'Solara',
#  'Tacoma',
#  'Tundra',
#  'Venza',
#  'Yaris'}

# %% [markdown]
# # CHANGES NEEDED:
# - Replace the caractere '\n' for space ' '

# %%
# Replace the caractere '\n' for space ' '
df_toyota['Model'] = df_toyota['Model'].str.replace("\n", " ", regex=False)

# %%
# Create a list to show all values/strings from column 'Security' to decide if changes need to be done
toyota_security_list = strings_from_column(df_toyota, 'Security')

# %%
# Print the list
print(toyota_security_list)
# Out:
# {'Std Smart Key HV', 'Std Smart LE', 'Std SLE, Opt SE', 'Std LTD', 'Std V6, Opt 14', 'Std LE/ XLE/ XLE Limited', 'Std XLE & LE\nAnd Limited', 'Smart Key', 'Std SLE Std SE V6', 'Std XLE\nStd LE V6', 'Std Ltd.\nOpt all others', 'Std Opt LE', 'Smart\nKey', 'Std V8, Opt V6', nan, 'Opt\nOpt on Liftback', 'Opt Sed & Sed. “S”\nN/A on Liftback', 'Std Smart Opt', 'Std LTD, Opt SR5', 'Opt', 'Std Ltd & HV, Opt Base', 'Smart\nKey Std', 'Std', 'Std XLE, Opt LE', 'Std Smart XLE', 'Smart', 'Std XLS, Opt XL', 'Std XLE Std LE/SE V6', 'Std V6', 'Std Ltd.', 'Std LTD pkg, Opt base', 'Std\nSmart Ltd', 'Std\nSmart Key HV', 'Std XLS', 'Std V6, Opt I4', 'Std Ltd, Opt Base', 'Smart Key Std', 'Std\nSmart XLE & HV', 'Std XLE', 'Std Smart Ltd', 'Std XLE & Ltd Std AWD\nCE/LE'}

# %% [markdown]
# CHANGES NEEDED:
# - Replace the charactere '\n' by space ' '.
# - Fill out null values

# %%
# Replace the charactere '\n' by space ' '
df_toyota['Security'] = df_toyota['Security'].str.replace('\n', ' ', regex=False)

# %%
# Fill out null values
df_toyota['Security'].fillna('Information not available', inplace=True)
# Out:
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_21292\266913319.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_toyota['Security'].fillna('Information not available', inplace=True)

# %%
# Reset index
df_toyota.reset_index(drop=True)
# Out:
#      Year    Make       Model                   Security
# 0    1996  Toyota    4 Runner  Information not available
# 1    1996  Toyota      Avalon  Information not available
# 2    1996  Toyota       Camry  Information not available
# 3    1996  Toyota      Celica  Information not available
# 4    1996  Toyota     Corolla  Information not available
# ..    ...     ...         ...                        ...
# 267  2013  Toyota  Highlander              Std Smart Ltd
# 268  2013  Toyota     Prius C              Std Smart Opt
# 269  2013  Toyota      Sienna              Std Smart XLE
# 270  2013  Toyota      Tacoma             Std V6, Opt 14
# 271  2013  Toyota      Tundra             Std V8, Opt V6
#
# [272 rows x 4 columns]

# %%
# Download the scion df to .pkl file format
df_toyota.to_excel('df_toyota_updated.xlsx')
