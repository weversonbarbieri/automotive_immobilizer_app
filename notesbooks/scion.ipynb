# %%
import pandas as pd

# %%
# %run Immo_Assistant.app.ipynb
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_12096\507487594.py:2: SyntaxWarning: invalid escape sequence '\L'
#   df = pd.read_excel('C:\Language_Projects\Language_Projects\Python\Flagship_1\Immo_Assistant.app\data\year_make_model_df.xlsx')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3463 entries, 0 to 3462
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            3463 non-null   int64
#  1   Make            3463 non-null   object
#  2   Model           3463 non-null   string
#  3   Security        3156 non-null   object
#  4   ParameterReset  938 non-null    object
# dtypes: int64(1), object(3), string(1)
# memory usage: 135.4+ KB
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# PATS Type A (Stand Alone PATS Module)
# ...

# %%
# Print the check list to see what is the next dataframe needs to be created
print(make_to_be_done)
# Out:
# ['Pontiac', 'Mazda', 'Acura', 'Honda', 'BMW', 'Lexus', 'Toyota', 'Chrysler', 'Dodge', 'Infiniti', 'Jaguar', 'Lincoln', 'Nissan', 'Plymouth', 'Jeep', 'Audi', 'Mitsubishi', 'Volkswagen', 'Land Rover', 'Mini', 'Rolls-Royce', 'Scion', 'Subaru', 'Fiat']

# %%
# Create Scion dataframe
df_scion = create_make_df('Scion')

# %%
# Check the dataframe to see how it is
df_scion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34 entries, 1331 to 3380
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            34 non-null     int64
#  1   Make            34 non-null     object
#  2   Model           34 non-null     string
#  3   Security        18 non-null     object
#  4   ParameterReset  0 non-null      object
# dtypes: int64(1), object(3), string(1)
# memory usage: 1.6+ KB

# %%
# Create a list w/ all strings/values from column model
scion_model_list = strings_from_column(df_scion, 'Model')

# %%
# Print the list
scion_model_list
# Out:
# {'FR-S', 'IQ', 'IQ EV', 'tC', 'xA', 'xB', 'xD'}

# %% [markdown]
# No changes are needed in the Model column as all models are correct described.

# %%
# Create a list w/ all strings/values from column security
scion_security_list = strings_from_column(df_scion, 'Security')

# %%
# Print the list
scion_security_list
# Out:
# {'Opt', 'Smart', 'Smart Key Std', 'Std', 'Std\nSmart Opt', 'Std Smart', nan}

# %% [markdown]
# CHANGES NEEDED:
# - Fill out null values.
# - Remove/replace the charactere '\n' for space ' '

# %%
# Remove/replace the charactere '\n' for space ' '
df_scion['Security'] = df_scion['Security'].str.replace('\n', ' ', regex=True)
# Out:
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_12096\2101698778.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_scion['Security'] = df_scion['Security'].str.replace('\n', ' ', regex=True)

# %%
# Fill out null values
df_scion['Security'].fillna('Information not available', inplace=True)
# Out:
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_12096\2815490269.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_scion['Security'].fillna('Information not available', inplace=True)
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_12096\2815490269.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
# Create a list w/ the strings/values updated 
scion_security_list_updated = strings_from_column(df_scion, 'Security')

# %%
# Print the list
scion_security_list_updated
# Out:
# {'Information not available',
#  'Opt',
#  'Smart',
#  'Smart Key Std',
#  'Std',
#  'Std Smart',
#  'Std Smart Opt'}

# %%
# Delete ParameterReset column as it is empty
df_scion_column_removed = df_scion.drop(columns=['ParameterReset'])

# %%
# Loop to confirm if column ParameterReset was dropped
for column in df_scion_column_removed.columns:
    print(column)
# Out:
# Year
# Make
# Model
# Security

# %%
# Reset index
df_scion_column_removed.reset_index(drop=True)
# Out:
#     Year   Make  Model                   Security
# 0   2004  Scion     xA  Information not available
# 1   2004  Scion     xB  Information not available
# 2   2004  Scion     tC                        Std
# 3   2005  Scion     xA  Information not available
# 4   2005  Scion     xB  Information not available
# 5   2005  Scion     tC                        Std
# 6   2006  Scion     xA  Information not available
# 7   2006  Scion     xB  Information not available
# 8   2006  Scion     tC                        Std
# 9   2007  Scion     xA  Information not available
# 10  2007  Scion     xB  Information not available
# 11  2007  Scion     tC                        Std
# 12  2008  Scion     xB  Information not available
# 13  2008  Scion     xD  Information not available
# 14  2008  Scion     tC                        Std
# 15  2009  Scion     xB  Information not available
# 16  2009  Scion     xD  Information not available
# 17  2009  Scion     tC                        Std
# ...

# %%
# Download the scion df to .pkl file format
df_scion_column_removed.to_excel('df_scion_updated.xlsx')
